# %%
import numpy as np   #importing libraries
import simpy 
import queue
import random
import random as rd
import matplotlib 
from matplotlib import pyplot as plt

# %%
global SZ,CP,RM
SZ=[]
CP=[]
RM=[]
N=1000
k=10
Lambda = 5
mu = 1.25
#t = 0   #system clock
t1=0
t2=0
t_lambda = 0 #poisson random variable used to generate next service time
t_mu = 0  #poisson random variable used to generate next departure time
t_a=0
wait=0
R=1000
transmission_time=0
l="0"
P_transmission=500
P_idle=100
alpha = 0.1
gamma = 0.95
episodes = 10
SHOW_EVERY = 100
STATS_EVERY=100
observation_space_discretesize = [20, 20]

# %%
class Packet(object):
    def __init__(self, time, id, mobileID, seeed):
        
        self.time=time                                                
        self.id=id
        self.mobileID=mobileID   
        self.size=random.randint(200,400) #seed 1 op 2, seed 2 op 
        SZ.append(round(self.size,2))
        #print(seeed)
        #random.seed(seeed)
        self.cpu=random.randint(20,90) #seed 1 op 2, seed 2 op 
        CP.append(round(self.cpu,2))
        #random.seed(seeed)
        self.ram=random.randint(1, 32) #seed 1 op 3, seed 2 op 1, seed 3 op 4
        RM.append(round(self.ram,2))

class mobile(object): #mobile class with an ID              
    def __init__(self, ID):
        self.ID=ID
        self.pot=int(1)
        
    #generates packets and sends via out_pipe
    def packet_generator(self, numPackets, env, out_pipe, task_id,send): 
        
        yield env.timeout(send)
        #print("sending task {} of mobile {} at time {}".format(task_id, self.ID, env.now))
        p=Packet(env.now, task_id, self.ID, self.pot)
        self.pot+=1
        if(self.pot==4):
                self.pot=1
        yield out_pipe.put(p)
        item = yield out_pipe.get()

# %%
 def reward_generator(T): 
    Tsla=2.5 
    Nsla=3
    Gsla=3  
    Cost_sla=50
    Cg=0
    Ct=0
    Cn=0
    Cost_n=0
    
    #if (G<Gsla):
        #Cg=-5*(Gsla/G)
    if (T>Tsla):
        Ct = -5 * (T/Tsla)
    #if (N>Nsla):
        #Cn=-5*(N/Nsla)
    #if (cost>Cost_sla):
        #Cost_n=-5*(cost/Cost_sla)
    
    Reward = (Tsla/T) + Ct #Reward Function
    return Reward

# %%
class Fog(object):      
    def __init__(self, ID):
        self.ID=ID
        self.Number_queue=1
        self.lost=0
        self.response_time=0
        self.server_count=0
        self.wait=0
        self.taskinqueue=0
        self.a=0
        self.time=0
        
        self.service_time=[]
        self.response_time_list=[]
        self.Serverqueue=[]
        self.total_serverqueue=[]
        self.waitlist=[]
        self.energy_offloading=[]
        self.reward_list=[]
        self.state=[]
        
    def FOG(self, env, server, in_pipe,mobile,pipe3):
        
         msg = yield in_pipe.get()
         transmission_time = (msg.size/R)
         #print("transmits task {} to need time {}".format(msg.id,transmission_time,self.ID))
         yield env.timeout(transmission_time)
         self.a=env.now
         #print("Arrived task {} at time {} at FOG {}".format(msg.id,self.a,self.ID))
         #print("server",self.server_count)
         if self.server_count==3:
            if len(self.Serverqueue)<k:
               self.Serverqueue.append(msg)
               self.taskinqueue=len(self.Serverqueue)
               #print("queue te ase ",len(self.Serverqueue))
               #print("task ase queue te ase ",taskinqueue)
               self.Number_queue = self.Number_queue + 1
               #self.server_count=0
            else:
                self.lost=self.lost+1 
                return  
         #s=q+1  
         #q=s
         u=rd.random()
         t_mu=-np.log(u)/mu
         self.service_time.append(t_mu)
         #print("service time",t_mu)
         E = (P_transmission * transmission_time) + (P_idle * t_mu)
         self.energy_offloading.append(E)
         
         #print("present a queue te ase ",len(self.Serverqueue))
         print("Fog:   Fog",self.ID,"mobile",mobile,", akhon queue te ase ",self.taskinqueue,", time",env.now)
         yield pipe3.put(env.now)
         with server.request() as req:
             yield req
             s=env.now
             self.wait=s-self.a
             if len(self.Serverqueue)>0:
                 self.Serverqueue.pop(0)
             #self.total_serverqueue.append(len(self.Serverqueue))
             #print("queue",len(self.Serverqueue))
             #print("wait",self.wait)
             #print("Starting service task {} at time {} at FOG {}".format(msg.id,s,self.ID))
             #print("Waiting time of task {} at time {} at FOG {}".format(msg.id,self.wait,self.ID))
             self.waitlist.append(self.wait)
             self.response_time=self.wait+t_mu
             self.response_time_list.append(self.response_time)
             
             #if self.wait>0:
                #print("queue",len(self.Serverqueue))
              #  if len(self.Serverqueue)<10:
               #     self.Serverqueue.append(msg)
                #    self.Number_queue = self.Number_queue + 1
                 #   self.total_serverqueue.append(len(self.Serverqueue))
                  #  yield env.timeout(t_mu)
                   # print("Finish service task {} at time {} at FOG {}".format(msg.id,env.now,self.ID))
                    #if len(self.Serverqueue)>0:
                     #   self.Serverqueue.pop(0)
                #else:
                 #   self.lost=self.lost+1 
                  #  return 
             self.server_count=self.server_count+1
             yield env.timeout(t_mu)
             #print("Finish service task {} at time {} at FOG {}".format(msg.id,env.now,self.ID))
             self.server_count=self.server_count-1   

                
             r=reward_generator(self.response_time)
             self.reward_list.append(r)
         #print("Fog",self.ID,"pore queue te ase ",self.taskinqueue,"time hoitese",env.now)
         return self.a 
    def nextstate(self,env,mobile,pipe3):
        state = yield pipe3.get()
        #print("return time is",state)
        #yield env.timeout(state)
        #print("time is",env.now)
        next_state=self.taskinqueue
        print("nxtstate: Fog",self.ID,"mobile",mobile,", req er age queue te ase",next_state,", time",env.now)

# %%
env1 = simpy.Environment()    
server1 = simpy.Resource(env1, capacity=3)
server2 = simpy.Resource(env1, capacity=3)

pipe1 = simpy.Store(env1)
pipe2 = simpy.Store(env1)
pipe3 = simpy.Store(env1)

ms1=mobile(1)
ms2=mobile(2)
ms3=mobile(3)

fog1 = Fog(1)
fog2 = Fog(2)
fog1_count=0
fog2_count=0
for i in range(N):
    
    choose=random.randint(1,2)

    if(choose==1):
        fog1_count=fog1_count+1
        u=rd.random()
        t_lambda=-np.log(u)/Lambda
        t_a=t1+t_lambda
        t1=t_a

        env1.process(ms1.packet_generator(1, env1, pipe1, i,t_a))
        p=env1.process(fog1.FOG(env1, server1, pipe1,ms1.ID,pipe3))
        env1.process(fog1.nextstate(env1,ms1.ID,pipe3))
        
        fog1_count=fog1_count+1
        u=rd.random()
        t_lambda=-np.log(u)/Lambda
        t_a=t2+t_lambda
        t2=t_a

        env1.process(ms2.packet_generator(1, env1, pipe2, i,t_a))
        env1.process(fog1.FOG(env1, server1, pipe2,ms2.ID,pipe3))
        env1.process(fog1.nextstate(env1,ms2.ID,pipe3))
    if(choose==2):
         fog2_count=fog2_count+1
         u=rd.random()
         t_lambda=-np.log(u)/Lambda
         t_a=t1+t_lambda
         t1=t_a

         env1.process(ms1.packet_generator(1, env1, pipe1, i,t_a))
         env1.process(fog2.FOG(env1, server2, pipe1,ms1.ID,pipe3))
         env1.process(fog2.nextstate(env1,ms1.ID,pipe3))
        
         fog2_count=fog2_count+1
         u=rd.random()
         t_lambda=-np.log(u)/Lambda
         t_a=t2+t_lambda
         t2=t_a

         env1.process(ms2.packet_generator(1, env1, pipe2, i,t_a))
         env1.process(fog2.FOG(env1, server2, pipe2,ms2.ID,pipe3))
         env1.process(fog2.nextstate(env1,ms2.ID,pipe3))
env1.run()
    
#i=0
#while (i<N):
 #   print("{}     {}     {}".format(i+1,fog1.response_time_list[i],fog1.reward_list[i]))
 #   i+=1

print(fog1.lost,fog2.lost)
print(fog1_count,fog2_count)
#print(len(fog1.total_serverqueue))
#Na=N-fog.lost
#print("No    serverqueue       wait_time")
#i=0
#c=0
#while (i<fog2_count):
   # if(fog2.waitlist[i]>0):
  #      c+=1
 #   i+=1
#print("total queue te ase",fog2.Number_queue)
#print("total wait list e ase",c)
#print("FOG-1 MAXIMUM REAWARD:", max(fog1.reward_list))
#print("FOG-1 total number of task in queue",fog1.Number_queue)
avgwaittime=sum(fog1.waitlist)/fog1_count
print("FOG-1 Average queueing time:", avgwaittime)
avgservicetime=sum(fog1.service_time)/fog1_count
print("FOG-1 Average service time:", avgservicetime)
avgsystemtime=sum(fog1.response_time_list)/fog1_count
print("FOG-1 Average response time:", avgsystemtime)
avgenergy=sum(fog1.energy_offloading)/fog1_count
print("FOG-1 Average Energy consumption:", avgenergy)

#print("No    response_time       reward")
#i=0
#while (i<N):
 #   print("{}     {}     {}".format(i+1,fog2.response_time_list[i],fog2.reward_list[i]))
  #  i+=1
#print("FOG-2 MAXIMUM REAWARD:", max(fog2.reward_list))
#print("FOG-2 total number of task in queue",fog2.Number_queue)
avgwaittime=sum(fog2.waitlist)/fog2_count
print("FOG-2 Average queueing time:", avgwaittime)
avgservicetime=sum(fog2.service_time)/fog2_count
print("FOG-2 Average service time:", avgservicetime)
avgsystemtime=sum(fog2.response_time_list)/fog2_count
print("FOG-2 Average response time:", avgsystemtime)
avgenergy=sum(fog2.energy_offloading)/fog2_count
print("FOG-2 Average Energy consumption:", avgenergy)
# Out:
# Fog:   Fog 2 mobile 1 , akhon queue te ase  0 , time 0.2385600808770469
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 0 , time 0.2385600808770469
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 0.6120858535639859
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 0 , time 0.6120858535639859
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 0.7464661267276542
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 0 , time 0.7464661267276542
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 0.9242627290457991
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 0 , time 0.9242627290457991
# Fog:   Fog 1 mobile 1 , akhon queue te ase  0 , time 0.9332773769594699
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 0 , time 0.9332773769594699
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 0.9757153771819433
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 1 , time 0.9757153771819433
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 1.033255959578819
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 0 , time 1.033255959578819
# Fog:   Fog 1 mobile 1 , akhon queue te ase  2 , time 1.1821478695064203
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 0 , time 1.1821478695064203
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 1.1895091512420535
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 1.1895091512420535
# Fog:   Fog 2 mobile 1 , akhon queue te ase  0 , time 1.3233065449128985
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 3 , time 1.3233065449128985
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 1.3467079727327111
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 4 , time 1.3467079727327111
# Fog:   Fog 1 mobile 1 , akhon queue te ase  3 , time 1.5327256023091544
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 3 , time 1.5327256023091544
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 1.652499973830898
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 4 , time 1.652499973830898
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 1.7006797360574486
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 5 , time 1.7006797360574486
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 1.7799549223058193
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 6 , time 1.7799549223058193
# Fog:   Fog 2 mobile 1 , akhon queue te ase  0 , time 1.814101569531454
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 6 , time 1.814101569531454
# Fog:   Fog 1 mobile 1 , akhon queue te ase  7 , time 1.8200133861587047
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 0 , time 1.8200133861587047
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 1.8980182197933728
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 1 , time 1.8980182197933728
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 2.0146907543183543
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 2 , time 2.0146907543183543
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 2.289150294588343
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 3 , time 2.289150294588343
# Fog:   Fog 2 mobile 2 , akhon queue te ase  4 , time 2.3437929623899945
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 4 , time 2.3437929623899945
# Fog:   Fog 2 mobile 2 , akhon queue te ase  5 , time 2.391251228255347
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 5 , time 2.391251228255347
# Fog:   Fog 2 mobile 1 , akhon queue te ase  5 , time 2.4887179536974022
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 7 , time 2.4887179536974022
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 2.5229245456066343
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 5 , time 2.5229245456066343
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 2.5770637211210103
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 5 , time 2.5770637211210103
# Fog:   Fog 2 mobile 2 , akhon queue te ase  6 , time 2.578735460742809
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 6 , time 2.578735460742809
# Fog:   Fog 2 mobile 1 , akhon queue te ase  6 , time 2.695506528878679
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 6 , time 2.695506528878679
# Fog:   Fog 2 mobile 1 , akhon queue te ase  7 , time 2.9502239478457564
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 7 , time 2.9502239478457564
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 3.1390418784678698
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 5 , time 3.1390418784678698
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 3.1426649168893115
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 6 , time 3.1426649168893115
# Fog:   Fog 1 mobile 1 , akhon queue te ase  4 , time 3.2511926621903777
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 4 , time 3.2511926621903777
# Fog:   Fog 2 mobile 1 , akhon queue te ase  7 , time 3.258252449494187
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 4 , time 3.258252449494187
# Fog:   Fog 1 mobile 1 , akhon queue te ase  4 , time 3.3041108781868056
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 4 , time 3.3041108781868056
# Fog:   Fog 2 mobile 2 , akhon queue te ase  8 , time 3.436691018982018
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 4 , time 3.436691018982018
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 3.465626255865577
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 8 , time 3.465626255865577
# Fog:   Fog 1 mobile 1 , akhon queue te ase  3 , time 3.4769812272755467
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 8 , time 3.4769812272755467
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 3.4832802708086357
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 4 , time 3.4832802708086357
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 3.694335882645597
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 4 , time 3.694335882645597
# Fog:   Fog 2 mobile 1 , akhon queue te ase  4 , time 3.812486826780989
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 4 , time 3.812486826780989
# Fog:   Fog 2 mobile 2 , akhon queue te ase  5 , time 4.039690014153509
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 5 , time 4.039690014153509
# Fog:   Fog 2 mobile 2 , akhon queue te ase  6 , time 4.042891956985758
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 6 , time 4.042891956985758
# Fog:   Fog 2 mobile 2 , akhon queue te ase  7 , time 4.130097408385798
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 7 , time 4.130097408385798
# Fog:   Fog 2 mobile 2 , akhon queue te ase  8 , time 4.206344498504708
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 8 , time 4.206344498504708
# Fog:   Fog 2 mobile 2 , akhon queue te ase  9 , time 4.23267975732341
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 9 , time 4.23267975732341
# Fog:   Fog 2 mobile 1 , akhon queue te ase  8 , time 4.410475332779555
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 8 , time 4.410475332779555
# Fog:   Fog 2 mobile 2 , akhon queue te ase  9 , time 4.4559254380109365
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 9 , time 4.4559254380109365
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 4.554515590080962
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 9 , time 4.554515590080962
# Fog:   Fog 2 mobile 1 , akhon queue te ase  7 , time 4.768266241339302
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 7 , time 4.768266241339302
# Fog:   Fog 2 mobile 1 , akhon queue te ase  8 , time 4.820005896415841
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 8 , time 4.820005896415841
# Fog:   Fog 2 mobile 1 , akhon queue te ase  9 , time 4.98531245278836
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 9 , time 4.98531245278836
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 5.026685565840923
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 4 , time 5.026685565840923
# Fog:   Fog 2 mobile 2 , akhon queue te ase  9 , time 5.08379980050611
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 4 , time 5.08379980050611
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 5.129566929619971
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 4 , time 5.129566929619971
# Fog:   Fog 1 mobile 1 , akhon queue te ase  4 , time 5.4623357040733875
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 4 , time 5.4623357040733875
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 5.654497309964365
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 5.654497309964365
# Fog:   Fog 1 mobile 1 , akhon queue te ase  4 , time 5.777558597169782
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 5.777558597169782
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 5.913678700163814
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 5.913678700163814
# Fog:   Fog 1 mobile 1 , akhon queue te ase  4 , time 6.082121361520858
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 6.082121361520858
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 6.101997807666195
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 4 , time 6.101997807666195
# Fog:   Fog 1 mobile 1 , akhon queue te ase  4 , time 6.344811238701438
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 4 , time 6.344811238701438
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 6.546457030983599
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 6.546457030983599
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 6.6897416283276225
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 6.6897416283276225
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 6.711865532617212
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 4 , time 6.711865532617212
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 7.15602855069887
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 4 , time 7.15602855069887
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 7.3138706980042
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 7.3138706980042
# Fog:   Fog 1 mobile 1 , akhon queue te ase  4 , time 7.368573112506238
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 7.368573112506238
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 7.613663523717478
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 7.613663523717478
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 7.65915648650415
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 7.65915648650415
# Fog:   Fog 2 mobile 1 , akhon queue te ase  9 , time 8.123401824332213
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 9 , time 8.123401824332213
# Fog:   Fog 1 mobile 1 , akhon queue te ase  4 , time 8.145137761429163
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 9 , time 8.145137761429163
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 8.284356425719505
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 4 , time 8.284356425719505
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 8.346347388979458
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 4 , time 8.346347388979458
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 8.489280262980554
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 8.489280262980554
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 8.705394378295201
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 8.705394378295201
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 8.852839023118207
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 8.852839023118207
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 8.921497779218951
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 8.921497779218951
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 9.052694634016724
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 9.052694634016724
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 9.256291650402098
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 9.256291650402098
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 9.318576806170533
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 1 , time 9.318576806170533
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 9.32214717312377
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 1 , time 9.32214717312377
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 9.553329935267117
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 9.553329935267117
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 9.623699947257046
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 9.623699947257046
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 9.700806509169597
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 1 , time 9.700806509169597
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 9.758470844519403
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 1 , time 9.758470844519403
# Fog:   Fog 1 mobile 1 , akhon queue te ase  2 , time 9.788702536984088
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 9.788702536984088
# Fog:   Fog 1 mobile 1 , akhon queue te ase  3 , time 10.00359804377872
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 10.00359804377872
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 10.139615794220857
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 10.139615794220857
# Fog:   Fog 1 mobile 1 , akhon queue te ase  3 , time 10.273573014991609
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 3 , time 10.273573014991609
# Fog:   Fog 1 mobile 1 , akhon queue te ase  3 , time 10.491426149770827
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 10.491426149770827
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 10.497436882504616
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 10.497436882504616
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 10.6422179508699
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 10.6422179508699
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 10.671612883976449
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 10.671612883976449
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 10.720638001763742
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 5 , time 10.720638001763742
# Fog:   Fog 1 mobile 1 , akhon queue te ase  4 , time 11.144866281012373
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 4 , time 11.144866281012373
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 11.272685042263333
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 11.272685042263333
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 11.323282427889929
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 11.323282427889929
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 11.482327465762857
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 11.482327465762857
# Fog:   Fog 1 mobile 1 , akhon queue te ase  4 , time 11.69671451963106
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 11.69671451963106
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 11.859044019645278
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 11.859044019645278
# Fog:   Fog 2 mobile 1 , akhon queue te ase  7 , time 12.184982442828607
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 7 , time 12.184982442828607
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 12.201436500893777
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 5 , time 12.201436500893777
# Fog:   Fog 2 mobile 2 , akhon queue te ase  8 , time 12.23265203410185
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 5 , time 12.23265203410185
# Fog:   Fog 2 mobile 2 , akhon queue te ase  9 , time 12.502102585385654
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 5 , time 12.502102585385654
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 12.63383473645115
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 5 , time 12.63383473645115
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 12.724294760904879
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 9 , time 12.724294760904879
# Fog:   Fog 2 mobile 1 , akhon queue te ase  9 , time 12.8337920757451
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 9 , time 12.8337920757451
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 12.888396758625781
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 12.888396758625781
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 13.021838075296055
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 13.021838075296055
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 13.206920901692412
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 5 , time 13.206920901692412
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 13.40194541716201
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 5 , time 13.40194541716201
# Fog:   Fog 1 mobile 2 , akhon queue te ase  6 , time 13.40567610179839
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 13.40567610179839
# Fog:   Fog 2 mobile 2 , akhon queue te ase  9 , time 13.846569951084582
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 9 , time 13.846569951084582
# Fog:   Fog 2 mobile 2 , akhon queue te ase  9 , time 14.07957193618962
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 6 , time 14.07957193618962
# Fog:   Fog 1 mobile 2 , akhon queue te ase  6 , time 14.322134820915055
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 6 , time 14.322134820915055
# Fog:   Fog 2 mobile 1 , akhon queue te ase  8 , time 14.446003292235135
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 6 , time 14.446003292235135
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 14.614288544156551
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 6 , time 14.614288544156551
# Fog:   Fog 2 mobile 1 , akhon queue te ase  8 , time 14.759956409385959
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 6 , time 14.759956409385959
# Fog:   Fog 1 mobile 2 , akhon queue te ase  6 , time 14.813378603549712
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 6 , time 14.813378603549712
# Fog:   Fog 2 mobile 1 , akhon queue te ase  9 , time 14.820026485255884
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 9 , time 14.820026485255884
# Fog:   Fog 1 mobile 2 , akhon queue te ase  7 , time 14.9923401380059
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 9 , time 14.9923401380059
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 15.16421940936522
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 9 , time 15.16421940936522
# Fog:   Fog 2 mobile 1 , akhon queue te ase  9 , time 15.176179072728436
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 9 , time 15.176179072728436
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 15.524596892191132
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 6 , time 15.524596892191132
# Fog:   Fog 1 mobile 1 , akhon queue te ase  4 , time 15.534899939531888
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 4 , time 15.534899939531888
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 15.586517828578792
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 5 , time 15.586517828578792
# Fog:   Fog 1 mobile 2 , akhon queue te ase  6 , time 15.657180969755693
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 6 , time 15.657180969755693
# Fog:   Fog 1 mobile 2 , akhon queue te ase  7 , time 15.779622545350536
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 15.779622545350536
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 15.936929181031635
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 15.936929181031635
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 15.963159074640666
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 6 , time 15.963159074640666
# Fog:   Fog 2 mobile 2 , akhon queue te ase  6 , time 16.388720215381124
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 6 , time 16.388720215381124
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 16.407079029950864
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 6 , time 16.407079029950864
# Fog:   Fog 1 mobile 2 , akhon queue te ase  7 , time 16.419965190291503
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 6 , time 16.419965190291503
# Fog:   Fog 2 mobile 2 , akhon queue te ase  6 , time 16.489568707070763
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 6 , time 16.489568707070763
# Fog:   Fog 2 mobile 2 , akhon queue te ase  7 , time 16.50091078884261
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 7 , time 16.50091078884261
# Fog:   Fog 2 mobile 2 , akhon queue te ase  8 , time 16.528861945001452
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 7 , time 16.528861945001452
# Fog:   Fog 1 mobile 1 , akhon queue te ase  7 , time 16.54572902601185
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 7 , time 16.54572902601185
# Fog:   Fog 1 mobile 1 , akhon queue te ase  7 , time 16.59595299612073
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 8 , time 16.59595299612073
# Fog:   Fog 1 mobile 2 , akhon queue te ase  8 , time 16.667070002599537
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 8 , time 16.667070002599537
# Fog:   Fog 2 mobile 2 , akhon queue te ase  8 , time 16.73622412273303
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 8 , time 16.73622412273303
# Fog:   Fog 1 mobile 2 , akhon queue te ase  7 , time 16.80762715494664
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 8 , time 16.80762715494664
# Fog:   Fog 2 mobile 2 , akhon queue te ase  9 , time 16.821318376301843
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 9 , time 16.821318376301843
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 16.87663914536744
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 16.87663914536744
# Fog:   Fog 1 mobile 1 , akhon queue te ase  8 , time 17.100564848226735
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 8 , time 17.100564848226735
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 17.167330021175356
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 8 , time 17.167330021175356
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 17.403104781450985
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 17.403104781450985
# Fog:   Fog 1 mobile 1 , akhon queue te ase  7 , time 17.75951340940145
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 17.75951340940145
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 17.794709441152065
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 17.794709441152065
# Fog:   Fog 1 mobile 1 , akhon queue te ase  8 , time 18.018287028313996
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 18.018287028313996
# Fog:   Fog 1 mobile 2 , akhon queue te ase  9 , time 18.03818210628904
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 9 , time 18.03818210628904
# Fog:   Fog 2 mobile 1 , akhon queue te ase  8 , time 18.254075041671932
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 9 , time 18.254075041671932
# Fog:   Fog 2 mobile 1 , akhon queue te ase  9 , time 18.28084839735873
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 9 , time 18.28084839735873
# Fog:   Fog 1 mobile 2 , akhon queue te ase  10 , time 18.321342054048284
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 9 , time 18.321342054048284
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 18.53549086914621
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 10 , time 18.53549086914621
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 18.567601478493206
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 18.567601478493206
# Fog:   Fog 1 mobile 1 , akhon queue te ase  8 , time 18.836551468422496
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 18.836551468422496
# Fog:   Fog 1 mobile 1 , akhon queue te ase  9 , time 18.95108720822733
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 18.95108720822733
# Fog:   Fog 2 mobile 1 , akhon queue te ase  9 , time 19.422005951019862
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 9 , time 19.422005951019862
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 19.43236352016977
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 19.43236352016977
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 19.625458838841283
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 19.625458838841283
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 19.656963367446494
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 19.656963367446494
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 19.908228301417793
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 5 , time 19.908228301417793
# Fog:   Fog 1 mobile 2 , akhon queue te ase  6 , time 20.039540352028155
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 6 , time 20.039540352028155
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 20.100301939856088
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 20.100301939856088
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 20.22327599928317
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 20.22327599928317
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 20.293727246995623
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 20.293727246995623
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 20.348031771156425
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 20.348031771156425
# Fog:   Fog 1 mobile 2 , akhon queue te ase  6 , time 20.50342721917704
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 20.50342721917704
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 20.52163031633448
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 20.52163031633448
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 20.63677106088574
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 5 , time 20.63677106088574
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 20.670957259067105
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 6 , time 20.670957259067105
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 20.782470860586606
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 6 , time 20.782470860586606
# Fog:   Fog 2 mobile 1 , akhon queue te ase  9 , time 20.95280882749657
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 6 , time 20.95280882749657
# Fog:   Fog 2 mobile 1 , akhon queue te ase  9 , time 21.38264133993651
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 6 , time 21.38264133993651
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 21.534190431177965
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 6 , time 21.534190431177965
# Fog:   Fog 1 mobile 1 , akhon queue te ase  4 , time 21.780221068650103
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 4 , time 21.780221068650103
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 21.85976097228324
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 5 , time 21.85976097228324
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 22.205867638368435
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 22.205867638368435
# Fog:   Fog 2 mobile 2 , akhon queue te ase  9 , time 22.20801042949038
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 3 , time 22.20801042949038
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 22.321856009336706
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 22.321856009336706
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 22.514612577920875
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 2 , time 22.514612577920875
# Fog:   Fog 1 mobile 1 , akhon queue te ase  3 , time 22.519261115701497
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 22.519261115701497
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 22.56737988224534
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 22.56737988224534
# Fog:   Fog 1 mobile 1 , akhon queue te ase  4 , time 22.679710268606964
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 22.679710268606964
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 22.707840925232983
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 22.707840925232983
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 22.72668021141911
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 22.72668021141911
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 23.00278873039945
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 23.00278873039945
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 23.174579864149027
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 23.174579864149027
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 23.677010707575775
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 23.677010707575775
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 23.852761972874923
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 6 , time 23.852761972874923
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 23.957943621823812
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 6 , time 23.957943621823812
# Fog:   Fog 1 mobile 1 , akhon queue te ase  7 , time 24.221311201724692
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 24.221311201724692
# Fog:   Fog 1 mobile 2 , akhon queue te ase  8 , time 24.298940745091986
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 24.298940745091986
# Fog:   Fog 1 mobile 2 , akhon queue te ase  9 , time 24.33228635697211
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 9 , time 24.33228635697211
# Fog:   Fog 1 mobile 2 , akhon queue te ase  10 , time 24.34911089873387
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 24.34911089873387
# Fog:   Fog 2 mobile 1 , akhon queue te ase  8 , time 24.39195826271948
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 8 , time 24.39195826271948
# Fog:   Fog 2 mobile 1 , akhon queue te ase  9 , time 24.644879196363746
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 9 , time 24.644879196363746
# Fog:   Fog 1 mobile 2 , akhon queue te ase  10 , time 24.66778985649365
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 9 , time 24.66778985649365
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 24.674526976290455
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 24.674526976290455
# Fog:   Fog 2 mobile 2 , akhon queue te ase  7 , time 24.96873926035446
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 7 , time 24.96873926035446
# Fog:   Fog 2 mobile 1 , akhon queue te ase  7 , time 25.037034741226233
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 7 , time 25.037034741226233
# Fog:   Fog 1 mobile 1 , akhon queue te ase  10 , time 25.19803847385126
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 10 , time 25.19803847385126
# Fog:   Fog 1 mobile 2 , akhon queue te ase  10 , time 25.263392385767418
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 25.263392385767418
# Fog:   Fog 2 mobile 1 , akhon queue te ase  7 , time 25.288484812134783
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 7 , time 25.288484812134783
# Fog:   Fog 2 mobile 2 , akhon queue te ase  8 , time 25.31788838991114
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 8 , time 25.31788838991114
# Fog:   Fog 2 mobile 1 , akhon queue te ase  9 , time 25.340723428252847
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 9 , time 25.340723428252847
# Fog:   Fog 2 mobile 1 , akhon queue te ase  9 , time 25.418920766557292
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 9 , time 25.418920766557292
# Fog:   Fog 1 mobile 1 , akhon queue te ase  9 , time 25.587247648599064
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 9 , time 25.587247648599064
# Fog:   Fog 1 mobile 1 , akhon queue te ase  10 , time 25.608478534900495
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 9 , time 25.608478534900495
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 25.9750648390258
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 9 , time 25.9750648390258
# Fog:   Fog 2 mobile 2 , akhon queue te ase  8 , time 26.05852901204384
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 8 , time 26.05852901204384
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 26.226290501679042
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 8 , time 26.226290501679042
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 26.315009348568676
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 8 , time 26.315009348568676
# Fog:   Fog 1 mobile 2 , akhon queue te ase  7 , time 26.349548312010725
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 7 , time 26.349548312010725
# Fog:   Fog 1 mobile 1 , akhon queue te ase  7 , time 26.383483298479483
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 7 , time 26.383483298479483
# Fog:   Fog 1 mobile 1 , akhon queue te ase  8 , time 26.40367352099979
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 8 , time 26.40367352099979
# Fog:   Fog 1 mobile 2 , akhon queue te ase  9 , time 26.45930864421957
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 9 , time 26.45930864421957
# Fog:   Fog 2 mobile 2 , akhon queue te ase  5 , time 26.68002867626769
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 5 , time 26.68002867626769
# Fog:   Fog 1 mobile 2 , akhon queue te ase  9 , time 26.766613356772922
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 5 , time 26.766613356772922
# Fog:   Fog 1 mobile 2 , akhon queue te ase  9 , time 26.77983884471338
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 5 , time 26.77983884471338
# Fog:   Fog 2 mobile 2 , akhon queue te ase  6 , time 26.827908180023417
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 6 , time 26.827908180023417
# Fog:   Fog 1 mobile 2 , akhon queue te ase  10 , time 26.832546637280256
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 6 , time 26.832546637280256
# Fog:   Fog 2 mobile 2 , akhon queue te ase  5 , time 26.897861306682767
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 5 , time 26.897861306682767
# Fog:   Fog 2 mobile 1 , akhon queue te ase  5 , time 27.131699535487023
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 5 , time 27.131699535487023
# Fog:   Fog 2 mobile 1 , akhon queue te ase  6 , time 27.256896051859854
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 6 , time 27.256896051859854
# Fog:   Fog 2 mobile 1 , akhon queue te ase  7 , time 27.320754207602906
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 7 , time 27.320754207602906
# Fog:   Fog 2 mobile 2 , akhon queue te ase  8 , time 27.32779943453656
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 8 , time 27.32779943453656
# Fog:   Fog 1 mobile 2 , akhon queue te ase  9 , time 27.395400660132076
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 9 , time 27.395400660132076
# Fog:   Fog 2 mobile 1 , akhon queue te ase  8 , time 28.010063311583846
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 9 , time 28.010063311583846
# Fog:   Fog 1 mobile 1 , akhon queue te ase  3 , time 28.22124669129649
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 8 , time 28.22124669129649
# Fog:   Fog 2 mobile 2 , akhon queue te ase  7 , time 28.531764819360795
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 7 , time 28.531764819360795
# Fog:   Fog 2 mobile 1 , akhon queue te ase  8 , time 28.662559539682096
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 28.662559539682096
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 28.830862155588765
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 1 , time 28.830862155588765
# Fog:   Fog 1 mobile 1 , akhon queue te ase  2 , time 28.96846316520494
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 2 , time 28.96846316520494
# Fog:   Fog 1 mobile 1 , akhon queue te ase  3 , time 28.993593992549574
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 3 , time 28.993593992549574
# Fog:   Fog 2 mobile 1 , akhon queue te ase  7 , time 29.016318246948344
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 29.016318246948344
# Fog:   Fog 1 mobile 1 , akhon queue te ase  4 , time 29.04974487346669
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 4 , time 29.04974487346669
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 29.22633125055592
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 5 , time 29.22633125055592
# Fog:   Fog 1 mobile 2 , akhon queue te ase  6 , time 29.233898736537043
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 6 , time 29.233898736537043
# Fog:   Fog 2 mobile 1 , akhon queue te ase  7 , time 29.313899524446875
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 6 , time 29.313899524446875
# Fog:   Fog 1 mobile 1 , akhon queue te ase  7 , time 29.33964009816327
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 7 , time 29.33964009816327
# Fog:   Fog 1 mobile 1 , akhon queue te ase  7 , time 29.678793261701554
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 7 , time 29.678793261701554
# Fog:   Fog 2 mobile 1 , akhon queue te ase  6 , time 29.679290972026838
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 7 , time 29.679290972026838
# Fog:   Fog 1 mobile 2 , akhon queue te ase  8 , time 30.029783199701452
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 8 , time 30.029783199701452
# Fog:   Fog 1 mobile 1 , akhon queue te ase  9 , time 30.283678721708576
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 9 , time 30.283678721708576
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 30.71547552193583
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 9 , time 30.71547552193583
# Fog:   Fog 1 mobile 2 , akhon queue te ase  10 , time 30.773982033328675
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 30.773982033328675
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 30.91975329998147
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 2 , time 30.91975329998147
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 30.948948163522466
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 3 , time 30.948948163522466
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 31.05503091610055
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 2 , time 31.05503091610055
# Fog:   Fog 2 mobile 1 , akhon queue te ase  3 , time 31.125720343403273
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 3 , time 31.125720343403273
# Fog:   Fog 2 mobile 2 , akhon queue te ase  4 , time 31.246970272987674
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 4 , time 31.246970272987674
# Fog:   Fog 1 mobile 2 , akhon queue te ase  10 , time 31.31633340235336
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 4 , time 31.31633340235336
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 31.455014198268355
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 10 , time 31.455014198268355
# Fog:   Fog 2 mobile 1 , akhon queue te ase  4 , time 31.540021928877945
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 31.540021928877945
# Fog:   Fog 1 mobile 1 , akhon queue te ase  8 , time 31.90800833355735
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 8 , time 31.90800833355735
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 31.954013197922595
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 8 , time 31.954013197922595
# Fog:   Fog 2 mobile 1 , akhon queue te ase  4 , time 32.05225333629141
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 4 , time 32.05225333629141
# Fog:   Fog 2 mobile 1 , akhon queue te ase  5 , time 32.08936608262706
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 5 , time 32.08936608262706
# Fog:   Fog 1 mobile 2 , akhon queue te ase  9 , time 32.11142604211105
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 5 , time 32.11142604211105
# Fog:   Fog 2 mobile 1 , akhon queue te ase  6 , time 32.177059383703096
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 6 , time 32.177059383703096
# Fog:   Fog 1 mobile 1 , akhon queue te ase  7 , time 32.389848206967315
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 6 , time 32.389848206967315
# Fog:   Fog 2 mobile 1 , akhon queue te ase  7 , time 32.652805267785716
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 7 , time 32.652805267785716
# Fog:   Fog 2 mobile 1 , akhon queue te ase  7 , time 32.72318123567636
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 7 , time 32.72318123567636
# Fog:   Fog 1 mobile 1 , akhon queue te ase  7 , time 32.79962006913345
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 7 , time 32.79962006913345
# Fog:   Fog 1 mobile 1 , akhon queue te ase  8 , time 32.87051154305794
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 8 , time 32.87051154305794
# Fog:   Fog 2 mobile 1 , akhon queue te ase  8 , time 32.93047344212284
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 8 , time 32.93047344212284
# Fog:   Fog 2 mobile 2 , akhon queue te ase  8 , time 33.00225266701116
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 8 , time 33.00225266701116
# Fog:   Fog 1 mobile 1 , akhon queue te ase  8 , time 33.02913331571962
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 8 , time 33.02913331571962
# Fog:   Fog 1 mobile 2 , akhon queue te ase  9 , time 33.04093975672638
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 9 , time 33.04093975672638
# Fog:   Fog 1 mobile 2 , akhon queue te ase  10 , time 33.09652059741343
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 33.09652059741343
# Fog:   Fog 2 mobile 1 , akhon queue te ase  7 , time 33.359619340753724
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 10 , time 33.359619340753724
# Fog:   Fog 2 mobile 2 , akhon queue te ase  8 , time 33.49300775642039
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 33.49300775642039
# Fog:   Fog 1 mobile 1 , akhon queue te ase  10 , time 33.54813945108666
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 10 , time 33.54813945108666
# Fog:   Fog 1 mobile 2 , akhon queue te ase  9 , time 33.97510467506453
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 9 , time 33.97510467506453
# Fog:   Fog 1 mobile 2 , akhon queue te ase  10 , time 34.0462311169221
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 10 , time 34.0462311169221
# Fog:   Fog 2 mobile 2 , akhon queue te ase  9 , time 34.13831096816117
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 34.13831096816117
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 34.183423906900536
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 10 , time 34.183423906900536
# Fog:   Fog 2 mobile 1 , akhon queue te ase  9 , time 34.355155957169885
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 34.355155957169885
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 34.379491940842065
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 34.379491940842065
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 34.66326471900308
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 34.66326471900308
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 34.75946928688027
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 34.75946928688027
# Fog:   Fog 1 mobile 1 , akhon queue te ase  9 , time 34.81789236590167
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 34.81789236590167
# Fog:   Fog 1 mobile 1 , akhon queue te ase  10 , time 34.83288465852043
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 34.83288465852043
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 34.98108496198761
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 34.98108496198761
# Fog:   Fog 1 mobile 2 , akhon queue te ase  7 , time 35.23792642401816
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 35.23792642401816
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 35.26420640478547
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 35.26420640478547
# Fog:   Fog 1 mobile 2 , akhon queue te ase  8 , time 35.325743019661985
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 8 , time 35.325743019661985
# Fog:   Fog 1 mobile 1 , akhon queue te ase  9 , time 35.40698891898505
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 9 , time 35.40698891898505
# Fog:   Fog 1 mobile 2 , akhon queue te ase  9 , time 35.74029181808277
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 35.74029181808277
# Fog:   Fog 1 mobile 2 , akhon queue te ase  8 , time 36.22611257452352
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 36.22611257452352
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 36.24453526498561
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 8 , time 36.24453526498561
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 36.371053952560686
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 8 , time 36.371053952560686
# Fog:   Fog 1 mobile 1 , akhon queue te ase  9 , time 36.539170496250826
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 9 , time 36.539170496250826
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 36.5524867476768
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 9 , time 36.5524867476768
# Fog:   Fog 1 mobile 2 , akhon queue te ase  10 , time 36.65202742366746
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 36.65202742366746
# Fog:   Fog 1 mobile 1 , akhon queue te ase  10 , time 36.735759221132334
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 36.735759221132334
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 36.88920507631418
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 10 , time 36.88920507631418
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 37.30702419705276
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 37.30702419705276
# Fog:   Fog 2 mobile 1 , akhon queue te ase  8 , time 37.71077980594193
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 10 , time 37.71077980594193
# Fog:   Fog 2 mobile 1 , akhon queue te ase  9 , time 37.79341552301027
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 37.79341552301027
# Fog:   Fog 1 mobile 2 , akhon queue te ase  10 , time 37.79744010840953
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 10 , time 37.79744010840953
# Fog:   Fog 2 mobile 1 , akhon queue te ase  10 , time 37.87868444105481
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 37.87868444105481
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 37.917597938221554
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 37.917597938221554
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 38.060688009763396
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 38.060688009763396
# Fog:   Fog 1 mobile 1 , akhon queue te ase  10 , time 38.4163433597489
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 10 , time 38.4163433597489
# Fog:   Fog 1 mobile 2 , akhon queue te ase  10 , time 38.802627536160024
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 38.802627536160024
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 39.16617209774505
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 39.16617209774505
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 39.30995517131796
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 39.30995517131796
# Fog:   Fog 1 mobile 2 , akhon queue te ase  7 , time 39.379490721101845
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 7 , time 39.379490721101845
# Fog:   Fog 2 mobile 2 , akhon queue te ase  9 , time 39.59025673377152
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 7 , time 39.59025673377152
# Fog:   Fog 1 mobile 2 , akhon queue te ase  8 , time 39.63316138677181
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 8 , time 39.63316138677181
# Fog:   Fog 1 mobile 1 , akhon queue te ase  9 , time 39.72957359077763
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 9 , time 39.72957359077763
# Fog:   Fog 2 mobile 1 , akhon queue te ase  9 , time 39.98324609804408
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 9 , time 39.98324609804408
# Fog:   Fog 1 mobile 2 , akhon queue te ase  6 , time 40.13266111244911
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 9 , time 40.13266111244911
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 40.22318469164657
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 10 , time 40.22318469164657
# Fog:   Fog 2 mobile 2 , akhon queue te ase  10 , time 40.345433705709695
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 10 , time 40.345433705709695
# Fog:   Fog 1 mobile 1 , akhon queue te ase  7 , time 40.35312072442356
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 7 , time 40.35312072442356
# Fog:   Fog 1 mobile 1 , akhon queue te ase  8 , time 40.42527184162316
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 8 , time 40.42527184162316
# Fog:   Fog 1 mobile 2 , akhon queue te ase  8 , time 40.510612196305985
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 8 , time 40.510612196305985
# ...
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 2 , time 185.18336289894256
# Fog:   Fog 2 mobile 1 , akhon queue te ase  3 , time 185.26851601078386
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 3 , time 185.26851601078386
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 185.2960676269158
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 6 , time 185.2960676269158
# Fog:   Fog 1 mobile 2 , akhon queue te ase  7 , time 185.31679836748668
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 7 , time 185.31679836748668
# Fog:   Fog 1 mobile 1 , akhon queue te ase  8 , time 185.51444328749412
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 8 , time 185.51444328749412
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 185.5177824048672
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 8 , time 185.5177824048672
# Fog:   Fog 1 mobile 2 , akhon queue te ase  9 , time 185.620539790394
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 9 , time 185.620539790394
# Fog:   Fog 1 mobile 1 , akhon queue te ase  8 , time 185.85578383612435
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 8 , time 185.85578383612435
# Fog:   Fog 1 mobile 1 , akhon queue te ase  9 , time 185.85845677375764
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 9 , time 185.85845677375764
# Fog:   Fog 1 mobile 2 , akhon queue te ase  9 , time 185.92641367273876
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 9 , time 185.92641367273876
# Fog:   Fog 1 mobile 1 , akhon queue te ase  10 , time 186.28987500221405
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 3 , time 186.28987500221405
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 186.3066112716699
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 2 , time 186.3066112716699
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 186.47434907649787
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 10 , time 186.47434907649787
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 186.49764720128474
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 186.49764720128474
# Fog:   Fog 2 mobile 1 , akhon queue te ase  4 , time 186.5510867300581
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 10 , time 186.5510867300581
# Fog:   Fog 2 mobile 1 , akhon queue te ase  4 , time 186.69855744815453
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 186.69855744815453
# Fog:   Fog 1 mobile 2 , akhon queue te ase  9 , time 186.81936569032874
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 4 , time 186.81936569032874
# Fog:   Fog 2 mobile 2 , akhon queue te ase  4 , time 186.8382785995753
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 4 , time 186.8382785995753
# Fog:   Fog 1 mobile 2 , akhon queue te ase  10 , time 186.9113221681416
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 4 , time 186.9113221681416
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 187.09281269121024
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 2 , time 187.09281269121024
# Fog:   Fog 1 mobile 1 , akhon queue te ase  10 , time 187.16288010418944
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 10 , time 187.16288010418944
# Fog:   Fog 1 mobile 2 , akhon queue te ase  10 , time 187.60006183812274
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 187.60006183812274
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 187.77018856759557
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 2 , time 187.77018856759557
# Fog:   Fog 1 mobile 2 , akhon queue te ase  10 , time 187.8347885356736
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 2 , time 187.8347885356736
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 187.94460346208885
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 2 , time 187.94460346208885
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 187.96012814625325
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 2 , time 187.96012814625325
# Fog:   Fog 1 mobile 2 , akhon queue te ase  9 , time 188.37729690445238
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 9 , time 188.37729690445238
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 188.56531657063576
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 9 , time 188.56531657063576
# Fog:   Fog 1 mobile 2 , akhon queue te ase  10 , time 188.61143770213627
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 10 , time 188.61143770213627
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 188.62113804062002
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 10 , time 188.62113804062002
# Fog:   Fog 1 mobile 1 , akhon queue te ase  8 , time 189.17909501578836
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 8 , time 189.17909501578836
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 189.3672996086317
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 8 , time 189.3672996086317
# Fog:   Fog 1 mobile 2 , akhon queue te ase  7 , time 189.73649967759317
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 7 , time 189.73649967759317
# Fog:   Fog 1 mobile 1 , akhon queue te ase  8 , time 189.76597232171213
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 8 , time 189.76597232171213
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 189.81913288270803
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 1 , time 189.81913288270803
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 189.8567726836637
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 1 , time 189.8567726836637
# Fog:   Fog 1 mobile 1 , akhon queue te ase  8 , time 189.95971242463384
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 1 , time 189.95971242463384
# Fog:   Fog 1 mobile 2 , akhon queue te ase  7 , time 190.06434501302556
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 1 , time 190.06434501302556
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 190.3341364823413
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 1 , time 190.3341364823413
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 190.34336307757368
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 2 , time 190.34336307757368
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 190.3721324368588
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 3 , time 190.3721324368588
# Fog:   Fog 2 mobile 2 , akhon queue te ase  4 , time 190.4398978861631
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 4 , time 190.4398978861631
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 190.77315282669804
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 4 , time 190.77315282669804
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 190.9312554886104
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 4 , time 190.9312554886104
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 190.94798964698842
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 190.94798964698842
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 190.96796445380502
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 3 , time 190.96796445380502
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 191.10814834401612
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 191.10814834401612
# Fog:   Fog 2 mobile 2 , akhon queue te ase  4 , time 191.36040371963057
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 3 , time 191.36040371963057
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 191.49020792329176
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 4 , time 191.49020792329176
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 191.70628961549548
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 3 , time 191.70628961549548
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 191.85554613962094
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 3 , time 191.85554613962094
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 191.99953250197743
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 1 , time 191.99953250197743
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 192.57934675487783
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 1 , time 192.57934675487783
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 192.61079814980226
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 1 , time 192.61079814980226
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 192.63266096727375
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 192.63266096727375
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 192.8038761733011
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 3 , time 192.8038761733011
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 192.83121387073348
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 1 , time 192.83121387073348
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 192.90169772639365
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 1 , time 192.90169772639365
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 192.9799898233917
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 1 , time 192.9799898233917
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 193.1964832751085
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 2 , time 193.1964832751085
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 193.23916744696868
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 2 , time 193.23916744696868
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 193.53026096035185
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 2 , time 193.53026096035185
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 194.15864302814816
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 194.15864302814816
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 194.2162156151449
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 3 , time 194.2162156151449
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 194.46873464300134
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 3 , time 194.46873464300134
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 194.48315273464237
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 3 , time 194.48315273464237
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 194.99201630138256
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 3 , time 194.99201630138256
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 195.26873176054636
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 3 , time 195.26873176054636
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 195.32596953627618
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 195.32596953627618
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 195.42199661478443
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 3 , time 195.42199661478443
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 195.4315508257677
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 195.4315508257677
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 195.74526887895428
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 3 , time 195.74526887895428
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 195.7614621131151
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 195.7614621131151
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 195.77046302371073
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 3 , time 195.77046302371073
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 195.92366120617856
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 3 , time 195.92366120617856
# Fog:   Fog 2 mobile 2 , akhon queue te ase  4 , time 195.9397560700557
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 4 , time 195.9397560700557
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 196.32980382078867
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 4 , time 196.32980382078867
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 196.53431789448118
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 1 , time 196.53431789448118
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 196.5554766825435
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 196.5554766825435
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 196.5816869121057
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 3 , time 196.5816869121057
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 196.63516190793237
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 1 , time 196.63516190793237
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 196.84608720216562
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 2 , time 196.84608720216562
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 196.93380314708216
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 196.93380314708216
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 197.6821966844825
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 3 , time 197.6821966844825
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 197.7423955009861
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 1 , time 197.7423955009861
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 198.12747261903957
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 1 , time 198.12747261903957
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 198.13097447602243
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 1 , time 198.13097447602243
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 198.13421234421477
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 2 , time 198.13421234421477
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 198.3553483612484
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 2 , time 198.3553483612484
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 198.41726133784854
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 2 , time 198.41726133784854
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 198.47293290212014
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 1 , time 198.47293290212014
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 198.65803118486923
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 1 , time 198.65803118486923
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 198.82878266063227
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 1 , time 198.82878266063227
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 198.86566763802315
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 1 , time 198.86566763802315
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 198.96560564597314
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 4 , time 198.96560564597314
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 199.06784450115055
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 3 , time 199.06784450115055
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 199.49244248978349
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 2 , time 199.49244248978349
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 199.5010330107492
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 3 , time 199.5010330107492
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 200.21853669316576
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 200.21853669316576
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 200.49679880933795
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 3 , time 200.49679880933795
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 200.87623662503137
# nxtstate: Fog 1 mobile 1 , req er age queue te ase 3 , time 200.87623662503137
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 200.92082469439745
# nxtstate: Fog 1 mobile 2 , req er age queue te ase 1 , time 200.92082469439745
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 201.64055625844355
# nxtstate: Fog 2 mobile 1 , req er age queue te ase 2 , time 201.64055625844355
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 201.64647446314575
# nxtstate: Fog 2 mobile 2 , req er age queue te ase 2 , time 201.64647446314575
# 204 322
# 952 1048
# FOG-1 Average queueing time: 0.15386279812078457
# FOG-1 Average service time: 0.6191950767981428
# FOG-1 Average response time: 0.7730578749189269
# FOG-1 Average Energy consumption: 180.1106841504026
# FOG-2 Average queueing time: 0.12722544250323178
# FOG-2 Average service time: 0.5691089711120583
# FOG-2 Average response time: 0.6963344136152896
# FOG-2 Average Energy consumption: 160.1523093249461

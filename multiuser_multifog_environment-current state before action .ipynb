# %%
import numpy as np   #importing libraries
import simpy 
import queue
import random
import random as rd
import matplotlib 
from matplotlib import pyplot as plt

# %%
global SZ,CP,RM
SZ=[]
CP=[]
RM=[]
N=1000
k=10
Lambda = 2
mu = 1.25
#t = 0   #system clock
t1=0
t2=0
t_lambda = 0 #poisson random variable used to generate next service time
t_mu = 0  #poisson random variable used to generate next departure time
t_a=0
wait=0
R=1000
transmission_time=0
l="0"
P_transmission=500
P_idle=100
alpha = 0.1
gamma = 0.95
episodes = 10
SHOW_EVERY = 100
STATS_EVERY=100

action_list=()

# %%
class Packet(object):
    def __init__(self, time, id, mobileID, seeed):
        
        self.time=time                                                
        self.id=id
        self.mobileID=mobileID   
        self.size=random.randint(200,400) #seed 1 op 2, seed 2 op 
        SZ.append(round(self.size,2))
        #print(seeed)
        #random.seed(seeed)
        self.cpu=random.randint(20,90) #seed 1 op 2, seed 2 op 
        CP.append(round(self.cpu,2))
        #random.seed(seeed)
        self.ram=random.randint(1, 32) #seed 1 op 3, seed 2 op 1, seed 3 op 4
        RM.append(round(self.ram,2))

class mobile(object): #mobile class with an ID              
    def __init__(self, ID):
        self.ID=ID
        self.pot=int(1)
        
    #generates packets and sends via out_pipe
    def packet_generator_initial(self, numPackets, env, out_pipe, task_id,send): 
        
        yield env.timeout(send)
        #print("sending task {} of mobile {} at time {}".format(task_id, self.ID, env.now))
        p=Packet(env.now, task_id, self.ID, self.pot)
        self.pot+=1
        if(self.pot==4):
                self.pot=1
        yield out_pipe.put(p)
        
    def packet_generator(self, numPackets, env, out_pipe, task_id,send,pipe4,currentpipe): 
        
        yield env.timeout(send)
        #print("sending task {} of mobile {} at time {}".format(task_id, self.ID, env.now))
        p=Packet(env.now, task_id, self.ID, self.pot)
        self.pot+=1
        if(self.pot==4):
                self.pot=1
        yield out_pipe.put(p)
        
        state=yield pipe4.get()
        yield currentpipe.put(state)

# %%
 def reward_generator(T): 
    Tsla=2 
    Nsla=3
    Gsla=3  
    Cost_sla=50
    Cg=0
    Ct=0
    Cn=0
    Cost_n=0
    
    #if (G<Gsla):
        #Cg=-5*(Gsla/G)
    if (T>Tsla):
        Ct = -5 * (T/Tsla)
    #if (N>Nsla):
        #Cn=-5*(N/Nsla)
    #if (cost>Cost_sla):
        #Cost_n=-5*(cost/Cost_sla)
    
    Reward = (Tsla/T) + Ct #Reward Function
    return Reward

# %%
class Fog(object):      
    def __init__(self, ID):
        self.ID=ID
        self.Number_queue=1
        self.lost=0
        self.response_time=0
        self.server_count=0
        self.wait=0
        self.taskinqueue=0
        self.a=0
        self.time=0
        self.neighbour1=None
        
        self.service_time=[]
        self.response_time_list=[]
        self.Serverqueue=[]
        self.total_serverqueue=[]
        self.waitlist=[]
        self.energy_offloading=[]
        self.reward_list=[]
        self.state=[]
        self.observation_space_discretesize = [11, 11, 2]
        self.q_table = np.random.uniform(low=0, high=0, size=(self.observation_space_discretesize))
    
        
    def Neighbour(self,neighbour):
        self.neighbour1=neighbour
    

    def FOG(self, env, server, in_pipe,mobile,pipe3,pipe4,rewardpipe):
        
         msg = yield in_pipe.get()
            
         discrete_state_action=()
         discrete_state=()
         discrete_state_action=(self.taskinqueue,self.neighbour1.taskinqueue, self.ID)
         discrete_state=(self.taskinqueue,self.neighbour1.taskinqueue)
        
         yield pipe4.put(discrete_state)
            
         transmission_time = (msg.size/R)
         #print("transmits task {} to need time {}".format(msg.id,transmission_time,self.ID))
         yield env.timeout(transmission_time)
         a=env.now
         #print("Arrived task {} at time {} at FOG {} from mobile {}".format(msg.id,a,self.ID,mobile))
         #print("server",self.server_count)
         #print("present q",self.taskinqueue)

         if self.server_count==3:
            if len(self.Serverqueue)<k:
               self.Serverqueue.append(msg)
               self.taskinqueue=len(self.Serverqueue)
               #print("queue te ase ",len(self.Serverqueue))
               #print("task ase queue te ase ",taskinqueue)
               self.Number_queue = self.Number_queue + 1
               #self.server_count=0
            else:
                self.lost=self.lost+1 
                return  
         #discrete_state_action=()
         #discrete_state_action=(self.taskinqueue,self.neighbour1.taskinqueue, self.ID)
         #yield pipe4.put(discrete_state_action)
         #s=q+1  
         #q=s
         u=rd.random()
         t_mu=-np.log(u)/mu
         self.service_time.append(t_mu)
         #print("service time",t_mu)
         E = (P_transmission * transmission_time) + (P_idle * t_mu)
         self.energy_offloading.append(E)
         
         #print("present a queue te ase ",len(self.Serverqueue))
         #print("Fog:   Fog",self.ID,"mobile",mobile,", akhon queue te ase ",self.taskinqueue,", time",env.now)

         with server.request() as req:
             yield req
             s=env.now
             self.wait=s-a
             if len(self.Serverqueue)>0:
                 self.Serverqueue.pop(0)
             #self.total_serverqueue.append(len(self.Serverqueue))
             #print("queue",len(self.Serverqueue))
             #print("wait",self.wait)
             #print("Starting service task {} at time {} at FOG {}".format(msg.id,s,self.ID))
             #print("Waiting time of task {} at time {} at FOG {}".format(msg.id,self.wait,self.ID))
             self.waitlist.append(self.wait)
             self.response_time=self.wait+t_mu
             self.response_time_list.append(self.response_time)
             
             self.server_count=self.server_count+1
             yield env.timeout(t_mu)
             #print("Finish service task {} at time {} at FOG {}".format(msg.id,env.now,self.ID))
             self.server_count=self.server_count-1   
           
             r=reward_generator(self.response_time)
             self.reward_list.append(r)
             #print("r",r)
             yield rewardpipe.put(r)
                
             discrete_state2=()
             #print("next q",self.taskinqueue)
             #state.append([self.ID,mobile,self.taskinqueue,env.now,self.neighbour1.ID,self.neighbour1.taskinqueue])
             discrete_state2=(self.taskinqueue,self.neighbour1.taskinqueue)
             #yield pipe3.put(state)
             yield pipe3.put(discrete_state2)
             #print("Fog",self.ID,"pore queue te ase ",self.taskinqueue,"time hoitese",env.now)
    
    def nextstate(self,env,mobile,pipe3,pipe4,rewardpipe,action,statepipe):
        
        discrete_state_action=(0,0,0)
        #print("update q table",self.q_table)

        action=np.argmax(self.q_table[discrete_state_action[0],discrete_state_action[1]])
        action_list=(discrete_state_action[0],discrete_state_action[1],action)
        yield statepipe.put(discrete_state_action)
        #print("q valu",self.q_table[discrete_state_action[0],discrete_state_action[1]])
        #print("Q-LEARNING onujae action neya uchit",action_list)
        r=yield rewardpipe.get()
        next_state = yield pipe3.get()
        #print("next state,time",next_state,env.now)
        current_q = self.q_table[discrete_state_action]
        max_future_q = np.max(self.q_table[next_state])
        new_q = current_q + alpha * (r + gamma * max_future_q - current_q )
        self.q_table[discrete_state_action] = new_q

# %%
class Decision(object):
    def __init__(self, ID):
        self.ID=ID
        self.fog1_count=0
        self.fog2_count=0
        self.t1=0
        self.t2=0
        self.statetime=0
        self.current=()
    def decision(self,env1,server1,server2,pipe1,pipe2,pipe3,pipe4,rewardpipe,ms1,ms2,fog1,fog2,i,statepipe,currentpipe):
        yield env1.timeout(0)
        fog1.Neighbour(fog2)
        fog2.Neighbour(fog1)
        
        #for j in range(10):
        
        if(i==0):
                 self.fog1_count=self.fog1_count+1           
                 u=rd.random()
                 t_lambda=-np.log(u)/Lambda
                 t_a=self.t1+t_lambda
                 self.t1=t_a
                 env1.process(ms1.packet_generator_initial(1, env1, pipe1, 0,t_a))
                 env1.process(fog1.FOG(env1, server1, pipe1,ms1.ID,pipe3,pipe4,rewardpipe))
                 env1.process(fog1.nextstate(env1,ms1.ID,pipe3,pipe4,rewardpipe,0,statepipe))
                    
                
        for j in range(1):
            
            u=rd.random()
            t_lambda=-np.log(u)/Lambda
            t_a=self.t1+t_lambda
            self.t1=t_a
            env1.process(ms1.packet_generator(1, env1, pipe1, i,t_a,pipe4,currentpipe))
            
            u=rd.random()
            t_lambda=-np.log(u)/Lambda
            t_a=self.t2+t_lambda
            self.t2=t_a
            env1.process(ms2.packet_generator(1, env1, pipe2, i,t_a,pipe4,currentpipe))

            current2=yield currentpipe.get()
            print("time, current state, i: ",env1.now,current2,i)
            
            action=random.randint(0,1)
            #action = np.argmax(q_table[discrete_state]) 
            
            if(action==0):
                            
                            self.fog1_count=self.fog1_count+1
                            env1.process(fog1.FOG(env1, server1, pipe1,ms1.ID,pipe3,pipe4,rewardpipe))
                            env1.process(fog1.nextstate(env1,ms1.ID,pipe3,pipe4,rewardpipe,action,statepipe))

                            self.fog1_count=self.fog1_count+1
                            env1.process(fog1.FOG(env1, server1, pipe2,ms2.ID,pipe3,pipe4,rewardpipe))
                            env1.process(fog1.nextstate(env1,ms2.ID,pipe3,pipe4,rewardpipe,action,statepipe))
                            
            if(action==1):
                             self.fog2_count=self.fog2_count+1
                             env1.process(fog2.FOG(env1, server2, pipe1,ms1.ID,pipe3,pipe4,rewardpipe))
                             env1.process(fog2.nextstate(env1,ms1.ID,pipe3,pipe4,rewardpipe,action,statepipe))

                             self.fog2_count=self.fog2_count+1
                             env1.process(fog2.FOG(env1, server2, pipe2,ms2.ID,pipe3,pipe4,rewardpipe))
                             env1.process(fog2.nextstate(env1,ms2.ID,pipe3,pipe4,rewardpipe,action,statepipe))
 
            self.current=yield statepipe.get()
            #print("current state",env1.now,self.current,i)
   
            #env1.run()

# %%
env1 = simpy.Environment()    
server1 = simpy.Resource(env1, capacity=3)
server2 = simpy.Resource(env1, capacity=3)


pipe1 = simpy.Store(env1)
pipe2 = simpy.Store(env1)
pipe3 = simpy.Store(env1)
pipe4 = simpy.Store(env1)
rewardpipe = simpy.Store(env1)
statepipe = simpy.Store(env1)
currentpipe = simpy.Store(env1)

ms1=mobile(1)
ms2=mobile(2)
ms3=mobile(3)

fog1 = Fog(0)
fog2 = Fog(1)

obj=Decision(1)
for i in range(N):
    env1.process(obj.decision(env1,server1,server2,pipe1,pipe2,pipe3,pipe4,rewardpipe,ms1,ms2,fog1,fog2,i,statepipe,currentpipe))
env1.run()

#print("after simulation q_table",q_table)
#print("after simulation present state and action",action_list)

fog1_count=obj.fog1_count
fog2_count=obj.fog2_count
fog1_count=fog1_count-fog1.lost
fog2_count=fog2_count-fog2.lost
print("count",fog1_count,fog2_count)
avgwaittime=sum(fog1.waitlist)/fog1_count
print("FOG-1 Average queueing time:", avgwaittime)
avgservicetime=sum(fog1.service_time)/fog1_count
print("FOG-1 Average service time:", avgservicetime)
avgsystemtime=sum(fog1.response_time_list)/fog1_count
print("FOG-1 Average response time:", avgsystemtime)
avgenergy=sum(fog1.energy_offloading)/fog1_count
print("FOG-1 Average Energy consumption:", avgenergy)
#print("No    response_time       reward")
#i=0
#while (i<N):
#   print("{}     {}     {}".format(i+1,fog2.response_time_list[i],fog2.reward_list[i]))
#  i+=1
#print("FOG-2 MAXIMUM REAWARD:", max(fog2.reward_list))
#print("FOG-2 total number of task in queue",fog2.Number_queue)
avgwaittime=sum(fog2.waitlist)/fog2_count
print("FOG-2 Average queueing time:", avgwaittime)
avgservicetime=sum(fog2.service_time)/fog2_count
print("FOG-2 Average service time:", avgservicetime)
avgsystemtime=sum(fog2.response_time_list)/fog2_count
print("FOG-2 Average response time:", avgsystemtime)
avgenergy=sum(fog2.energy_offloading)/fog2_count
print("FOG-2 Average Energy consumption:", avgenergy)
# Out:
# time, current state, i:  0.9679056294910475 (0, 0) 0
# time, current state, i:  1.7518807428453305 (0, 0) 1
# time, current state, i:  2.0840515158812396 (0, 0) 2
# time, current state, i:  2.1092012343778976 (0, 0) 3
# time, current state, i:  2.1816183016996025 (0, 0) 4
# time, current state, i:  2.274638573053721 (0, 0) 5
# time, current state, i:  2.374365086372336 (0, 0) 6
# time, current state, i:  2.791562313289642 (0, 0) 7
# time, current state, i:  2.8722945890395524 (0, 0) 8
# time, current state, i:  3.1779409242295995 (0, 0) 9
# time, current state, i:  3.3576925367071344 (0, 0) 10
# time, current state, i:  3.508444556845266 (0, 1) 11
# time, current state, i:  3.7178783945497895 (1, 0) 12
# time, current state, i:  4.246511859230898 (0, 1) 13
# time, current state, i:  4.24909092047795 (1, 1) 14
# time, current state, i:  5.449004067980535 (1, 1) 15
# time, current state, i:  6.046577796681811 (1, 1) 16
# time, current state, i:  6.467934558553835 (1, 1) 17
# time, current state, i:  6.522087781048276 (1, 1) 18
# time, current state, i:  6.669637121203737 (1, 1) 19
# time, current state, i:  6.753391372181494 (1, 1) 20
# time, current state, i:  7.118057095964515 (1, 1) 21
# time, current state, i:  7.160604796432346 (1, 1) 22
# time, current state, i:  7.436726166153746 (1, 1) 23
# time, current state, i:  7.696848759594584 (1, 1) 24
# time, current state, i:  7.752027322466756 (1, 1) 25
# time, current state, i:  8.049763291752328 (1, 1) 26
# time, current state, i:  8.084795887982633 (1, 1) 27
# time, current state, i:  8.17224953759995 (1, 1) 28
# time, current state, i:  8.235200736294736 (1, 1) 29
# time, current state, i:  9.337672668168395 (1, 1) 30
# time, current state, i:  9.780996594095742 (1, 2) 31
# time, current state, i:  10.441937775306362 (2, 1) 32
# time, current state, i:  10.59618932659753 (2, 1) 33
# time, current state, i:  10.87652936920756 (1, 2) 34
# time, current state, i:  11.063398462996755 (2, 1) 35
# time, current state, i:  11.27886557432635 (2, 1) 36
# time, current state, i:  11.329318996176905 (1, 1) 37
# time, current state, i:  11.534774021746367 (1, 1) 38
# time, current state, i:  11.591114078833797 (1, 1) 39
# time, current state, i:  12.046148885543241 (1, 1) 40
# time, current state, i:  12.079109587862396 (1, 1) 41
# time, current state, i:  12.903801745950584 (1, 1) 42
# time, current state, i:  13.580871170926708 (1, 1) 43
# time, current state, i:  13.586320719258461 (1, 1) 44
# time, current state, i:  13.923328324280455 (1, 1) 45
# time, current state, i:  14.233438407579861 (1, 1) 46
# time, current state, i:  14.443839519954121 (1, 1) 47
# time, current state, i:  14.808717297040078 (1, 1) 48
# time, current state, i:  15.059876302274553 (1, 1) 49
# time, current state, i:  15.087911539521034 (1, 1) 50
# time, current state, i:  15.147556673525921 (1, 1) 51
# time, current state, i:  15.390783128331215 (1, 1) 52
# time, current state, i:  15.454909874321128 (1, 1) 53
# time, current state, i:  16.014628655759694 (1, 1) 54
# time, current state, i:  16.49407192135304 (1, 1) 55
# time, current state, i:  16.753757043058226 (1, 1) 56
# time, current state, i:  16.80949389718436 (1, 1) 57
# time, current state, i:  16.978832795801317 (1, 1) 58
# time, current state, i:  17.290580133387657 (1, 1) 59
# time, current state, i:  17.32772692190029 (1, 1) 60
# time, current state, i:  17.52717270102542 (1, 1) 61
# time, current state, i:  17.53961853938899 (1, 1) 62
# time, current state, i:  17.591936289460833 (1, 1) 63
# time, current state, i:  17.831776718668944 (1, 1) 64
# time, current state, i:  17.94736288839697 (1, 1) 65
# time, current state, i:  18.625211995359475 (2, 1) 66
# time, current state, i:  18.690095875533004 (1, 1) 67
# time, current state, i:  18.70423417837487 (1, 1) 68
# time, current state, i:  18.94949475785043 (1, 1) 69
# time, current state, i:  19.021402452145697 (1, 1) 70
# time, current state, i:  19.130756907125793 (1, 1) 71
# time, current state, i:  19.168893924721555 (1, 1) 72
# time, current state, i:  19.273874433595303 (1, 1) 73
# time, current state, i:  19.321514570921487 (1, 1) 74
# time, current state, i:  19.731873194515405 (1, 1) 75
# time, current state, i:  19.789481560615698 (1, 1) 76
# time, current state, i:  19.920848141748813 (1, 1) 77
# time, current state, i:  20.05602145068405 (1, 1) 78
# time, current state, i:  20.490669641903345 (1, 1) 79
# time, current state, i:  21.04010333435896 (2, 1) 80
# time, current state, i:  21.068496562721606 (2, 1) 81
# time, current state, i:  21.14619885967597 (1, 2) 82
# time, current state, i:  21.15521720711534 (1, 2) 83
# time, current state, i:  21.305827008503478 (1, 2) 84
# time, current state, i:  21.878496838027683 (1, 2) 85
# time, current state, i:  21.96765932613513 (2, 1) 86
# time, current state, i:  22.017780602044667 (1, 2) 87
# time, current state, i:  22.164844490596913 (1, 2) 88
# time, current state, i:  22.16855842149993 (2, 1) 89
# time, current state, i:  22.530737640874065 (1, 2) 90
# time, current state, i:  22.87315345706923 (3, 2) 91
# time, current state, i:  23.212497638433327 (2, 2) 92
# time, current state, i:  23.93156162973652 (2, 2) 93
# time, current state, i:  24.546819293757817 (1, 2) 94
# time, current state, i:  25.063010841489714 (2, 2) 95
# time, current state, i:  25.069521363715523 (2, 1) 96
# time, current state, i:  25.133395210983313 (1, 2) 97
# time, current state, i:  25.444695146177875 (2, 1) 98
# time, current state, i:  26.14154420423516 (2, 2) 99
# time, current state, i:  26.1907672429741 (2, 2) 100
# time, current state, i:  26.334463837962304 (2, 2) 101
# time, current state, i:  26.696627348055493 (2, 2) 102
# time, current state, i:  27.071040042806324 (2, 2) 103
# time, current state, i:  27.087181872399505 (2, 2) 104
# time, current state, i:  27.09840343352499 (2, 2) 105
# time, current state, i:  27.206414072471382 (2, 2) 106
# time, current state, i:  27.876758299551962 (2, 2) 107
# time, current state, i:  27.923666654493584 (2, 2) 108
# time, current state, i:  28.00533205017014 (2, 2) 109
# time, current state, i:  28.3395324666805 (2, 2) 110
# time, current state, i:  28.40053669227447 (2, 2) 111
# time, current state, i:  28.534432010273747 (2, 2) 112
# time, current state, i:  28.976578311705506 (2, 2) 113
# time, current state, i:  28.987589981164344 (2, 2) 114
# time, current state, i:  29.108072604807663 (2, 2) 115
# time, current state, i:  29.222799735515256 (2, 2) 116
# time, current state, i:  29.32153749730612 (2, 2) 117
# time, current state, i:  30.004968730494053 (2, 1) 118
# time, current state, i:  30.431075122816186 (2, 1) 119
# time, current state, i:  30.74876412297157 (1, 2) 120
# time, current state, i:  30.80553953179832 (1, 2) 121
# time, current state, i:  31.291010942410782 (2, 1) 122
# time, current state, i:  31.3255923216957 (2, 1) 123
# time, current state, i:  31.56292816860524 (2, 1) 124
# time, current state, i:  31.657257145090483 (2, 1) 125
# time, current state, i:  31.88271418516023 (1, 2) 126
# time, current state, i:  32.20534215194934 (1, 1) 127
# time, current state, i:  32.44505645194249 (1, 1) 128
# time, current state, i:  32.55034233945453 (1, 1) 129
# time, current state, i:  32.602707346102285 (1, 1) 130
# time, current state, i:  32.7064921146379 (1, 1) 131
# time, current state, i:  32.9681822629919 (1, 1) 132
# time, current state, i:  33.12096179638678 (1, 1) 133
# time, current state, i:  33.47880098996077 (1, 1) 134
# time, current state, i:  33.87360572720073 (1, 1) 135
# time, current state, i:  34.38055297529223 (1, 1) 136
# time, current state, i:  34.71943563378199 (1, 1) 137
# time, current state, i:  34.77172826767208 (1, 1) 138
# time, current state, i:  35.301569789250756 (1, 1) 139
# time, current state, i:  35.30895039062439 (1, 1) 140
# time, current state, i:  35.90274319792207 (1, 1) 141
# time, current state, i:  35.90301762041849 (1, 1) 142
# time, current state, i:  36.004242355870524 (1, 1) 143
# time, current state, i:  36.004296687527905 (1, 1) 144
# time, current state, i:  36.93571172672445 (1, 1) 145
# time, current state, i:  37.245456127050474 (1, 2) 146
# time, current state, i:  37.32743571418353 (1, 2) 147
# time, current state, i:  37.41901830657376 (1, 2) 148
# time, current state, i:  38.04014857395078 (2, 1) 149
# time, current state, i:  38.07752587907012 (2, 1) 150
# time, current state, i:  38.12053520097329 (2, 1) 151
# time, current state, i:  39.245761798040924 (1, 2) 152
# time, current state, i:  40.29598743095633 (1, 2) 153
# time, current state, i:  40.47136918898712 (2, 1) 154
# time, current state, i:  40.737069217353415 (2, 1) 155
# time, current state, i:  40.93122769814321 (1, 2) 156
# time, current state, i:  40.97111825077146 (2, 1) 157
# time, current state, i:  41.07092017378682 (1, 2) 158
# time, current state, i:  41.21041289108433 (2, 1) 159
# time, current state, i:  41.39146339889497 (2, 1) 160
# time, current state, i:  41.445885994543644 (2, 1) 161
# time, current state, i:  41.92960594819731 (1, 2) 162
# time, current state, i:  42.02446176678605 (2, 1) 163
# time, current state, i:  42.32247372698124 (1, 2) 164
# time, current state, i:  42.39497777339758 (1, 1) 165
# time, current state, i:  42.8546949025148 (1, 1) 166
# time, current state, i:  42.92930079357195 (2, 1) 167
# time, current state, i:  43.2897904336577 (1, 2) 168
# time, current state, i:  44.520041524854065 (1, 1) 169
# time, current state, i:  44.76560121206129 (1, 1) 170
# time, current state, i:  44.78269806281507 (1, 1) 171
# time, current state, i:  45.128622347671616 (1, 1) 172
# time, current state, i:  45.13158147251762 (1, 1) 173
# time, current state, i:  45.32198422422063 (1, 1) 174
# time, current state, i:  45.42902302127333 (1, 1) 175
# time, current state, i:  45.46430940129436 (1, 1) 176
# time, current state, i:  45.70840208820056 (1, 1) 177
# time, current state, i:  45.76296832193943 (1, 1) 178
# time, current state, i:  45.92239125632216 (1, 1) 179
# time, current state, i:  46.2200727727107 (1, 1) 180
# time, current state, i:  46.22075500033364 (1, 1) 181
# time, current state, i:  46.425777286846454 (1, 1) 182
# time, current state, i:  46.65435904195179 (2, 1) 183
# time, current state, i:  46.93959066795156 (1, 2) 184
# time, current state, i:  47.333051789906015 (1, 2) 185
# time, current state, i:  47.37042286663374 (1, 2) 186
# time, current state, i:  47.406482468024514 (1, 2) 187
# time, current state, i:  47.677948824860565 (1, 2) 188
# time, current state, i:  47.870933435797056 (2, 1) 189
# time, current state, i:  47.87868130925083 (1, 2) 190
# time, current state, i:  48.25773301615411 (2, 1) 191
# time, current state, i:  48.28486979512832 (2, 2) 192
# time, current state, i:  48.53723480441298 (2, 2) 193
# time, current state, i:  48.649745127720834 (2, 2) 194
# time, current state, i:  48.69524166771709 (2, 2) 195
# time, current state, i:  48.97527147659689 (2, 2) 196
# time, current state, i:  49.057335300951685 (2, 2) 197
# time, current state, i:  49.22333465503422 (2, 2) 198
# time, current state, i:  49.28667055369299 (2, 2) 199
# time, current state, i:  49.68271127615489 (2, 2) 200
# time, current state, i:  49.68633369151013 (2, 1) 201
# time, current state, i:  49.697502679604504 (1, 2) 202
# time, current state, i:  49.85180395490415 (2, 1) 203
# time, current state, i:  49.910674001124704 (1, 2) 204
# time, current state, i:  50.40353847082692 (2, 1) 205
# time, current state, i:  50.61839716127031 (2, 1) 206
# time, current state, i:  50.719624027585624 (1, 2) 207
# time, current state, i:  50.757683036523275 (2, 1) 208
# time, current state, i:  50.768028279352805 (1, 2) 209
# time, current state, i:  50.884275706315506 (2, 1) 210
# time, current state, i:  51.47927376336999 (1, 2) 211
# time, current state, i:  51.52962567165292 (3, 2) 212
# time, current state, i:  51.79172299399263 (2, 3) 213
# time, current state, i:  52.01310649386096 (1, 2) 214
# time, current state, i:  52.059673592605364 (2, 1) 215
# time, current state, i:  52.20611907291185 (2, 1) 216
# time, current state, i:  52.35910246060989 (2, 1) 217
# time, current state, i:  52.63976654004963 (1, 1) 218
# time, current state, i:  52.71175864297625 (1, 1) 219
# time, current state, i:  53.019649868180046 (1, 1) 220
# time, current state, i:  53.14590767128185 (1, 1) 221
# time, current state, i:  53.23389161581669 (1, 1) 222
# time, current state, i:  53.47991446288929 (1, 1) 223
# time, current state, i:  53.52952461874242 (1, 1) 224
# time, current state, i:  54.022566954553454 (1, 1) 225
# time, current state, i:  54.49071965257374 (1, 1) 226
# time, current state, i:  54.51304331789264 (1, 1) 227
# time, current state, i:  54.773316540787974 (1, 1) 228
# time, current state, i:  55.02260939508032 (1, 1) 229
# time, current state, i:  55.173996807059126 (1, 1) 230
# time, current state, i:  55.345103666473435 (1, 1) 231
# time, current state, i:  55.37179967964447 (1, 1) 232
# time, current state, i:  56.60061251100757 (1, 1) 233
# time, current state, i:  56.64274008312041 (1, 1) 234
# time, current state, i:  56.663648468503474 (1, 1) 235
# time, current state, i:  57.27011737514752 (1, 1) 236
# time, current state, i:  57.55879934322114 (1, 1) 237
# time, current state, i:  57.7109968266995 (1, 1) 238
# time, current state, i:  57.81703763217445 (1, 1) 239
# time, current state, i:  58.252786704592964 (1, 1) 240
# time, current state, i:  58.50989278022019 (1, 1) 241
# time, current state, i:  58.67832084089003 (1, 1) 242
# time, current state, i:  58.76131823484299 (1, 1) 243
# time, current state, i:  58.783511145108314 (1, 1) 244
# time, current state, i:  58.84421258639409 (1, 1) 245
# time, current state, i:  58.97560623112334 (1, 1) 246
# time, current state, i:  59.20637455826533 (1, 1) 247
# time, current state, i:  59.29893983683828 (1, 4) 248
# time, current state, i:  59.35946896506492 (5, 1) 249
# time, current state, i:  59.36424066190123 (5, 1) 250
# time, current state, i:  60.20232941659191 (5, 1) 251
# time, current state, i:  60.49529839927956 (7, 1) 252
# time, current state, i:  60.49744911953999 (1, 7) 253
# time, current state, i:  60.58288187772169 (7, 1) 254
# time, current state, i:  60.89471981097418 (1, 7) 255
# time, current state, i:  61.020125680868915 (5, 1) 256
# time, current state, i:  61.07021416917008 (5, 1) 257
# time, current state, i:  61.10105774877104 (5, 1) 258
# time, current state, i:  61.16592696556295 (1, 5) 259
# time, current state, i:  61.53296485313834 (1, 4) 260
# time, current state, i:  61.879813196799816 (6, 1) 261
# time, current state, i:  61.88949788189174 (3, 1) 262
# time, current state, i:  61.902354061230604 (3, 1) 263
# time, current state, i:  62.528293577807894 (3, 1) 264
# time, current state, i:  62.633193037770056 (4, 1) 265
# time, current state, i:  62.854211553718166 (1, 4) 266
# time, current state, i:  62.895165990595004 (1, 4) 267
# time, current state, i:  63.283235871582356 (1, 4) 268
# time, current state, i:  63.39328085076824 (1, 1) 269
# time, current state, i:  63.48447457434305 (1, 1) 270
# time, current state, i:  63.76978278188194 (1, 1) 271
# time, current state, i:  64.25777954984129 (1, 1) 272
# time, current state, i:  64.428293958056 (1, 1) 273
# time, current state, i:  64.73308183083131 (1, 1) 274
# time, current state, i:  64.79273220689251 (1, 1) 275
# time, current state, i:  64.90658686908193 (1, 1) 276
# time, current state, i:  65.25337313294582 (1, 1) 277
# time, current state, i:  65.28705914693477 (1, 1) 278
# time, current state, i:  65.78846905401598 (1, 1) 279
# time, current state, i:  66.03220272553718 (1, 1) 280
# time, current state, i:  66.1547191134169 (1, 1) 281
# time, current state, i:  66.45830240876742 (1, 1) 282
# time, current state, i:  66.57151132544952 (1, 1) 283
# time, current state, i:  66.61846361994992 (1, 1) 284
# time, current state, i:  66.96406455452558 (1, 1) 285
# time, current state, i:  67.46375415051513 (1, 1) 286
# time, current state, i:  67.54291957811654 (1, 1) 287
# time, current state, i:  67.65380178836259 (1, 1) 288
# time, current state, i:  68.00927206352868 (1, 1) 289
# time, current state, i:  68.15444955853164 (1, 1) 290
# time, current state, i:  68.18874487329664 (1, 1) 291
# time, current state, i:  68.49753273799877 (1, 1) 292
# time, current state, i:  68.62483625489321 (1, 1) 293
# time, current state, i:  68.74827307636224 (1, 1) 294
# time, current state, i:  69.33724171191852 (1, 1) 295
# time, current state, i:  70.38119360868924 (1, 1) 296
# time, current state, i:  70.70437732745569 (1, 1) 297
# time, current state, i:  70.71993385238744 (1, 1) 298
# time, current state, i:  70.81470988993907 (1, 1) 299
# time, current state, i:  70.8199035930537 (1, 1) 300
# time, current state, i:  71.01974223199124 (1, 1) 301
# time, current state, i:  71.14439853297547 (1, 1) 302
# time, current state, i:  71.19108773353457 (1, 1) 303
# time, current state, i:  71.74464195960653 (1, 1) 304
# time, current state, i:  71.78806388196635 (1, 1) 305
# time, current state, i:  71.84405398961383 (1, 1) 306
# time, current state, i:  72.00426216869712 (1, 1) 307
# time, current state, i:  72.0820143271563 (1, 1) 308
# time, current state, i:  72.14454852627176 (1, 1) 309
# time, current state, i:  72.3322348250268 (1, 1) 310
# time, current state, i:  72.35850212837806 (1, 1) 311
# time, current state, i:  72.40799124970506 (1, 1) 312
# time, current state, i:  72.55818249854354 (1, 1) 313
# time, current state, i:  72.65190076347918 (2, 1) 314
# time, current state, i:  73.2107874210552 (1, 3) 315
# time, current state, i:  73.33260968602818 (4, 1) 316
# time, current state, i:  73.5869296349781 (4, 1) 317
# time, current state, i:  73.96665435968121 (4, 1) 318
# time, current state, i:  74.0918105672054 (1, 6) 319
# time, current state, i:  74.11686560411388 (6, 1) 320
# time, current state, i:  74.22723759818466 (1, 6) 321
# time, current state, i:  74.48406134597508 (1, 6) 322
# time, current state, i:  74.53430692907672 (1, 2) 323
# time, current state, i:  74.6861971582337 (1, 2) 324
# time, current state, i:  74.76532985563053 (1, 2) 325
# time, current state, i:  76.00975250325783 (1, 2) 326
# time, current state, i:  76.42059821230224 (4, 2) 327
# time, current state, i:  76.48195550049735 (2, 4) 328
# time, current state, i:  76.52103016093426 (2, 4) 329
# time, current state, i:  76.73003738278292 (2, 4) 330
# time, current state, i:  77.64049113659689 (2, 4) 331
# time, current state, i:  77.72207801935902 (2, 4) 332
# time, current state, i:  77.81872437695644 (2, 4) 333
# time, current state, i:  77.96187868550115 (2, 4) 334
# time, current state, i:  77.98222574874649 (2, 4) 335
# time, current state, i:  78.00302609657348 (2, 4) 336
# time, current state, i:  78.1793328772846 (2, 4) 337
# time, current state, i:  78.31967563411983 (4, 1) 338
# time, current state, i:  78.65059069776188 (4, 1) 339
# time, current state, i:  78.65302499639873 (1, 4) 340
# time, current state, i:  78.75062676017744 (1, 4) 341
# time, current state, i:  78.9156309938901 (1, 4) 342
# time, current state, i:  79.23621519906594 (4, 1) 343
# time, current state, i:  79.66878328040151 (1, 4) 344
# time, current state, i:  79.74657293656273 (1, 4) 345
# time, current state, i:  79.82494629191308 (4, 1) 346
# time, current state, i:  80.2213198120675 (1, 4) 347
# time, current state, i:  80.27391449664796 (4, 1) 348
# time, current state, i:  80.34188014572527 (1, 4) 349
# time, current state, i:  80.66573827885553 (1, 4) 350
# time, current state, i:  80.66993770552666 (1, 4) 351
# time, current state, i:  81.15100353724944 (4, 1) 352
# time, current state, i:  81.31689065070962 (1, 4) 353
# time, current state, i:  81.35391052717867 (4, 1) 354
# time, current state, i:  81.53361747096059 (4, 1) 355
# time, current state, i:  82.08827233007324 (1, 4) 356
# time, current state, i:  82.40913400008863 (4, 1) 357
# time, current state, i:  82.43747524827273 (4, 1) 358
# time, current state, i:  82.6378041528726 (1, 4) 359
# time, current state, i:  82.9825391922767 (1, 1) 360
# time, current state, i:  83.01347214578968 (1, 1) 361
# time, current state, i:  83.82061955409306 (1, 1) 362
# time, current state, i:  83.83088867106122 (1, 1) 363
# time, current state, i:  84.13368462731084 (1, 1) 364
# time, current state, i:  84.18941889233727 (1, 1) 365
# time, current state, i:  84.52953663856493 (1, 1) 366
# time, current state, i:  85.04084108482945 (1, 1) 367
# time, current state, i:  85.1612200352181 (1, 1) 368
# time, current state, i:  85.78405633460446 (1, 1) 369
# time, current state, i:  85.80917897100146 (1, 1) 370
# time, current state, i:  86.10463452859375 (1, 1) 371
# time, current state, i:  86.14503087421333 (1, 1) 372
# time, current state, i:  86.16590983241993 (1, 1) 373
# time, current state, i:  86.24421607799822 (1, 1) 374
# time, current state, i:  86.7611307695131 (1, 1) 375
# time, current state, i:  87.02759631449003 (1, 1) 376
# time, current state, i:  87.06448950442507 (1, 1) 377
# time, current state, i:  87.12175775618616 (1, 1) 378
# time, current state, i:  87.46229029397092 (1, 1) 379
# time, current state, i:  87.57577888654846 (1, 1) 380
# time, current state, i:  88.39462433216761 (1, 1) 381
# time, current state, i:  88.41064330493295 (1, 1) 382
# time, current state, i:  88.55782789664894 (1, 1) 383
# time, current state, i:  88.56596101193671 (1, 1) 384
# time, current state, i:  88.69671612266687 (1, 1) 385
# time, current state, i:  88.87485961013823 (1, 1) 386
# time, current state, i:  89.41418032836614 (1, 1) 387
# time, current state, i:  89.6215972782853 (1, 1) 388
# time, current state, i:  90.39832883016449 (1, 1) 389
# time, current state, i:  90.65709216363501 (1, 1) 390
# time, current state, i:  90.71589106463257 (1, 1) 391
# time, current state, i:  90.75254476100251 (1, 1) 392
# time, current state, i:  90.9666357001149 (1, 1) 393
# time, current state, i:  91.21061042476813 (1, 1) 394
# time, current state, i:  91.42470495160518 (1, 1) 395
# time, current state, i:  91.42676537955131 (1, 1) 396
# time, current state, i:  91.57413836265026 (1, 1) 397
# time, current state, i:  91.9676192700743 (1, 1) 398
# time, current state, i:  92.98804403401755 (2, 1) 399
# time, current state, i:  93.15913544264342 (1, 2) 400
# time, current state, i:  93.2153452867782 (2, 1) 401
# time, current state, i:  93.31874612984524 (1, 2) 402
# time, current state, i:  93.36308385604501 (2, 1) 403
# time, current state, i:  93.48441626890833 (2, 1) 404
# time, current state, i:  93.58128199701272 (2, 1) 405
# time, current state, i:  94.17605164270006 (1, 2) 406
# time, current state, i:  94.28589717984137 (1, 2) 407
# time, current state, i:  94.5764206935159 (1, 2) 408
# time, current state, i:  94.73989641514896 (1, 2) 409
# time, current state, i:  94.92879296988734 (1, 2) 410
# time, current state, i:  94.94172993118399 (2, 1) 411
# time, current state, i:  95.01388289455909 (1, 2) 412
# time, current state, i:  95.35733451212002 (1, 2) 413
# time, current state, i:  96.17001517850369 (2, 3) 414
# time, current state, i:  96.78004936710036 (3, 2) 415
# time, current state, i:  96.80154913538357 (3, 2) 416
# time, current state, i:  97.04594077693677 (2, 3) 417
# time, current state, i:  97.2926371271587 (3, 2) 418
# time, current state, i:  97.3223908982466 (2, 3) 419
# time, current state, i:  97.59554472475348 (3, 2) 420
# time, current state, i:  98.14953233483645 (2, 3) 421
# time, current state, i:  98.5231004010017 (3, 2) 422
# time, current state, i:  98.58375382792389 (2, 3) 423
# time, current state, i:  98.67764782697387 (2, 3) 424
# time, current state, i:  99.04523098707602 (3, 2) 425
# time, current state, i:  99.09277235361905 (2, 3) 426
# time, current state, i:  99.11536325286964 (3, 2) 427
# time, current state, i:  99.20926114385011 (3, 2) 428
# time, current state, i:  99.25122461215643 (2, 3) 429
# time, current state, i:  99.54396417682567 (3, 2) 430
# time, current state, i:  99.57510234386882 (2, 3) 431
# time, current state, i:  99.93242855559457 (2, 3) 432
# time, current state, i:  100.07419493009071 (1, 3) 433
# time, current state, i:  100.1819950085732 (1, 3) 434
# time, current state, i:  100.55285796583975 (1, 3) 435
# time, current state, i:  100.88172884194228 (3, 1) 436
# time, current state, i:  100.97375574998789 (1, 3) 437
# time, current state, i:  101.17904718709904 (1, 3) 438
# time, current state, i:  101.18724194768807 (1, 3) 439
# time, current state, i:  101.28025999394953 (3, 1) 440
# time, current state, i:  101.42503330562845 (3, 1) 441
# time, current state, i:  101.44548321395854 (3, 1) 442
# time, current state, i:  101.59682270012878 (1, 3) 443
# time, current state, i:  101.64933902799082 (3, 1) 444
# time, current state, i:  101.71359769589729 (3, 1) 445
# time, current state, i:  102.00675157474184 (1, 1) 446
# time, current state, i:  102.48943635779804 (1, 2) 447
# time, current state, i:  102.57990125121522 (2, 1) 448
# time, current state, i:  103.08717237063058 (2, 1) 449
# time, current state, i:  103.308485802783 (3, 1) 450
# time, current state, i:  103.31152852984151 (3, 1) 451
# time, current state, i:  103.4999839873704 (1, 3) 452
# time, current state, i:  103.50277908514617 (1, 3) 453
# time, current state, i:  103.59983958424324 (3, 1) 454
# time, current state, i:  104.00819315812083 (1, 4) 455
# time, current state, i:  104.06220599219135 (1, 4) 456
# time, current state, i:  105.20660802678357 (1, 4) 457
# time, current state, i:  105.24429611536404 (1, 4) 458
# time, current state, i:  105.42836167659812 (4, 1) 459
# time, current state, i:  105.51355219115264 (4, 1) 460
# time, current state, i:  105.74058805039361 (4, 1) 461
# time, current state, i:  105.99842445744258 (1, 1) 462
# time, current state, i:  106.0078649886636 (1, 1) 463
# time, current state, i:  106.16297921180387 (1, 1) 464
# time, current state, i:  106.18723287656057 (1, 1) 465
# time, current state, i:  106.23846655526867 (1, 1) 466
# time, current state, i:  107.06258762567619 (1, 1) 467
# time, current state, i:  107.13298838816755 (1, 2) 468
# time, current state, i:  107.53685513618328 (2, 1) 469
# time, current state, i:  108.04079712417023 (2, 1) 470
# time, current state, i:  108.09208834148222 (1, 2) 471
# time, current state, i:  108.13952132739884 (1, 2) 472
# time, current state, i:  108.18443628260704 (2, 1) 473
# time, current state, i:  108.2059442150432 (2, 1) 474
# time, current state, i:  108.39812273499155 (2, 1) 475
# time, current state, i:  108.51426040121795 (2, 1) 476
# time, current state, i:  109.01145714437082 (1, 1) 477
# time, current state, i:  109.12049328256442 (1, 2) 478
# time, current state, i:  110.03486896793808 (1, 2) 479
# time, current state, i:  110.22558366220643 (1, 2) 480
# time, current state, i:  110.80384900474067 (1, 2) 481
# time, current state, i:  110.96332398680268 (1, 2) 482
# time, current state, i:  110.98456806205016 (2, 1) 483
# time, current state, i:  111.11356024844095 (2, 1) 484
# time, current state, i:  111.42515335264358 (2, 1) 485
# time, current state, i:  111.57185262934489 (2, 1) 486
# time, current state, i:  111.62216413158964 (1, 2) 487
# time, current state, i:  111.79782178124914 (2, 1) 488
# time, current state, i:  111.84425326095676 (1, 1) 489
# time, current state, i:  112.47844541365038 (1, 1) 490
# time, current state, i:  112.89977374170593 (1, 1) 491
# time, current state, i:  113.04844456203635 (1, 1) 492
# time, current state, i:  113.28244344017054 (1, 1) 493
# time, current state, i:  113.56075788666236 (1, 1) 494
# time, current state, i:  113.80184792576502 (1, 1) 495
# time, current state, i:  113.83535196952559 (1, 1) 496
# time, current state, i:  113.89046565502643 (1, 1) 497
# time, current state, i:  114.00340687552625 (1, 1) 498
# time, current state, i:  114.96150615166111 (1, 1) 499
# time, current state, i:  115.12105234807031 (1, 1) 500
# time, current state, i:  115.28729750557129 (1, 1) 501
# time, current state, i:  115.66541583153729 (1, 1) 502
# time, current state, i:  115.66863390158643 (1, 1) 503
# time, current state, i:  116.16743438846989 (1, 1) 504
# time, current state, i:  116.71794044168188 (1, 1) 505
# time, current state, i:  116.77358630201162 (1, 1) 506
# time, current state, i:  117.33283678408607 (1, 1) 507
# time, current state, i:  117.8073512833224 (1, 1) 508
# time, current state, i:  118.06119656104106 (1, 1) 509
# time, current state, i:  118.33683853925464 (1, 1) 510
# time, current state, i:  118.62781586022629 (1, 1) 511
# time, current state, i:  119.15908512384856 (1, 1) 512
# time, current state, i:  119.27643621938269 (1, 1) 513
# time, current state, i:  119.6162839298705 (1, 1) 514
# time, current state, i:  119.70588074680104 (1, 1) 515
# time, current state, i:  120.04782484221658 (1, 1) 516
# time, current state, i:  120.15042287292968 (1, 1) 517
# time, current state, i:  120.36433057327223 (1, 1) 518
# time, current state, i:  120.4266703457254 (1, 1) 519
# time, current state, i:  120.87289285965814 (1, 1) 520
# time, current state, i:  121.14825969658693 (1, 1) 521
# time, current state, i:  121.38949693003191 (1, 1) 522
# time, current state, i:  121.58723499386019 (1, 1) 523
# time, current state, i:  121.7044625221556 (1, 1) 524
# time, current state, i:  121.95512728317739 (1, 1) 525
# time, current state, i:  122.11576929372814 (1, 1) 526
# time, current state, i:  122.30305175135315 (1, 1) 527
# time, current state, i:  123.00185215199348 (1, 1) 528
# time, current state, i:  123.97047407952704 (1, 1) 529
# time, current state, i:  124.11232929897943 (1, 1) 530
# time, current state, i:  124.5261661527922 (1, 1) 531
# time, current state, i:  124.61628126120713 (1, 1) 532
# time, current state, i:  124.62067666649101 (1, 1) 533
# time, current state, i:  124.96997849891846 (1, 1) 534
# time, current state, i:  125.40696071388089 (1, 1) 535
# time, current state, i:  125.79804890284758 (1, 1) 536
# time, current state, i:  125.92808770180936 (1, 1) 537
# time, current state, i:  126.23110212559092 (1, 1) 538
# time, current state, i:  126.37156380586113 (1, 1) 539
# time, current state, i:  126.37366384557681 (1, 1) 540
# time, current state, i:  126.67495105889141 (1, 1) 541
# time, current state, i:  126.89819229828183 (1, 1) 542
# time, current state, i:  127.28451192678268 (1, 1) 543
# time, current state, i:  127.29242302031051 (1, 1) 544
# time, current state, i:  127.75941911850252 (1, 1) 545
# time, current state, i:  127.7690620652666 (1, 1) 546
# time, current state, i:  127.85153103866479 (1, 1) 547
# time, current state, i:  128.12089646173985 (1, 1) 548
# time, current state, i:  128.43868175129603 (1, 1) 549
# time, current state, i:  129.1380008508485 (1, 1) 550
# time, current state, i:  129.24505111589946 (1, 1) 551
# time, current state, i:  130.1358774434604 (1, 1) 552
# time, current state, i:  130.20716922699302 (1, 1) 553
# time, current state, i:  130.5276268603002 (1, 1) 554
# time, current state, i:  130.67071153737956 (1, 1) 555
# time, current state, i:  130.98064739790289 (1, 1) 556
# time, current state, i:  131.0936723604601 (1, 1) 557
# time, current state, i:  131.17972859774338 (1, 1) 558
# time, current state, i:  131.28558558328098 (1, 1) 559
# time, current state, i:  131.319384730948 (1, 1) 560
# time, current state, i:  132.10993930849617 (1, 1) 561
# time, current state, i:  132.22851348212885 (1, 2) 562
# time, current state, i:  132.2803272191089 (2, 1) 563
# time, current state, i:  132.69517933231052 (1, 2) 564
# time, current state, i:  132.72298853669426 (1, 2) 565
# time, current state, i:  133.36061748495828 (2, 1) 566
# time, current state, i:  133.57341767518156 (1, 2) 567
# time, current state, i:  134.5945082778032 (2, 1) 568
# time, current state, i:  135.0645896443951 (1, 2) 569
# time, current state, i:  135.09079315809095 (1, 2) 570
# time, current state, i:  135.54398659931198 (1, 2) 571
# time, current state, i:  136.00426619255668 (1, 2) 572
# time, current state, i:  136.17547203661755 (1, 2) 573
# time, current state, i:  136.41830318651586 (2, 1) 574
# time, current state, i:  136.4477802694426 (2, 1) 575
# time, current state, i:  136.9134450882868 (1, 2) 576
# time, current state, i:  137.04577817389955 (1, 2) 577
# time, current state, i:  137.46707751668882 (2, 1) 578
# time, current state, i:  137.65706725683734 (1, 2) 579
# time, current state, i:  137.8090290823783 (2, 1) 580
# time, current state, i:  138.33616022622888 (2, 1) 581
# time, current state, i:  138.3776037035652 (1, 2) 582
# time, current state, i:  138.39108825650757 (2, 1) 583
# time, current state, i:  138.63640130323859 (2, 1) 584
# time, current state, i:  138.6475153581452 (2, 1) 585
# time, current state, i:  138.71589590802813 (2, 1) 586
# time, current state, i:  138.97491172986122 (2, 1) 587
# time, current state, i:  139.27861270321313 (1, 2) 588
# time, current state, i:  139.38617468722578 (1, 2) 589
# time, current state, i:  139.83309188545564 (1, 2) 590
# time, current state, i:  139.93473047370273 (1, 2) 591
# time, current state, i:  140.5248422454146 (1, 2) 592
# time, current state, i:  140.52952514468157 (2, 1) 593
# time, current state, i:  140.53966736441396 (2, 1) 594
# time, current state, i:  140.7686905037886 (1, 2) 595
# time, current state, i:  141.31984025377434 (2, 1) 596
# time, current state, i:  141.34775957136372 (2, 1) 597
# time, current state, i:  141.35492978133075 (1, 2) 598
# time, current state, i:  141.43350209832835 (1, 2) 599
# time, current state, i:  141.58909574634237 (2, 1) 600
# time, current state, i:  141.80219700164093 (1, 2) 601
# time, current state, i:  141.84940298555827 (2, 1) 602
# time, current state, i:  142.26336618797188 (1, 1) 603
# time, current state, i:  142.5864956997813 (1, 1) 604
# time, current state, i:  142.65102903417298 (1, 1) 605
# time, current state, i:  143.02137672448495 (1, 1) 606
# time, current state, i:  143.05273255691702 (1, 1) 607
# time, current state, i:  143.31289184519105 (1, 1) 608
# time, current state, i:  143.44706789924743 (1, 1) 609
# time, current state, i:  143.49032968080286 (2, 1) 610
# time, current state, i:  143.89804989488778 (2, 1) 611
# time, current state, i:  143.939679177294 (1, 4) 612
# time, current state, i:  144.23854684910853 (1, 4) 613
# time, current state, i:  144.25879842138085 (1, 4) 614
# time, current state, i:  144.3276746267183 (4, 1) 615
# time, current state, i:  144.36374055589658 (4, 1) 616
# time, current state, i:  144.49151120232804 (4, 1) 617
# time, current state, i:  144.53426489762325 (1, 4) 618
# time, current state, i:  144.86817997815902 (3, 1) 619
# time, current state, i:  144.88576891975816 (4, 1) 620
# time, current state, i:  145.36621938145313 (4, 1) 621
# time, current state, i:  145.54038979528215 (1, 6) 622
# time, current state, i:  145.73099930303857 (1, 6) 623
# time, current state, i:  146.03023421703116 (1, 6) 624
# time, current state, i:  146.2591424818455 (6, 1) 625
# time, current state, i:  146.41087418542827 (1, 6) 626
# time, current state, i:  146.44044792122855 (4, 1) 627
# time, current state, i:  146.50806676953755 (1, 4) 628
# time, current state, i:  146.61475348900788 (1, 4) 629
# time, current state, i:  146.79221238263827 (4, 1) 630
# time, current state, i:  147.49217171393494 (4, 1) 631
# time, current state, i:  147.86315273514919 (1, 2) 632
# time, current state, i:  148.1266717149862 (2, 1) 633
# time, current state, i:  148.5041941269806 (2, 1) 634
# time, current state, i:  149.1617669609529 (2, 1) 635
# time, current state, i:  149.2956738310744 (1, 2) 636
# time, current state, i:  149.3062094173101 (2, 1) 637
# time, current state, i:  149.3504738364029 (1, 2) 638
# time, current state, i:  149.35226383091108 (1, 2) 639
# time, current state, i:  149.60942593784998 (1, 2) 640
# time, current state, i:  149.70128906074243 (2, 1) 641
# time, current state, i:  149.70545447743876 (1, 2) 642
# time, current state, i:  149.70853033381212 (2, 1) 643
# time, current state, i:  150.14199497682466 (1, 2) 644
# time, current state, i:  150.171796736404 (1, 1) 645
# time, current state, i:  150.61476811729642 (1, 1) 646
# time, current state, i:  151.07001317185328 (2, 1) 647
# time, current state, i:  151.2336370807951 (1, 1) 648
# time, current state, i:  151.24175483100842 (1, 1) 649
# time, current state, i:  151.27408221268755 (1, 1) 650
# time, current state, i:  151.6380842408392 (1, 1) 651
# time, current state, i:  151.65794746452005 (1, 1) 652
# time, current state, i:  152.19612988430094 (1, 1) 653
# time, current state, i:  152.75422030971245 (1, 1) 654
# time, current state, i:  153.25904544161608 (1, 1) 655
# time, current state, i:  153.29952286185065 (1, 1) 656
# time, current state, i:  153.42977226936048 (1, 1) 657
# time, current state, i:  153.4983854935484 (1, 1) 658
# time, current state, i:  153.85059748733622 (1, 1) 659
# time, current state, i:  153.99929854200047 (1, 1) 660
# time, current state, i:  154.153305306199 (1, 1) 661
# time, current state, i:  154.62831951353493 (1, 1) 662
# time, current state, i:  154.7666755920712 (1, 1) 663
# time, current state, i:  154.8643683889604 (1, 1) 664
# time, current state, i:  155.0272479603707 (1, 1) 665
# time, current state, i:  155.04100742910023 (1, 1) 666
# time, current state, i:  155.3092775458725 (1, 1) 667
# time, current state, i:  155.42099732456126 (1, 1) 668
# time, current state, i:  155.58782952366028 (1, 1) 669
# time, current state, i:  155.6681142630219 (1, 1) 670
# time, current state, i:  156.30561027137756 (1, 1) 671
# time, current state, i:  156.9973650273806 (1, 1) 672
# time, current state, i:  157.11340995230182 (1, 1) 673
# time, current state, i:  157.31666194464682 (1, 1) 674
# time, current state, i:  157.4533216080821 (1, 1) 675
# time, current state, i:  157.80542780061649 (1, 1) 676
# time, current state, i:  157.95011755002494 (1, 1) 677
# time, current state, i:  158.2669465330768 (1, 1) 678
# time, current state, i:  158.78689411636677 (1, 1) 679
# time, current state, i:  159.26447875350547 (1, 1) 680
# time, current state, i:  159.2707450677172 (1, 1) 681
# time, current state, i:  159.81650947894516 (1, 1) 682
# time, current state, i:  159.9798079317791 (1, 1) 683
# time, current state, i:  160.02562842022854 (1, 1) 684
# time, current state, i:  160.20637319974313 (1, 1) 685
# time, current state, i:  160.71878708622617 (1, 1) 686
# time, current state, i:  160.98249594899744 (1, 1) 687
# time, current state, i:  161.7006827108549 (1, 1) 688
# time, current state, i:  161.87952687869725 (1, 2) 689
# time, current state, i:  162.17132594796416 (1, 2) 690
# time, current state, i:  162.65132043111896 (2, 1) 691
# time, current state, i:  162.6530865652835 (2, 1) 692
# time, current state, i:  162.77849244042295 (2, 1) 693
# time, current state, i:  162.9546118453258 (2, 1) 694
# time, current state, i:  162.97858054053071 (2, 1) 695
# time, current state, i:  163.4642503136054 (1, 2) 696
# time, current state, i:  164.0811455044871 (1, 1) 697
# time, current state, i:  164.35125032656924 (2, 1) 698
# time, current state, i:  165.32320826607486 (1, 2) 699
# time, current state, i:  165.33306528107136 (1, 2) 700
# time, current state, i:  165.80333367959733 (2, 1) 701
# time, current state, i:  166.03776562826226 (1, 1) 702
# time, current state, i:  166.1628784074265 (1, 1) 703
# time, current state, i:  166.41538279395178 (1, 1) 704
# time, current state, i:  167.03154108719838 (1, 1) 705
# time, current state, i:  167.05832645640092 (1, 1) 706
# time, current state, i:  167.42424376569062 (1, 1) 707
# time, current state, i:  167.66683607129545 (1, 1) 708
# time, current state, i:  167.95892651867632 (1, 1) 709
# time, current state, i:  167.97686457482993 (1, 1) 710
# time, current state, i:  168.05698965389678 (1, 1) 711
# time, current state, i:  168.13765494082497 (1, 1) 712
# time, current state, i:  168.2823099446417 (1, 1) 713
# time, current state, i:  168.28359072059675 (1, 1) 714
# time, current state, i:  168.3259204537608 (1, 1) 715
# time, current state, i:  168.84973764893903 (1, 1) 716
# time, current state, i:  168.92822663058183 (1, 2) 717
# time, current state, i:  169.57341919209762 (1, 2) 718
# time, current state, i:  169.65663145683445 (1, 2) 719
# time, current state, i:  169.66231538214694 (1, 2) 720
# time, current state, i:  169.69318929215194 (1, 2) 721
# time, current state, i:  170.04985055164926 (1, 2) 722
# time, current state, i:  170.1864291461843 (1, 2) 723
# time, current state, i:  170.3240789419827 (1, 2) 724
# time, current state, i:  170.7783481007112 (1, 2) 725
# time, current state, i:  170.78266572701102 (2, 2) 726
# time, current state, i:  171.01981465658753 (2, 2) 727
# time, current state, i:  171.90548797943222 (2, 1) 728
# time, current state, i:  172.1646941873408 (1, 2) 729
# time, current state, i:  172.27663270662305 (1, 2) 730
# time, current state, i:  172.3965973520246 (2, 1) 731
# time, current state, i:  173.20732673711944 (1, 2) 732
# time, current state, i:  173.29506451041436 (1, 2) 733
# time, current state, i:  173.40570583233716 (1, 2) 734
# time, current state, i:  173.4161823609588 (1, 2) 735
# time, current state, i:  173.610022330106 (1, 2) 736
# time, current state, i:  173.7548827361129 (2, 2) 737
# time, current state, i:  174.12373085857712 (2, 4) 738
# time, current state, i:  174.71449371413053 (4, 2) 739
# time, current state, i:  174.78516000410988 (2, 3) 740
# time, current state, i:  175.2097881482635 (2, 3) 741
# time, current state, i:  175.48928103937894 (2, 3) 742
# time, current state, i:  175.51214577609554 (2, 3) 743
# time, current state, i:  176.36930462941064 (2, 3) 744
# time, current state, i:  176.53486728745955 (1, 3) 745
# time, current state, i:  176.65967095062246 (3, 1) 746
# time, current state, i:  177.46474072308737 (3, 1) 747
# time, current state, i:  177.6462257645181 (3, 1) 748
# time, current state, i:  177.71341137077232 (1, 3) 749
# time, current state, i:  177.74964787679036 (1, 3) 750
# time, current state, i:  177.84093605368523 (1, 3) 751
# time, current state, i:  177.95227851482846 (3, 1) 752
# time, current state, i:  177.97191803840977 (3, 1) 753
# time, current state, i:  178.08064287375842 (1, 3) 754
# time, current state, i:  178.49538166467286 (3, 1) 755
# time, current state, i:  178.61708991067172 (1, 1) 756
# time, current state, i:  178.64221436127553 (1, 1) 757
# time, current state, i:  179.22396282758385 (1, 1) 758
# time, current state, i:  179.61481619303348 (1, 1) 759
# time, current state, i:  180.15233398046317 (1, 1) 760
# time, current state, i:  180.2243622974252 (1, 1) 761
# time, current state, i:  180.47488205346406 (1, 1) 762
# time, current state, i:  180.84416647811972 (1, 1) 763
# time, current state, i:  181.22644924800335 (1, 1) 764
# time, current state, i:  181.7540990797072 (1, 1) 765
# time, current state, i:  182.05484258834528 (1, 1) 766
# time, current state, i:  182.2409382456515 (1, 1) 767
# time, current state, i:  182.29349468274154 (1, 1) 768
# time, current state, i:  182.47448667406488 (1, 1) 769
# time, current state, i:  182.57921725347717 (1, 1) 770
# time, current state, i:  182.698514569769 (1, 1) 771
# time, current state, i:  182.8625814900555 (1, 1) 772
# time, current state, i:  183.49072104827346 (1, 1) 773
# time, current state, i:  183.53993522254314 (1, 1) 774
# time, current state, i:  183.90622832512875 (1, 1) 775
# time, current state, i:  184.18685995941433 (1, 1) 776
# time, current state, i:  184.4656893105766 (1, 1) 777
# time, current state, i:  184.53281613034977 (1, 1) 778
# time, current state, i:  184.6159987980539 (1, 1) 779
# time, current state, i:  184.77606483532105 (1, 1) 780
# time, current state, i:  185.18806967573062 (1, 1) 781
# time, current state, i:  185.22899136471503 (1, 1) 782
# time, current state, i:  185.36725333735814 (1, 1) 783
# time, current state, i:  186.1748183634636 (1, 1) 784
# time, current state, i:  186.25675252323268 (1, 1) 785
# time, current state, i:  186.64449390086483 (1, 1) 786
# time, current state, i:  186.81719812431913 (1, 1) 787
# time, current state, i:  187.93026427817483 (1, 1) 788
# time, current state, i:  187.94118658536638 (1, 1) 789
# time, current state, i:  188.13079114981855 (1, 1) 790
# time, current state, i:  188.16639749914685 (1, 1) 791
# time, current state, i:  188.22435853549607 (1, 1) 792
# time, current state, i:  188.261151548464 (1, 1) 793
# time, current state, i:  188.38667350873865 (1, 1) 794
# time, current state, i:  188.53357339849555 (1, 1) 795
# time, current state, i:  188.7520316570407 (1, 1) 796
# time, current state, i:  189.41717328446688 (1, 2) 797
# time, current state, i:  189.65557134483376 (1, 3) 798
# time, current state, i:  189.7356450614407 (3, 1) 799
# time, current state, i:  189.75764569853786 (1, 3) 800
# time, current state, i:  189.86504343134365 (1, 3) 801
# time, current state, i:  190.4936053112802 (3, 1) 802
# time, current state, i:  190.8602341104398 (3, 1) 803
# time, current state, i:  191.77803752315342 (1, 3) 804
# time, current state, i:  192.2667264366262 (1, 3) 805
# time, current state, i:  192.60673201029692 (3, 1) 806
# time, current state, i:  192.68373802061217 (1, 3) 807
# time, current state, i:  192.75595989547392 (1, 3) 808
# time, current state, i:  192.79160046095527 (1, 3) 809
# time, current state, i:  193.21289334112208 (1, 3) 810
# time, current state, i:  193.24356561086194 (2, 3) 811
# time, current state, i:  193.79381940774346 (2, 3) 812
# time, current state, i:  193.98118456902932 (1, 3) 813
# time, current state, i:  194.1398970871888 (3, 1) 814
# time, current state, i:  194.17618686725902 (1, 3) 815
# time, current state, i:  194.3885821956212 (3, 1) 816
# time, current state, i:  194.72828650111978 (3, 1) 817
# time, current state, i:  194.86469293942477 (1, 3) 818
# time, current state, i:  195.04910581784884 (3, 1) 819
# time, current state, i:  195.16662671997395 (3, 1) 820
# time, current state, i:  195.3370945002352 (3, 1) 821
# time, current state, i:  195.3730353509944 (1, 1) 822
# time, current state, i:  195.5557595480776 (1, 1) 823
# time, current state, i:  196.3977084794078 (1, 2) 824
# time, current state, i:  196.5091254029256 (3, 1) 825
# time, current state, i:  196.66590779012284 (3, 1) 826
# time, current state, i:  196.99151951147834 (1, 3) 827
# time, current state, i:  197.4672383035402 (3, 1) 828
# time, current state, i:  197.78283586788936 (1, 3) 829
# time, current state, i:  197.90719578402877 (1, 3) 830
# time, current state, i:  198.00502691104734 (1, 3) 831
# time, current state, i:  198.07982686272538 (1, 3) 832
# time, current state, i:  198.14478953103742 (1, 3) 833
# time, current state, i:  199.24706981269972 (3, 1) 834
# time, current state, i:  199.36940674593967 (3, 1) 835
# time, current state, i:  199.50161954088105 (3, 1) 836
# time, current state, i:  200.2084730247373 (3, 1) 837
# time, current state, i:  201.08803066686866 (3, 1) 838
# time, current state, i:  201.78645280749456 (3, 1) 839
# time, current state, i:  202.05188503545102 (3, 1) 840
# time, current state, i:  202.15137089201045 (3, 1) 841
# time, current state, i:  202.36698004439924 (1, 3) 842
# time, current state, i:  202.47176410651642 (1, 3) 843
# time, current state, i:  202.47281718471035 (3, 1) 844
# time, current state, i:  202.49966031114846 (1, 3) 845
# time, current state, i:  202.58328342099702 (1, 3) 846
# time, current state, i:  202.67812327137725 (1, 3) 847
# time, current state, i:  202.70520671915634 (3, 1) 848
# time, current state, i:  202.70887166739126 (1, 3) 849
# time, current state, i:  202.87348419968546 (1, 3) 850
# time, current state, i:  202.92945620372782 (1, 3) 851
# time, current state, i:  203.37245036515776 (3, 1) 852
# time, current state, i:  203.62785537040577 (3, 4) 853
# time, current state, i:  203.65736098558253 (3, 4) 854
# time, current state, i:  203.92499195444867 (3, 4) 855
# time, current state, i:  204.44787074698996 (3, 4) 856
# time, current state, i:  204.45134598314732 (1, 4) 857
# time, current state, i:  204.51064441418245 (1, 4) 858
# time, current state, i:  204.629351048038 (1, 4) 859
# time, current state, i:  204.77151290299508 (4, 1) 860
# time, current state, i:  205.10463228698103 (2, 4) 861
# time, current state, i:  205.33299825855795 (1, 4) 862
# time, current state, i:  205.67936046270674 (2, 4) 863
# time, current state, i:  205.92238586074043 (1, 4) 864
# time, current state, i:  205.98409927315092 (1, 4) 865
# time, current state, i:  206.0986403635977 (4, 2) 866
# time, current state, i:  206.43126198808804 (2, 4) 867
# time, current state, i:  206.79430341493463 (1, 3) 868
# time, current state, i:  207.0555119411735 (1, 3) 869
# time, current state, i:  207.07044322257494 (1, 3) 870
# time, current state, i:  207.6091389937872 (3, 1) 871
# time, current state, i:  207.78642927368654 (1, 3) 872
# time, current state, i:  208.6449295822933 (3, 1) 873
# time, current state, i:  208.94353942828906 (1, 3) 874
# time, current state, i:  209.2243922210089 (1, 3) 875
# time, current state, i:  209.46698120267774 (3, 1) 876
# time, current state, i:  209.87467463651095 (3, 1) 877
# time, current state, i:  210.14208929643462 (3, 1) 878
# time, current state, i:  210.29078894186253 (1, 3) 879
# time, current state, i:  211.05242577136903 (1, 3) 880
# time, current state, i:  211.1388307962132 (3, 1) 881
# time, current state, i:  211.5845524566059 (3, 1) 882
# time, current state, i:  211.88396789977773 (3, 1) 883
# time, current state, i:  211.902778901101 (3, 1) 884
# time, current state, i:  211.90502532171854 (1, 3) 885
# time, current state, i:  212.35246909960208 (1, 3) 886
# time, current state, i:  212.81262388670262 (1, 3) 887
# time, current state, i:  212.89184562284044 (1, 3) 888
# time, current state, i:  213.00401391427692 (1, 3) 889
# time, current state, i:  213.1328463019717 (3, 1) 890
# time, current state, i:  213.2972685971006 (3, 1) 891
# time, current state, i:  213.41409698427734 (1, 3) 892
# time, current state, i:  213.93362230288167 (3, 1) 893
# time, current state, i:  214.6558870775932 (3, 1) 894
# time, current state, i:  214.86770477703874 (1, 1) 895
# time, current state, i:  215.37510831251072 (1, 1) 896
# time, current state, i:  215.47602005840045 (1, 1) 897
# time, current state, i:  215.47892421314882 (1, 1) 898
# time, current state, i:  216.0063917285496 (1, 1) 899
# time, current state, i:  216.11135472811776 (1, 1) 900
# time, current state, i:  216.44740802091422 (1, 1) 901
# time, current state, i:  216.4564704345256 (1, 1) 902
# time, current state, i:  217.01001918707456 (1, 1) 903
# time, current state, i:  217.87648957251474 (1, 2) 904
# time, current state, i:  217.94998438170956 (1, 2) 905
# time, current state, i:  218.24523595945013 (2, 1) 906
# time, current state, i:  218.47275075131463 (1, 2) 907
# time, current state, i:  218.53967517937852 (1, 2) 908
# time, current state, i:  218.57595062519712 (2, 1) 909
# time, current state, i:  218.88043579573656 (2, 1) 910
# time, current state, i:  218.8882702747619 (2, 1) 911
# time, current state, i:  218.93930378793556 (2, 1) 912
# time, current state, i:  218.98454257517417 (2, 1) 913
# time, current state, i:  219.43718029260887 (2, 1) 914
# time, current state, i:  219.53726106160772 (2, 1) 915
# time, current state, i:  219.85640379820208 (2, 1) 916
# time, current state, i:  220.067832732589 (1, 2) 917
# time, current state, i:  220.19643094285058 (2, 1) 918
# time, current state, i:  220.84818061965595 (2, 1) 919
# time, current state, i:  220.93202110617543 (1, 2) 920
# time, current state, i:  221.32466549115944 (2, 1) 921
# time, current state, i:  221.92097732050712 (1, 2) 922
# time, current state, i:  222.66924743367017 (1, 2) 923
# time, current state, i:  222.99270116344715 (2, 1) 924
# time, current state, i:  223.0009041115638 (1, 2) 925
# time, current state, i:  223.03258919312606 (1, 2) 926
# time, current state, i:  223.090343159025 (1, 2) 927
# time, current state, i:  223.2738776425044 (1, 2) 928
# time, current state, i:  223.36583085281316 (2, 1) 929
# time, current state, i:  223.8329640950062 (1, 2) 930
# time, current state, i:  223.8705617319069 (2, 2) 931
# time, current state, i:  224.3043279487529 (2, 2) 932
# time, current state, i:  225.0218378243085 (2, 2) 933
# time, current state, i:  225.22024577931677 (2, 2) 934
# time, current state, i:  225.58809173487535 (2, 2) 935
# time, current state, i:  225.6031119238846 (2, 2) 936
# time, current state, i:  225.84701626589376 (2, 2) 937
# time, current state, i:  225.9598027521796 (1, 2) 938
# time, current state, i:  226.09616449637497 (2, 2) 939
# time, current state, i:  226.43458157416543 (2, 2) 940
# time, current state, i:  226.51192317529606 (3, 2) 941
# time, current state, i:  226.58656107840912 (2, 3) 942
# time, current state, i:  226.66894571860664 (2, 3) 943
# time, current state, i:  227.6209937482693 (3, 2) 944
# time, current state, i:  227.851168427351 (2, 4) 945
# time, current state, i:  227.93848279953144 (4, 2) 946
# time, current state, i:  228.1170545946295 (2, 4) 947
# time, current state, i:  228.32627873061818 (2, 4) 948
# time, current state, i:  228.64261049245619 (3, 1) 949
# time, current state, i:  228.74575692753996 (3, 2) 950
# time, current state, i:  228.76567955694338 (2, 3) 951
# time, current state, i:  228.89018692074146 (3, 2) 952
# time, current state, i:  229.61970196068526 (2, 3) 953
# time, current state, i:  230.46912449060451 (1, 2) 954
# time, current state, i:  230.8218098917981 (1, 2) 955
# time, current state, i:  230.82525384372343 (1, 2) 956
# time, current state, i:  231.07120029258837 (2, 1) 957
# time, current state, i:  231.31146751834302 (1, 2) 958
# time, current state, i:  231.57596087593697 (1, 2) 959
# time, current state, i:  232.08094897122936 (2, 1) 960
# time, current state, i:  232.15378466827565 (2, 1) 961
# time, current state, i:  232.18620144266046 (2, 1) 962
# time, current state, i:  232.40963346922197 (1, 2) 963
# time, current state, i:  233.04667658483163 (1, 2) 964
# time, current state, i:  233.3915788711994 (2, 1) 965
# time, current state, i:  233.60007737457283 (1, 2) 966
# time, current state, i:  233.67761614093294 (1, 2) 967
# time, current state, i:  233.68308758048042 (2, 1) 968
# time, current state, i:  233.77069634552603 (1, 2) 969
# time, current state, i:  233.80781155807605 (2, 1) 970
# time, current state, i:  233.9785916626553 (2, 1) 971
# time, current state, i:  234.05371093258742 (1, 2) 972
# time, current state, i:  234.31979536664917 (2, 1) 973
# time, current state, i:  234.42942571274426 (1, 1) 974
# time, current state, i:  234.43357835758448 (1, 1) 975
# time, current state, i:  234.4354524563035 (1, 1) 976
# time, current state, i:  234.73945498892894 (1, 1) 977
# time, current state, i:  235.582376501854 (1, 1) 978
# time, current state, i:  235.72050394755377 (1, 1) 979
# time, current state, i:  235.8919240846903 (1, 1) 980
# time, current state, i:  235.9756806667056 (1, 1) 981
# time, current state, i:  235.99598284981872 (1, 1) 982
# time, current state, i:  236.30320386760133 (1, 1) 983
# time, current state, i:  236.45824343583277 (1, 1) 984
# time, current state, i:  236.58915018575823 (1, 1) 985
# time, current state, i:  236.63713820887642 (1, 1) 986
# time, current state, i:  236.87741068434013 (1, 1) 987
# time, current state, i:  237.0105446244029 (1, 1) 988
# time, current state, i:  237.1767128258066 (2, 1) 989
# time, current state, i:  237.48354118899493 (1, 3) 990
# time, current state, i:  237.60832711042548 (1, 2) 991
# time, current state, i:  237.84731956770244 (2, 1) 992
# time, current state, i:  237.8786142151584 (1, 2) 993
# time, current state, i:  238.10030982117314 (1, 2) 994
# time, current state, i:  238.1133277794622 (2, 1) 995
# time, current state, i:  238.44708216001612 (1, 2) 996
# time, current state, i:  238.69579885456275 (1, 2) 997
# time, current state, i:  239.25956227805966 (2, 1) 998
# time, current state, i:  239.3251005964343 (2, 2) 999
# count 999 1002
# FOG-1 Average queueing time: 0.13490651919484917
# FOG-1 Average service time: 0.8226157245364474
# FOG-1 Average response time: 0.9575222437312961
# FOG-1 Average Energy consumption: 232.2005113925833
# FOG-2 Average queueing time: 0.1311390369669863
# FOG-2 Average service time: 0.784426109560518
# FOG-2 Average response time: 0.9155651465275043
# FOG-2 Average Energy consumption: 229.08382852092205

# %%
import numpy as np   #importing libraries
import simpy 
import queue
import random
import random as rd
import matplotlib 
from matplotlib import pyplot as plt

# %%
global SZ,CP,RM
SZ=[]
CP=[]
RM=[]
N=1000
k=10
Lambda = 2
mu = 1.25
#t = 0   #system clock
t1=0
t2=0
t_lambda = 0 #poisson random variable used to generate next service time
t_mu = 0  #poisson random variable used to generate next departure time
t_a=0
wait=0
R=1000
transmission_time=0
l="0"
P_transmission=500
P_idle=100
alpha = 0.1
gamma = 0.95
episodes = 10
SHOW_EVERY = 100
STATS_EVERY=100
observation_space_discretesize = [20, 20]

# %%
class Packet(object):
    def __init__(self, time, id, mobileID, seeed):
        
        self.time=time                                                
        self.id=id
        self.mobileID=mobileID   
        self.size=random.randint(200,400) #seed 1 op 2, seed 2 op 
        SZ.append(round(self.size,2))
        #print(seeed)
        #random.seed(seeed)
        self.cpu=random.randint(20,90) #seed 1 op 2, seed 2 op 
        CP.append(round(self.cpu,2))
        #random.seed(seeed)
        self.ram=random.randint(1, 32) #seed 1 op 3, seed 2 op 1, seed 3 op 4
        RM.append(round(self.ram,2))

class mobile(object): #mobile class with an ID              
    def __init__(self, ID):
        self.ID=ID
        self.pot=int(1)
        
    #generates packets and sends via out_pipe
    def packet_generator(self, numPackets, env, out_pipe, task_id,send): 
        
        yield env.timeout(send)
        #print("sending task {} of mobile {} at time {}".format(task_id, self.ID, env.now))
        p=Packet(env.now, task_id, self.ID, self.pot)
        self.pot+=1
        if(self.pot==4):
                self.pot=1
        yield out_pipe.put(p)
        item = yield out_pipe.get()

# %%
 def reward_generator(T): 
    Tsla=2.5 
    Nsla=3
    Gsla=3  
    Cost_sla=50
    Cg=0
    Ct=0
    Cn=0
    Cost_n=0
    
    #if (G<Gsla):
        #Cg=-5*(Gsla/G)
    if (T>Tsla):
        Ct = -5 * (T/Tsla)
    #if (N>Nsla):
        #Cn=-5*(N/Nsla)
    #if (cost>Cost_sla):
        #Cost_n=-5*(cost/Cost_sla)
    
    Reward = (Tsla/T) + Ct #Reward Function
    return Reward

# %%
class Fog(object):      
    def __init__(self, ID):
        self.ID=ID
        self.Number_queue=1
        self.lost=0
        self.response_time=0
        self.server_count=0
        self.wait=0
        self.taskinqueue=0
        self.a=0
        self.time=0
        
        self.service_time=[]
        self.response_time_list=[]
        self.Serverqueue=[]
        self.total_serverqueue=[]
        self.waitlist=[]
        self.energy_offloading=[]
        self.reward_list=[]
        self.state=[]
        
    def FOG(self, env, server, in_pipe,mobile,pipe3):
        
         msg = yield in_pipe.get()
         transmission_time = (msg.size/R)
         #print("transmits task {} to need time {}".format(msg.id,transmission_time,self.ID))
         yield env.timeout(transmission_time)
         self.a=env.now
         #print("Arrived task {} at time {} at FOG {}".format(msg.id,self.a,self.ID))
         #print("server",self.server_count)
         if self.server_count==3:
            if len(self.Serverqueue)<k:
               self.Serverqueue.append(msg)
               self.taskinqueue=len(self.Serverqueue)
               #print("queue te ase ",len(self.Serverqueue))
               #print("task ase queue te ase ",taskinqueue)
               self.Number_queue = self.Number_queue + 1
               #self.server_count=0
            else:
                self.lost=self.lost+1 
                return  
         #s=q+1  
         #q=s
         u=rd.random()
         t_mu=-np.log(u)/mu
         self.service_time.append(t_mu)
         #print("service time",t_mu)
         E = (P_transmission * transmission_time) + (P_idle * t_mu)
         self.energy_offloading.append(E)
         
         #print("present a queue te ase ",len(self.Serverqueue))
         print("Fog:   Fog",self.ID,"mobile",mobile,", akhon queue te ase ",self.taskinqueue,", time",env.now)
         state=[]
         state.append([self.ID,mobile,self.taskinqueue,env.now])
         yield pipe3.put(state)
         with server.request() as req:
             yield req
             s=env.now
             self.wait=s-self.a
             if len(self.Serverqueue)>0:
                 self.Serverqueue.pop(0)
             #self.total_serverqueue.append(len(self.Serverqueue))
             #print("queue",len(self.Serverqueue))
             #print("wait",self.wait)
             #print("Starting service task {} at time {} at FOG {}".format(msg.id,s,self.ID))
             #print("Waiting time of task {} at time {} at FOG {}".format(msg.id,self.wait,self.ID))
             self.waitlist.append(self.wait)
             self.response_time=self.wait+t_mu
             self.response_time_list.append(self.response_time)
             
             #if self.wait>0:
                #print("queue",len(self.Serverqueue))
              #  if len(self.Serverqueue)<10:
               #     self.Serverqueue.append(msg)
                #    self.Number_queue = self.Number_queue + 1
                 #   self.total_serverqueue.append(len(self.Serverqueue))
                  #  yield env.timeout(t_mu)
                   # print("Finish service task {} at time {} at FOG {}".format(msg.id,env.now,self.ID))
                    #if len(self.Serverqueue)>0:
                     #   self.Serverqueue.pop(0)
                #else:
                 #   self.lost=self.lost+1 
                  #  return 
             self.server_count=self.server_count+1
             yield env.timeout(t_mu)
             #print("Finish service task {} at time {} at FOG {}".format(msg.id,env.now,self.ID))
             self.server_count=self.server_count-1   

                
             r=reward_generator(self.response_time)
             self.reward_list.append(r)
         #print("Fog",self.ID,"pore queue te ase ",self.taskinqueue,"time hoitese",env.now)
         return self.a 
    def nextstate(self,env,mobile,pipe3):
        state = yield pipe3.get()
        print("FOG, mobile, queue te ase, time")
        print(state)
        #next_state=self.taskinqueue
        #print("nxtstate: Fog",self.ID,"mobile",mobile,", req er age queue te ase",next_state,", time",env.now)

# %%
env1 = simpy.Environment()    
server1 = simpy.Resource(env1, capacity=3)
server2 = simpy.Resource(env1, capacity=3)

pipe1 = simpy.Store(env1)
pipe2 = simpy.Store(env1)
pipe3 = simpy.Store(env1)

ms1=mobile(1)
ms2=mobile(2)
ms3=mobile(3)

fog1 = Fog(1)
fog2 = Fog(2)
fog1_count=0
fog2_count=0
for i in range(N):
    
    choose=random.randint(1,2)

    if(choose==1):
        fog1_count=fog1_count+1
        u=rd.random()
        t_lambda=-np.log(u)/Lambda
        t_a=t1+t_lambda
        t1=t_a

        env1.process(ms1.packet_generator(1, env1, pipe1, i,t_a))
        p=env1.process(fog1.FOG(env1, server1, pipe1,ms1.ID,pipe3))
        env1.process(fog1.nextstate(env1,ms1.ID,pipe3))
        
        fog1_count=fog1_count+1
        u=rd.random()
        t_lambda=-np.log(u)/Lambda
        t_a=t2+t_lambda
        t2=t_a

        env1.process(ms2.packet_generator(1, env1, pipe2, i,t_a))
        env1.process(fog1.FOG(env1, server1, pipe2,ms2.ID,pipe3))
        env1.process(fog1.nextstate(env1,ms2.ID,pipe3))
    if(choose==2):
         fog2_count=fog2_count+1
         u=rd.random()
         t_lambda=-np.log(u)/Lambda
         t_a=t1+t_lambda
         t1=t_a

         env1.process(ms1.packet_generator(1, env1, pipe1, i,t_a))
         env1.process(fog2.FOG(env1, server2, pipe1,ms1.ID,pipe3))
         env1.process(fog2.nextstate(env1,ms1.ID,pipe3))
        
         fog2_count=fog2_count+1
         u=rd.random()
         t_lambda=-np.log(u)/Lambda
         t_a=t2+t_lambda
         t2=t_a

         env1.process(ms2.packet_generator(1, env1, pipe2, i,t_a))
         env1.process(fog2.FOG(env1, server2, pipe2,ms2.ID,pipe3))
         env1.process(fog2.nextstate(env1,ms2.ID,pipe3))
env1.run()
    
#i=0
#while (i<N):
 #   print("{}     {}     {}".format(i+1,fog1.response_time_list[i],fog1.reward_list[i]))
 #   i+=1

print(fog1.lost,fog2.lost)
print(fog1_count,fog2_count)
#print(len(fog1.total_serverqueue))
#Na=N-fog.lost
#print("No    serverqueue       wait_time")
#i=0
#c=0
#while (i<fog2_count):
   # if(fog2.waitlist[i]>0):
  #      c+=1
 #   i+=1
#print("total queue te ase",fog2.Number_queue)
#print("total wait list e ase",c)
#print("FOG-1 MAXIMUM REAWARD:", max(fog1.reward_list))
#print("FOG-1 total number of task in queue",fog1.Number_queue)
avgwaittime=sum(fog1.waitlist)/fog1_count
print("FOG-1 Average queueing time:", avgwaittime)
avgservicetime=sum(fog1.service_time)/fog1_count
print("FOG-1 Average service time:", avgservicetime)
avgsystemtime=sum(fog1.response_time_list)/fog1_count
print("FOG-1 Average response time:", avgsystemtime)
avgenergy=sum(fog1.energy_offloading)/fog1_count
print("FOG-1 Average Energy consumption:", avgenergy)

#print("No    response_time       reward")
#i=0
#while (i<N):
 #   print("{}     {}     {}".format(i+1,fog2.response_time_list[i],fog2.reward_list[i]))
  #  i+=1
#print("FOG-2 MAXIMUM REAWARD:", max(fog2.reward_list))
#print("FOG-2 total number of task in queue",fog2.Number_queue)
avgwaittime=sum(fog2.waitlist)/fog2_count
print("FOG-2 Average queueing time:", avgwaittime)
avgservicetime=sum(fog2.service_time)/fog2_count
print("FOG-2 Average service time:", avgservicetime)
avgsystemtime=sum(fog2.response_time_list)/fog2_count
print("FOG-2 Average response time:", avgsystemtime)
avgenergy=sum(fog2.energy_offloading)/fog2_count
print("FOG-2 Average Energy consumption:", avgenergy)
# Out:
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3983.5619669937537
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3983.5619669937537]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3984.5572807049425
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3984.5572807049425]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 3984.9343045385795
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 3984.9343045385795]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3985.8045468204114
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3985.8045468204114]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3986.390278468738
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3986.390278468738]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3986.5204442646705
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3986.5204442646705]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 3987.1494191753472
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 3987.1494191753472]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3987.2833134492716
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3987.2833134492716]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3987.8091954750807
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3987.8091954750807]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3988.1823777716963
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3988.1823777716963]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 3988.1965566259223
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 3988.1965566259223]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3988.243220093898
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3988.243220093898]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3988.4420082619135
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3988.4420082619135]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3989.6133542273715
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3989.6133542273715]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 3990.0035685388543
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 3990.0035685388543]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 3990.0757004730845
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 3990.0757004730845]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 3991.025672692077
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 3991.025672692077]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 3991.041975870421
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 3991.041975870421]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3991.6758371412902
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3991.6758371412902]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3995.6579630091915
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3995.6579630091915]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3996.7794436021863
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3996.7794436021863]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3997.3498275781294
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3997.3498275781294]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 3997.4365324774594
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 3997.4365324774594]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3997.909562187649
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3997.909562187649]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 3998.274009498599
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 3998.274009498599]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4000.2895083268386
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4000.2895083268386]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4000.452631493199
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4000.452631493199]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4000.518609482575
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4000.518609482575]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4000.6439502894204
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4000.6439502894204]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4000.684955065433
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4000.684955065433]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4000.7851921004803
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4000.7851921004803]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4001.7769990050883
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4001.7769990050883]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4002.599321876043
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4002.599321876043]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4002.7442798983298
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4002.7442798983298]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4003.4656819275833
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4003.4656819275833]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4004.13108500086
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4004.13108500086]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4004.439925617935
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4004.439925617935]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4005.5650098255173
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4005.5650098255173]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4006.0046533628793
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4006.0046533628793]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4006.4919385083963
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4006.4919385083963]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4007.0276290981246
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4007.0276290981246]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4007.086966158385
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4007.086966158385]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4007.492353590981
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4007.492353590981]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4008.3396947954147
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4008.3396947954147]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4008.6574014584453
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4008.6574014584453]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4008.7861005905916
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4008.7861005905916]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4008.8063093081487
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4008.8063093081487]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4009.9208999714274
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4009.9208999714274]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4010.1543294983385
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4010.1543294983385]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4010.4002994027273
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4010.4002994027273]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4011.1749631864236
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4011.1749631864236]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4011.6742913929756
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4011.6742913929756]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4012.445097134814
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4012.445097134814]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4014.4697682817505
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4014.4697682817505]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4014.764049824005
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4014.764049824005]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4016.0191624347667
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4016.0191624347667]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4016.2835099717877
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4016.2835099717877]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4016.2923749674637
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4016.2923749674637]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4016.6456388574834
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4016.6456388574834]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4017.490131683056
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4017.490131683056]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4018.88981519633
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4018.88981519633]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4019.0805573624507
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4019.0805573624507]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4019.3723158548037
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4019.3723158548037]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4019.605012736296
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4019.605012736296]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4020.469369267829
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4020.469369267829]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4021.3460342105013
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4021.3460342105013]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4021.386521302796
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4021.386521302796]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  0 , time 4021.9661860648953
# FOG, mobile, queue te ase, time
# [[1, 1, 0, 4021.9661860648953]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  0 , time 4022.075584739662
# FOG, mobile, queue te ase, time
# [[1, 1, 0, 4022.075584739662]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  0 , time 4022.735947929084
# FOG, mobile, queue te ase, time
# [[2, 1, 0, 4022.735947929084]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  0 , time 4023.196476342615
# FOG, mobile, queue te ase, time
# [[1, 1, 0, 4023.196476342615]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  0 , time 4023.4409665580847
# FOG, mobile, queue te ase, time
# [[1, 2, 0, 4023.4409665580847]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  0 , time 4023.5294241365987
# FOG, mobile, queue te ase, time
# [[1, 1, 0, 4023.5294241365987]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4023.7193473445363
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4023.7193473445363]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  0 , time 4023.750625574049
# FOG, mobile, queue te ase, time
# [[2, 1, 0, 4023.750625574049]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4023.8638150027105
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4023.8638150027105]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4024.8654419376376
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4024.8654419376376]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4025.870349735498
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4025.870349735498]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  0 , time 4026.0305984389843
# FOG, mobile, queue te ase, time
# [[2, 1, 0, 4026.0305984389843]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4026.099463020875
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4026.099463020875]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  0 , time 4026.101412605854
# FOG, mobile, queue te ase, time
# [[2, 2, 0, 4026.101412605854]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4026.1533601973506
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4026.1533601973506]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4026.524295778165
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4026.524295778165]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4026.5618674115644
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4026.5618674115644]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4026.5820866997024
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4026.5820866997024]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4026.713643256541
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4026.713643256541]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4027.18375578738
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4027.18375578738]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4027.203685392801
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4027.203685392801]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4027.2139114781485
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4027.2139114781485]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4027.2192995019886
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4027.2192995019886]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4028.0728966189204
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4028.0728966189204]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4028.09424548067
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4028.09424548067]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4028.0958501283003
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4028.0958501283003]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4028.192511838474
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4028.192511838474]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4028.343415963277
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4028.343415963277]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4028.457262766238
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4028.457262766238]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4028.7575725796555
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4028.7575725796555]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4029.325163764727
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4029.325163764727]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4029.327109945006
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4029.327109945006]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4029.437589747004
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4029.437589747004]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 4029.593285749862
# FOG, mobile, queue te ase, time
# [[2, 2, 2, 4029.593285749862]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4030.315390759709
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4030.315390759709]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 4030.331985023833
# FOG, mobile, queue te ase, time
# [[2, 2, 2, 4030.331985023833]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4030.3972385550755
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4030.3972385550755]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  2 , time 4030.7248007014905
# FOG, mobile, queue te ase, time
# [[1, 1, 2, 4030.7248007014905]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 4031.013787138914
# FOG, mobile, queue te ase, time
# [[2, 2, 2, 4031.013787138914]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4031.084400545289
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4031.084400545289]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4031.1951920677516
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4031.1951920677516]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4031.3835316212603
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4031.3835316212603]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4032.167056103665
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4032.167056103665]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4033.473611189762
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4033.473611189762]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4033.5946586607665
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4033.5946586607665]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4034.216628831456
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4034.216628831456]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4034.365966481605
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4034.365966481605]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4034.541303755004
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4034.541303755004]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4035.1059908782704
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4035.1059908782704]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4035.146149170908
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4035.146149170908]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4035.2704617660766
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4035.2704617660766]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  2 , time 4035.451439891294
# FOG, mobile, queue te ase, time
# [[1, 1, 2, 4035.451439891294]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4035.6339014440546
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4035.6339014440546]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4036.014235292936
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4036.014235292936]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4036.6462732367154
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4036.6462732367154]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4037.098795042739
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4037.098795042739]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  2 , time 4037.481769194255
# FOG, mobile, queue te ase, time
# [[1, 1, 2, 4037.481769194255]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  2 , time 4037.8851208273704
# FOG, mobile, queue te ase, time
# [[1, 1, 2, 4037.8851208273704]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4038.5139256348953
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4038.5139256348953]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  2 , time 4038.657851227147
# FOG, mobile, queue te ase, time
# [[1, 1, 2, 4038.657851227147]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4038.8187830380957
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4038.8187830380957]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4039.068538973946
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4039.068538973946]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  2 , time 4039.673164939786
# FOG, mobile, queue te ase, time
# [[1, 1, 2, 4039.673164939786]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4039.99679634728
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4039.99679634728]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4039.9981054916057
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4039.9981054916057]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4040.464594292618
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4040.464594292618]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4040.5642307220164
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4040.5642307220164]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4040.854764170817
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4040.854764170817]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4041.182810034557
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4041.182810034557]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  2 , time 4041.3218874438207
# FOG, mobile, queue te ase, time
# [[1, 1, 2, 4041.3218874438207]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4041.3989579286817
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4041.3989579286817]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4041.887543757807
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4041.887543757807]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4041.9886739613376
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4041.9886739613376]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4042.2086893138103
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4042.2086893138103]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4042.2640720004138
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4042.2640720004138]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  2 , time 4042.5348378991653
# FOG, mobile, queue te ase, time
# [[1, 1, 2, 4042.5348378991653]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4042.738680523743
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4042.738680523743]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4042.8070839361444
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4042.8070839361444]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  3 , time 4042.9172264358
# FOG, mobile, queue te ase, time
# [[1, 1, 3, 4042.9172264358]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  3 , time 4043.223414647475
# FOG, mobile, queue te ase, time
# [[1, 2, 3, 4043.223414647475]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 4043.294395311068
# FOG, mobile, queue te ase, time
# [[1, 2, 4, 4043.294395311068]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 4043.3412175339486
# FOG, mobile, queue te ase, time
# [[1, 2, 5, 4043.3412175339486]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 4043.809810043931
# FOG, mobile, queue te ase, time
# [[1, 2, 5, 4043.809810043931]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4044.2945138059263
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4044.2945138059263]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4044.4685134238534
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4044.4685134238534]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4044.9121111519353
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4044.9121111519353]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4045.583440796215
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4045.583440796215]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 4045.675422528099
# FOG, mobile, queue te ase, time
# [[1, 1, 5, 4045.675422528099]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4045.9459935964464
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4045.9459935964464]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4046.0357080458816
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4046.0357080458816]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4046.454946614152
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4046.454946614152]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 4046.754663210902
# FOG, mobile, queue te ase, time
# [[1, 2, 5, 4046.754663210902]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 4046.8086086003827
# FOG, mobile, queue te ase, time
# [[1, 2, 5, 4046.8086086003827]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4046.8626466475976
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4046.8626466475976]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4047.2370195855824
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4047.2370195855824]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4047.7045442131416
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4047.7045442131416]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4048.0927876115447
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4048.0927876115447]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 4048.567802700028
# FOG, mobile, queue te ase, time
# [[1, 2, 5, 4048.567802700028]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4048.6206797700765
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4048.6206797700765]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4048.865287176656
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4048.865287176656]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 4048.885495950428
# FOG, mobile, queue te ase, time
# [[1, 2, 5, 4048.885495950428]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4048.9262534977534
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4048.9262534977534]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 4049.3303027660595
# FOG, mobile, queue te ase, time
# [[1, 1, 5, 4049.3303027660595]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 4049.445434562152
# FOG, mobile, queue te ase, time
# [[1, 1, 5, 4049.445434562152]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 4050.0444865425025
# FOG, mobile, queue te ase, time
# [[1, 2, 5, 4050.0444865425025]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 4050.3755214814714
# FOG, mobile, queue te ase, time
# [[1, 1, 5, 4050.3755214814714]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4050.764429039929
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4050.764429039929]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4051.008489627969
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4051.008489627969]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 4051.3209134371677
# FOG, mobile, queue te ase, time
# [[1, 1, 5, 4051.3209134371677]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  5 , time 4051.4066723077303
# FOG, mobile, queue te ase, time
# [[1, 2, 5, 4051.4066723077303]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4051.483010937794
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4051.483010937794]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4051.767637536772
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4051.767637536772]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4051.7800159450894
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4051.7800159450894]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4051.873543653681
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4051.873543653681]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4051.917977339988
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4051.917977339988]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 4052.3928416142503
# FOG, mobile, queue te ase, time
# [[1, 1, 5, 4052.3928416142503]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4052.4427301609844
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4052.4427301609844]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 4052.5210974863508
# FOG, mobile, queue te ase, time
# [[1, 1, 5, 4052.5210974863508]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 4052.632804917644
# FOG, mobile, queue te ase, time
# [[1, 1, 5, 4052.632804917644]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4052.8152869438613
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4052.8152869438613]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4053.0372883514
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4053.0372883514]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4053.7089740565298
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4053.7089740565298]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4053.776845996515
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4053.776845996515]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4054.1311176694767
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4054.1311176694767]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4055.053117712339
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4055.053117712339]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4055.434026277561
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4055.434026277561]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4055.7758049886747
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4055.7758049886747]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4056.018979081493
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4056.018979081493]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4056.11034620919
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4056.11034620919]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4056.545640168124
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4056.545640168124]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4056.5638825090555
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4056.5638825090555]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4056.689301326361
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4056.689301326361]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4056.9369469517524
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4056.9369469517524]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4057.7437989061714
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4057.7437989061714]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4057.9607056490777
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4057.9607056490777]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4058.381319081071
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4058.381319081071]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4058.920277359696
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4058.920277359696]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4059.024816469008
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4059.024816469008]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4059.9180808905
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4059.9180808905]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4060.2235584038276
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4060.2235584038276]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4060.269924746568
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4060.269924746568]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4060.4735906426386
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4060.4735906426386]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4061.1757167296855
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4061.1757167296855]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4061.234013463226
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4061.234013463226]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4061.3563807245528
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4061.3563807245528]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4061.515002623493
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4061.515002623493]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4061.7416393745007
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4061.7416393745007]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4062.0478053491356
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4062.0478053491356]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4062.2028803284406
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4062.2028803284406]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4062.2535399306016
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4062.2535399306016]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4062.320638062846
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4062.320638062846]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4062.4970712016816
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4062.4970712016816]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4062.881686457291
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4062.881686457291]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4062.9124528682974
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4062.9124528682974]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4063.0872476928903
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4063.0872476928903]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4063.368607564979
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4063.368607564979]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4063.427058276078
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4063.427058276078]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4063.4586772910284
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4063.4586772910284]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4063.634855354746
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4063.634855354746]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4063.822275983786
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4063.822275983786]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4063.8525921824926
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4063.8525921824926]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4064.034411932105
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4064.034411932105]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4064.1000658336056
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4064.1000658336056]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4064.3369130727833
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4064.3369130727833]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4064.4811475470524
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4064.4811475470524]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  2 , time 4064.5600779802403
# FOG, mobile, queue te ase, time
# [[1, 1, 2, 4064.5600779802403]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4065.536483523755
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4065.536483523755]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4065.662105765324
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4065.662105765324]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4065.9280468644047
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4065.9280468644047]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4066.749166188901
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4066.749166188901]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4067.345063890734
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4067.345063890734]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4067.866886058188
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4067.866886058188]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4067.913022818208
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4067.913022818208]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  2 , time 4068.0111194368783
# FOG, mobile, queue te ase, time
# [[1, 1, 2, 4068.0111194368783]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4068.242752860528
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4068.242752860528]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  2 , time 4068.806516140977
# FOG, mobile, queue te ase, time
# [[1, 1, 2, 4068.806516140977]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4069.0263572449844
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4069.0263572449844]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4069.107038378741
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4069.107038378741]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4069.168793113101
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4069.168793113101]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4069.757979484584
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4069.757979484584]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4069.770824237191
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4069.770824237191]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4070.3210212149006
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4070.3210212149006]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4070.569818145506
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4070.569818145506]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4071.1816957268525
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4071.1816957268525]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4071.336910107017
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4071.336910107017]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4071.4958374049593
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4071.4958374049593]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4071.767235294067
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4071.767235294067]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4071.973260857451
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4071.973260857451]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4072.169557646472
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4072.169557646472]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4072.1888584310373
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4072.1888584310373]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4072.49831671874
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4072.49831671874]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  2 , time 4072.74652635565
# FOG, mobile, queue te ase, time
# [[1, 1, 2, 4072.74652635565]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4072.9580020963413
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4072.9580020963413]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4073.0499917779302
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4073.0499917779302]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  3 , time 4073.0813571720687
# FOG, mobile, queue te ase, time
# [[1, 1, 3, 4073.0813571720687]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  4 , time 4073.271416086343
# FOG, mobile, queue te ase, time
# [[1, 1, 4, 4073.271416086343]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  3 , time 4073.4988694016997
# FOG, mobile, queue te ase, time
# [[1, 1, 3, 4073.4988694016997]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  3 , time 4073.5265344562413
# FOG, mobile, queue te ase, time
# [[1, 1, 3, 4073.5265344562413]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 4073.625771974724
# FOG, mobile, queue te ase, time
# [[1, 2, 4, 4073.625771974724]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 4073.9046016535594
# FOG, mobile, queue te ase, time
# [[1, 2, 4, 4073.9046016535594]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  5 , time 4074.1242032394143
# FOG, mobile, queue te ase, time
# [[1, 1, 5, 4074.1242032394143]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  6 , time 4074.2188478941607
# FOG, mobile, queue te ase, time
# [[1, 1, 6, 4074.2188478941607]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4074.2296234051037
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4074.2296234051037]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  7 , time 4074.3472902104663
# FOG, mobile, queue te ase, time
# [[1, 1, 7, 4074.3472902104663]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4075.247813860785
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4075.247813860785]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  4 , time 4075.4328010598315
# FOG, mobile, queue te ase, time
# [[1, 2, 4, 4075.4328010598315]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4076.0448744151345
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4076.0448744151345]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4076.3708157310753
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4076.3708157310753]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4076.462848495271
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4076.462848495271]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  2 , time 4077.402374812575
# FOG, mobile, queue te ase, time
# [[1, 2, 2, 4077.402374812575]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4077.4544534145957
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4077.4544534145957]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4077.5104924647135
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4077.5104924647135]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  2 , time 4077.593445543802
# FOG, mobile, queue te ase, time
# [[1, 1, 2, 4077.593445543802]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4077.6188129348016
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4077.6188129348016]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4077.636559723354
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4077.636559723354]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4077.71119667724
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4077.71119667724]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 4077.7236579006076
# FOG, mobile, queue te ase, time
# [[2, 2, 2, 4077.7236579006076]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4078.67860077779
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4078.67860077779]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4078.6973096966517
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4078.6973096966517]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4078.8288559992297
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4078.8288559992297]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 4079.220006253215
# FOG, mobile, queue te ase, time
# [[2, 1, 2, 4079.220006253215]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4079.335752724721
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4079.335752724721]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 4079.4493564137338
# FOG, mobile, queue te ase, time
# [[2, 2, 2, 4079.4493564137338]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4079.661421699346
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4079.661421699346]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 4079.8073667010717
# FOG, mobile, queue te ase, time
# [[2, 1, 2, 4079.8073667010717]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 4080.0477553807323
# FOG, mobile, queue te ase, time
# [[2, 2, 2, 4080.0477553807323]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  3 , time 4080.1794885439085
# FOG, mobile, queue te ase, time
# [[2, 1, 3, 4080.1794885439085]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 4080.2979922529876
# FOG, mobile, queue te ase, time
# [[2, 2, 3, 4080.2979922529876]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4080.4575697659143
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4080.4575697659143]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  4 , time 4080.633869516562
# FOG, mobile, queue te ase, time
# [[2, 1, 4, 4080.633869516562]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4080.9365962902234
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4080.9365962902234]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4080.967302749495
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4080.967302749495]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  3 , time 4081.202952413932
# FOG, mobile, queue te ase, time
# [[2, 1, 3, 4081.202952413932]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4081.287813049306
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4081.287813049306]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 4081.305134426495
# FOG, mobile, queue te ase, time
# [[2, 2, 3, 4081.305134426495]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  4 , time 4081.464700225757
# FOG, mobile, queue te ase, time
# [[2, 1, 4, 4081.464700225757]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 4082.1387946734444
# FOG, mobile, queue te ase, time
# [[2, 2, 3, 4082.1387946734444]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4082.1680245739876
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4082.1680245739876]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4082.3120142434736
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4082.3120142434736]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 4082.3568161137923
# FOG, mobile, queue te ase, time
# [[2, 2, 2, 4082.3568161137923]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 4082.5380607502384
# FOG, mobile, queue te ase, time
# [[2, 2, 3, 4082.5380607502384]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  4 , time 4082.6101964975846
# FOG, mobile, queue te ase, time
# [[2, 1, 4, 4082.6101964975846]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  5 , time 4082.9424002513665
# FOG, mobile, queue te ase, time
# [[2, 2, 5, 4082.9424002513665]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4083.010752415379
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4083.010752415379]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  4 , time 4083.0258298268313
# FOG, mobile, queue te ase, time
# [[2, 2, 4, 4083.0258298268313]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4083.0531862466255
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4083.0531862466255]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  5 , time 4083.1528640691095
# FOG, mobile, queue te ase, time
# [[2, 1, 5, 4083.1528640691095]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  5 , time 4083.2658285616403
# FOG, mobile, queue te ase, time
# [[2, 1, 5, 4083.2658285616403]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4083.8285628616313
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4083.8285628616313]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  4 , time 4084.5652415679074
# FOG, mobile, queue te ase, time
# [[2, 1, 4, 4084.5652415679074]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4084.756646257945
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4084.756646257945]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  4 , time 4084.799650443399
# FOG, mobile, queue te ase, time
# [[2, 1, 4, 4084.799650443399]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4084.806395507741
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4084.806395507741]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4084.8304640926717
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4084.8304640926717]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  4 , time 4084.9968812267716
# FOG, mobile, queue te ase, time
# [[2, 1, 4, 4084.9968812267716]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  5 , time 4085.0717175141863
# FOG, mobile, queue te ase, time
# [[2, 1, 5, 4085.0717175141863]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  6 , time 4085.609764915294
# FOG, mobile, queue te ase, time
# [[2, 2, 6, 4085.609764915294]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4085.793476705826
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4085.793476705826]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  4 , time 4086.4512200465324
# FOG, mobile, queue te ase, time
# [[2, 2, 4, 4086.4512200465324]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4086.7143894817304
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4086.7143894817304]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4086.740647255762
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4086.740647255762]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  3 , time 4087.026957063371
# FOG, mobile, queue te ase, time
# [[2, 1, 3, 4087.026957063371]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4087.1291988417347
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4087.1291988417347]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4088.063932817935
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4088.063932817935]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4088.1431507441025
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4088.1431507441025]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 4088.3786940794234
# FOG, mobile, queue te ase, time
# [[2, 2, 2, 4088.3786940794234]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  3 , time 4088.4345143432465
# FOG, mobile, queue te ase, time
# [[2, 1, 3, 4088.4345143432465]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  4 , time 4088.5067046480713
# FOG, mobile, queue te ase, time
# [[2, 1, 4, 4088.5067046480713]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4088.6406425146047
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4088.6406425146047]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 4088.664494013944
# FOG, mobile, queue te ase, time
# [[2, 2, 2, 4088.664494013944]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4088.7586761104567
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4088.7586761104567]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4089.477984325555
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4089.477984325555]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 4089.7213715933285
# FOG, mobile, queue te ase, time
# [[2, 1, 2, 4089.7213715933285]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 4090.532267553413
# FOG, mobile, queue te ase, time
# [[2, 2, 2, 4090.532267553413]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 4090.992800821209
# FOG, mobile, queue te ase, time
# [[2, 2, 2, 4090.992800821209]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4091.308325899013
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4091.308325899013]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4091.517566662935
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4091.517566662935]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4091.7690303255354
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4091.7690303255354]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4092.426723368076
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4092.426723368076]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 4092.528876115304
# FOG, mobile, queue te ase, time
# [[2, 2, 2, 4092.528876115304]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 4093.0418616387665
# FOG, mobile, queue te ase, time
# [[2, 1, 2, 4093.0418616387665]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4093.097276208066
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4093.097276208066]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4093.169404301609
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4093.169404301609]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 4093.2777111739133
# FOG, mobile, queue te ase, time
# [[2, 2, 2, 4093.2777111739133]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4093.336322302059
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4093.336322302059]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4093.4555001074796
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4093.4555001074796]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 4093.5201160953807
# FOG, mobile, queue te ase, time
# [[2, 2, 2, 4093.5201160953807]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 4093.8024011846005
# FOG, mobile, queue te ase, time
# [[2, 1, 2, 4093.8024011846005]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4093.9895458899027
# ...
# [[2, 2, 1, 4473.028064791422]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4473.107958567405
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4473.107958567405]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4473.319496576116
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4473.319496576116]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4473.395803192801
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4473.395803192801]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4473.7761596023665
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4473.7761596023665]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4473.81934434407
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4473.81934434407]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4473.88818893079
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4473.88818893079]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4474.187525991883
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4474.187525991883]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4474.216918909746
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4474.216918909746]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4474.509667745745
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4474.509667745745]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4474.523677902462
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4474.523677902462]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4474.549961197827
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4474.549961197827]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4474.727838764659
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4474.727838764659]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4475.148116776132
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4475.148116776132]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4475.189673883425
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4475.189673883425]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4475.216792634914
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4475.216792634914]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4475.569225738032
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4475.569225738032]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4475.754191168437
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4475.754191168437]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4476.623220133564
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4476.623220133564]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4476.638709771822
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4476.638709771822]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4476.803168147529
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4476.803168147529]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4477.135241784527
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4477.135241784527]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4477.303637845051
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4477.303637845051]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4478.555294464339
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4478.555294464339]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4479.081687314381
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4479.081687314381]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4479.199257628475
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4479.199257628475]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4480.144531137376
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4480.144531137376]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4480.440562546552
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4480.440562546552]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4480.555459462344
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4480.555459462344]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4480.682325312958
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4480.682325312958]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4480.913737601166
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4480.913737601166]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4480.950181651371
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4480.950181651371]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4481.063020048268
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4481.063020048268]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 4481.186162532896
# FOG, mobile, queue te ase, time
# [[2, 1, 2, 4481.186162532896]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4481.187075185133
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4481.187075185133]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4481.327112001232
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4481.327112001232]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 4481.498584355378
# FOG, mobile, queue te ase, time
# [[2, 1, 2, 4481.498584355378]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4482.360815491578
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4482.360815491578]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4482.587619687507
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4482.587619687507]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 4482.756853038861
# FOG, mobile, queue te ase, time
# [[2, 2, 2, 4482.756853038861]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4482.810341182844
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4482.810341182844]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 4482.864413358598
# FOG, mobile, queue te ase, time
# [[2, 1, 2, 4482.864413358598]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4482.957006903184
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4482.957006903184]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 4483.014828150569
# FOG, mobile, queue te ase, time
# [[2, 1, 2, 4483.014828150569]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4483.077519426823
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4483.077519426823]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4483.132156189129
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4483.132156189129]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4483.4567400882825
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4483.4567400882825]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4483.747952340355
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4483.747952340355]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4483.928976554959
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4483.928976554959]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4484.200559047149
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4484.200559047149]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4484.341347284728
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4484.341347284728]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4484.980467477782
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4484.980467477782]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4485.564079158605
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4485.564079158605]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4485.81989332843
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4485.81989332843]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4486.666110677558
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4486.666110677558]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4486.772661192886
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4486.772661192886]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4487.35719892936
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4487.35719892936]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4487.736261662907
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4487.736261662907]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4487.937086533304
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4487.937086533304]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4488.006829279835
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4488.006829279835]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4488.461962577202
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4488.461962577202]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4488.6108326990925
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4488.6108326990925]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4489.036677488721
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4489.036677488721]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4489.483034714537
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4489.483034714537]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4489.78858875728
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4489.78858875728]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4490.057170367824
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4490.057170367824]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4490.061049471098
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4490.061049471098]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4490.411010081868
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4490.411010081868]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4490.537262154998
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4490.537262154998]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4490.648157840681
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4490.648157840681]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4491.041783972749
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4491.041783972749]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4491.066860593341
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4491.066860593341]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4491.1276919475995
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4491.1276919475995]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4491.508489308993
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4491.508489308993]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4491.559576777697
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4491.559576777697]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4491.767437637509
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4491.767437637509]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4491.778244226149
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4491.778244226149]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  2 , time 4492.3983362124745
# FOG, mobile, queue te ase, time
# [[2, 1, 2, 4492.3983362124745]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  3 , time 4492.444298302006
# FOG, mobile, queue te ase, time
# [[2, 2, 3, 4492.444298302006]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4492.667782836421
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4492.667782836421]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4493.371419215786
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4493.371419215786]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4493.373602881623
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4493.373602881623]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4493.934567057819
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4493.934567057819]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4494.090788419925
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4494.090788419925]]
# Fog:   Fog 1 mobile 2 , akhon queue te ase  1 , time 4494.353789994739
# FOG, mobile, queue te ase, time
# [[1, 2, 1, 4494.353789994739]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4494.595662350017
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4494.595662350017]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  1 , time 4494.81184792502
# FOG, mobile, queue te ase, time
# [[2, 2, 1, 4494.81184792502]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  2 , time 4494.919976112677
# FOG, mobile, queue te ase, time
# [[2, 2, 2, 4494.919976112677]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  3 , time 4494.928115633199
# FOG, mobile, queue te ase, time
# [[2, 1, 3, 4494.928115633199]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  4 , time 4494.9290763367935
# FOG, mobile, queue te ase, time
# [[2, 1, 4, 4494.9290763367935]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  5 , time 4495.134360354836
# FOG, mobile, queue te ase, time
# [[2, 1, 5, 4495.134360354836]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4495.670442787676
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4495.670442787676]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  5 , time 4495.69251362023
# FOG, mobile, queue te ase, time
# [[2, 1, 5, 4495.69251362023]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4495.79306268712
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4495.79306268712]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4496.081644024963
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4496.081644024963]]
# Fog:   Fog 2 mobile 2 , akhon queue te ase  5 , time 4496.624876854731
# FOG, mobile, queue te ase, time
# [[2, 2, 5, 4496.624876854731]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4496.629754691723
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4496.629754691723]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4496.985253458857
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4496.985253458857]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4497.404886838317
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4497.404886838317]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4497.695392396772
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4497.695392396772]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4498.03101543265
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4498.03101543265]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4498.254104518971
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4498.254104518971]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4498.284031015814
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4498.284031015814]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4499.054879274157
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4499.054879274157]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4499.78694400348
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4499.78694400348]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4500.551411291713
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4500.551411291713]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4500.749559389901
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4500.749559389901]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4501.1976949264
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4501.1976949264]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4501.729624322138
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4501.729624322138]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4501.776302554535
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4501.776302554535]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4502.217627443083
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4502.217627443083]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4502.361893270299
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4502.361893270299]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4502.376197327913
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4502.376197327913]]
# Fog:   Fog 1 mobile 1 , akhon queue te ase  1 , time 4502.938698540365
# FOG, mobile, queue te ase, time
# [[1, 1, 1, 4502.938698540365]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4503.056817767005
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4503.056817767005]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4504.213546817171
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4504.213546817171]]
# Fog:   Fog 2 mobile 1 , akhon queue te ase  1 , time 4505.2510071676015
# FOG, mobile, queue te ase, time
# [[2, 1, 1, 4505.2510071676015]]
# 0 1
# 958 1042
# FOG-1 Average queueing time: 0.06225595478896796
# FOG-1 Average service time: 0.7682632493977907
# FOG-1 Average response time: 0.830519204186758
# FOG-1 Average Energy consumption: 226.97924769552037
# FOG-2 Average queueing time: 0.08824891669404017
# FOG-2 Average service time: 0.7984123727546586
# FOG-2 Average response time: 0.8866612894486993
# FOG-2 Average Energy consumption: 230.16993209312446

# %%
import numpy as np   #importing libraries
import simpy 
import queue
import random
import random as rd
import matplotlib 
from matplotlib import pyplot as plt

# %%
global SZ,CP,RM
SZ=[]
CP=[]
RM=[]
N=1000
k=10
Lambda = 5
mu = 1.25
#t = 0   #system clock
t1=0
t2=0
t_lambda = 0 #poisson random variable used to generate next service time
t_mu = 0  #poisson random variable used to generate next departure time
t_a=0
wait=0
R=1000
transmission_time=0
l="0"
P_transmission=500
P_idle=100
alpha = 0.1
gamma = 0.95
episodes = 10
SHOW_EVERY = 100
STATS_EVERY=100
observation_space_discretesize = [20, 20]

# %%
class Packet(object):
    def __init__(self, time, id, mobileID, seeed):
        
        self.time=time                                                
        self.id=id
        self.mobileID=mobileID   
        self.size=random.randint(200,400) #seed 1 op 2, seed 2 op 
        SZ.append(round(self.size,2))
        #print(seeed)
        #random.seed(seeed)
        self.cpu=random.randint(20,90) #seed 1 op 2, seed 2 op 
        CP.append(round(self.cpu,2))
        #random.seed(seeed)
        self.ram=random.randint(1, 32) #seed 1 op 3, seed 2 op 1, seed 3 op 4
        RM.append(round(self.ram,2))

class mobile(object): #mobile class with an ID              
    def __init__(self, ID):
        self.ID=ID
        self.pot=int(1)
        
    #generates packets and sends via out_pipe
    def packet_generator(self, numPackets, env, out_pipe, task_id,send): 
        
        yield env.timeout(send)
        #print("sending task {} of mobile {} at time {}".format(task_id, self.ID, env.now))
        p=Packet(env.now, task_id, self.ID, self.pot)
        self.pot+=1
        if(self.pot==4):
                self.pot=1
        yield out_pipe.put(p)
        item = yield out_pipe.get()

# %%
 def reward_generator(T): 
    Tsla=2.5 
    Nsla=3
    Gsla=3  
    Cost_sla=50
    Cg=0
    Ct=0
    Cn=0
    Cost_n=0
    
    #if (G<Gsla):
        #Cg=-5*(Gsla/G)
    if (T>Tsla):
        Ct = -5 * (T/Tsla)
    #if (N>Nsla):
        #Cn=-5*(N/Nsla)
    #if (cost>Cost_sla):
        #Cost_n=-5*(cost/Cost_sla)
    
    Reward = (Tsla/T) + Ct #Reward Function
    return Reward

# %%
class Fog(object):      
    def __init__(self, ID):
        self.ID=ID
        self.Number_queue=1
        self.lost=0
        self.response_time=0
        self.server_count=0
        self.wait=0
        self.taskinqueue=0
        self.time=0
        
        self.service_time=[]
        self.response_time_list=[]
        self.Serverqueue=[]
        self.total_serverqueue=[]
        self.waitlist=[]
        self.energy_offloading=[]
        self.reward_list=[]
        self.state=[]
        
    def FOG(self, env, server, in_pipe,mobile):
        
         msg = yield in_pipe.get()
         transmission_time = (msg.size/R)
         #print("transmits task {} to need time {}".format(msg.id,transmission_time,self.ID))
         yield env.timeout(transmission_time)
         a=env.now
         #print("Arrived task {} at time {} at FOG {}".format(msg.id,a,self.ID))
         #print("server",self.server_count)
         if self.server_count==3:
            if len(self.Serverqueue)<k:
               self.Serverqueue.append(msg)
               self.taskinqueue=len(self.Serverqueue)
               #print("queue te ase ",len(self.Serverqueue))
               #print("task ase queue te ase ",taskinqueue)
               self.Number_queue = self.Number_queue + 1
               #self.server_count=0
            else:
                self.lost=self.lost+1 
                return  
         #s=q+1  
         #q=s
         u=rd.random()
         t_mu=-np.log(u)/mu
         self.service_time.append(t_mu)
         #print("service time",t_mu)
         E = (P_transmission * transmission_time) + (P_idle * t_mu)
         self.energy_offloading.append(E)
         
         #print("present a queue te ase ",len(self.Serverqueue))
         print("Fog",self.ID,"akhon queue te ase ",self.taskinqueue)
         with server.request() as req:
             yield req
             s=env.now
             self.wait=s-a
             if len(self.Serverqueue)>0:
                 self.Serverqueue.pop(0)
             #self.total_serverqueue.append(len(self.Serverqueue))
             #print("queue",len(self.Serverqueue))
             #print("wait",self.wait)
             #print("Starting service task {} at time {} at FOG {}".format(msg.id,s,self.ID))
             #print("Waiting time of task {} at time {} at FOG {}".format(msg.id,self.wait,self.ID))
             self.waitlist.append(self.wait)
             self.response_time=self.wait+t_mu
             self.response_time_list.append(self.response_time)
             
             #if self.wait>0:
                #print("queue",len(self.Serverqueue))
              #  if len(self.Serverqueue)<10:
               #     self.Serverqueue.append(msg)
                #    self.Number_queue = self.Number_queue + 1
                 #   self.total_serverqueue.append(len(self.Serverqueue))
                  #  yield env.timeout(t_mu)
                   # print("Finish service task {} at time {} at FOG {}".format(msg.id,env.now,self.ID))
                    #if len(self.Serverqueue)>0:
                     #   self.Serverqueue.pop(0)
                #else:
                 #   self.lost=self.lost+1 
                  #  return 
             self.server_count=self.server_count+1
             yield env.timeout(t_mu)
             #print("Finish service task {} at time {} at FOG {}".format(msg.id,env.now,self.ID))
             self.server_count=self.server_count-1   

                
             r=reward_generator(self.response_time)
             self.reward_list.append(r)
             
    def decision(self,env):
        self.time=self.time+1
        yield env.timeout(self.time)
        print("time is",env.now)
        next_state=self.taskinqueue
        print("decision: Req er age ei time a queue te ase",next_state)

# %%
env1 = simpy.Environment()    
server1 = simpy.Resource(env1, capacity=3)
server2 = simpy.Resource(env1, capacity=3)

pipe1 = simpy.Store(env1)
pipe2 = simpy.Store(env1)
pipe3 = simpy.Store(env1)

ms1=mobile(1)
ms2=mobile(2)
ms3=mobile(3)

fog1 = Fog(1)
fog2 = Fog(2)
fog1_count=0
fog2_count=0
for i in range(N):
    
    choose=random.randint(1,2)

    if(choose==1):
        fog1_count=fog1_count+1
        u=rd.random()
        t_lambda=-np.log(u)/Lambda
        t_a=t1+t_lambda
        t1=t_a

        env1.process(ms1.packet_generator(1, env1, pipe1, i,t_a))
        env1.process(fog1.FOG(env1, server1, pipe1,ms1.ID))
        env1.process(fog1.decision(env1))
        
        fog1_count=fog1_count+1
        u=rd.random()
        t_lambda=-np.log(u)/Lambda
        t_a=t2+t_lambda
        t2=t_a

        env1.process(ms2.packet_generator(1, env1, pipe2, i,t_a))
        env1.process(fog1.FOG(env1, server1, pipe2,ms2.ID))
        env1.process(fog1.decision(env1))
    if(choose==2):
         fog2_count=fog2_count+1
         u=rd.random()
         t_lambda=-np.log(u)/Lambda
         t_a=t1+t_lambda
         t1=t_a

         env1.process(ms1.packet_generator(1, env1, pipe1, i,t_a))
         env1.process(fog2.FOG(env1, server2, pipe1,ms1.ID))
         env1.process(fog1.decision(env1))
        
         fog2_count=fog2_count+1
         u=rd.random()
         t_lambda=-np.log(u)/Lambda
         t_a=t2+t_lambda
         t2=t_a

         env1.process(ms2.packet_generator(1, env1, pipe2, i,t_a))
         env1.process(fog2.FOG(env1, server2, pipe2,ms2.ID))
         env1.process(fog1.decision(env1))
env1.run()
    
#i=0
#while (i<N):
 #   print("{}     {}     {}".format(i+1,fog1.response_time_list[i],fog1.reward_list[i]))
 #   i+=1

print(fog1.lost,fog2.lost)
print(fog1_count,fog2_count)
#print(len(fog1.total_serverqueue))
#Na=N-fog.lost
#print("No    serverqueue       wait_time")
#i=0
#c=0
#while (i<fog2_count):
   # if(fog2.waitlist[i]>0):
  #      c+=1
 #   i+=1
#print("total queue te ase",fog2.Number_queue)
#print("total wait list e ase",c)
#print("FOG-1 MAXIMUM REAWARD:", max(fog1.reward_list))
#print("FOG-1 total number of task in queue",fog1.Number_queue)
avgwaittime=sum(fog1.waitlist)/fog1_count
print("FOG-1 Average queueing time:", avgwaittime)
avgservicetime=sum(fog1.service_time)/fog1_count
print("FOG-1 Average service time:", avgservicetime)
avgsystemtime=sum(fog1.response_time_list)/fog1_count
print("FOG-1 Average response time:", avgsystemtime)
avgenergy=sum(fog1.energy_offloading)/fog1_count
print("FOG-1 Average Energy consumption:", avgenergy)

#print("No    response_time       reward")
#i=0
#while (i<N):
 #   print("{}     {}     {}".format(i+1,fog2.response_time_list[i],fog2.reward_list[i]))
  #  i+=1
#print("FOG-2 MAXIMUM REAWARD:", max(fog2.reward_list))
#print("FOG-2 total number of task in queue",fog2.Number_queue)
avgwaittime=sum(fog2.waitlist)/fog2_count
print("FOG-2 Average queueing time:", avgwaittime)
avgservicetime=sum(fog2.service_time)/fog2_count
print("FOG-2 Average service time:", avgservicetime)
avgsystemtime=sum(fog2.response_time_list)/fog2_count
print("FOG-2 Average response time:", avgsystemtime)
avgenergy=sum(fog2.energy_offloading)/fog2_count
print("FOG-2 Average Energy consumption:", avgenergy)
# Out:
# Fog 1 akhon queue te ase  0
# Fog 1 akhon queue te ase  0
# Fog 2 akhon queue te ase  0
# Fog 2 akhon queue te ase  0
# Fog 1 akhon queue te ase  0
# Fog 2 akhon queue te ase  0
# time is 1
# decision: Req er age ei time a queue te ase 0
# Fog 2 akhon queue te ase  1
# Fog 1 akhon queue te ase  0
# Fog 1 akhon queue te ase  0
# Fog 1 akhon queue te ase  0
# Fog 1 akhon queue te ase  0
# Fog 1 akhon queue te ase  1
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  2
# time is 2
# decision: Req er age ei time a queue te ase 2
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  3
# Fog 2 akhon queue te ase  1
# Fog 2 akhon queue te ase  1
# Fog 1 akhon queue te ase  4
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# time is 3
# decision: Req er age ei time a queue te ase 7
# Fog 2 akhon queue te ase  1
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  1
# Fog 2 akhon queue te ase  1
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  2
# Fog 2 akhon queue te ase  3
# Fog 2 akhon queue te ase  4
# Fog 1 akhon queue te ase  9
# time is 4
# decision: Req er age ei time a queue te ase 9
# Fog 2 akhon queue te ase  2
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  2
# Fog 1 akhon queue te ase  9
# time is 5
# decision: Req er age ei time a queue te ase 9
# Fog 2 akhon queue te ase  3
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  3
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  3
# Fog 2 akhon queue te ase  4
# time is 6
# decision: Req er age ei time a queue te ase 8
# Fog 2 akhon queue te ase  4
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# time is 7
# decision: Req er age ei time a queue te ase 9
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  4
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  1
# Fog 1 akhon queue te ase  10
# time is 8
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  2
# Fog 2 akhon queue te ase  2
# Fog 2 akhon queue te ase  2
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  1
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  1
# Fog 1 akhon queue te ase  10
# time is 9
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  1
# Fog 2 akhon queue te ase  1
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  1
# time is 10
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  2
# Fog 2 akhon queue te ase  3
# Fog 2 akhon queue te ase  4
# Fog 1 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  3
# Fog 2 akhon queue te ase  6
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  4
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  6
# Fog 1 akhon queue te ase  4
# Fog 2 akhon queue te ase  7
# time is 11
# decision: Req er age ei time a queue te ase 4
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  4
# time is 12
# decision: Req er age ei time a queue te ase 4
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  2
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  2
# Fog 2 akhon queue te ase  9
# time is 13
# decision: Req er age ei time a queue te ase 2
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  2
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  2
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  1
# time is 14
# decision: Req er age ei time a queue te ase 1
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  1
# Fog 1 akhon queue te ase  1
# Fog 1 akhon queue te ase  1
# Fog 1 akhon queue te ase  1
# Fog 2 akhon queue te ase  10
# time is 15
# decision: Req er age ei time a queue te ase 1
# Fog 1 akhon queue te ase  1
# Fog 1 akhon queue te ase  2
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  4
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  6
# time is 16
# decision: Req er age ei time a queue te ase 6
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  4
# time is 17
# decision: Req er age ei time a queue te ase 4
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  4
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# time is 18
# decision: Req er age ei time a queue te ase 8
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# time is 19
# decision: Req er age ei time a queue te ase 9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# time is 20
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  9
# time is 21
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  3
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  5
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# time is 22
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  6
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  2
# Fog 1 akhon queue te ase  10
# time is 23
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  3
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  1
# Fog 2 akhon queue te ase  2
# time is 24
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  2
# Fog 2 akhon queue te ase  2
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  3
# time is 25
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  3
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  4
# time is 26
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  4
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  4
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  4
# Fog 1 akhon queue te ase  10
# time is 27
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  6
# time is 28
# decision: Req er age ei time a queue te ase 6
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  5
# time is 29
# decision: Req er age ei time a queue te ase 8
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  4
# Fog 2 akhon queue te ase  10
# time is 30
# decision: Req er age ei time a queue te ase 4
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  4
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  8
# time is 31
# decision: Req er age ei time a queue te ase 6
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  5
# time is 32
# decision: Req er age ei time a queue te ase 5
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  4
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  4
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  4
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# time is 33
# decision: Req er age ei time a queue te ase 7
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  4
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  5
# Fog 2 akhon queue te ase  9
# time is 34
# decision: Req er age ei time a queue te ase 5
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# time is 35
# decision: Req er age ei time a queue te ase 7
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  7
# time is 36
# decision: Req er age ei time a queue te ase 7
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# time is 37
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# time is 38
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  1
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  3
# time is 39
# decision: Req er age ei time a queue te ase 3
# Fog 1 akhon queue te ase  4
# Fog 1 akhon queue te ase  5
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  4
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  4
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  7
# time is 40
# decision: Req er age ei time a queue te ase 7
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# time is 41
# decision: Req er age ei time a queue te ase 6
# Fog 1 akhon queue te ase  1
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  4
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  4
# time is 42
# decision: Req er age ei time a queue te ase 4
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  3
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  3
# Fog 2 akhon queue te ase  9
# time is 43
# decision: Req er age ei time a queue te ase 3
# Fog 1 akhon queue te ase  2
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  2
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  4
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# time is 44
# decision: Req er age ei time a queue te ase 4
# Fog 1 akhon queue te ase  4
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  5
# time is 45
# decision: Req er age ei time a queue te ase 5
# Fog 1 akhon queue te ase  5
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  4
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  8
# time is 46
# decision: Req er age ei time a queue te ase 8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 47
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  10
# time is 48
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  7
# time is 49
# decision: Req er age ei time a queue te ase 7
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# time is 50
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  4
# Fog 1 akhon queue te ase  10
# time is 51
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  2
# Fog 2 akhon queue te ase  2
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  3
# time is 52
# decision: Req er age ei time a queue te ase 8
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  6
# Fog 1 akhon queue te ase  10
# time is 53
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  2
# Fog 2 akhon queue te ase  2
# Fog 1 akhon queue te ase  7
# time is 54
# decision: Req er age ei time a queue te ase 7
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  2
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  2
# Fog 2 akhon queue te ase  2
# Fog 2 akhon queue te ase  1
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  1
# time is 55
# decision: Req er age ei time a queue te ase 9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  1
# Fog 2 akhon queue te ase  2
# Fog 2 akhon queue te ase  3
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  3
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  3
# Fog 1 akhon queue te ase  10
# time is 56
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  3
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  4
# time is 57
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  4
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  10
# time is 58
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# time is 59
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  7
# time is 60
# decision: Req er age ei time a queue te ase 7
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  4
# Fog 1 akhon queue te ase  10
# time is 61
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  5
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  4
# time is 62
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  10
# time is 63
# decision: Req er age ei time a queue te ase 6
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# time is 64
# decision: Req er age ei time a queue te ase 8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# time is 65
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# time is 66
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  9
# time is 67
# decision: Req er age ei time a queue te ase 9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  8
# time is 68
# decision: Req er age ei time a queue te ase 8
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# time is 69
# decision: Req er age ei time a queue te ase 9
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  10
# time is 70
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# time is 71
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# time is 72
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  7
# time is 73
# decision: Req er age ei time a queue te ase 7
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# time is 74
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# time is 75
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# time is 76
# decision: Req er age ei time a queue te ase 9
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  6
# time is 77
# decision: Req er age ei time a queue te ase 8
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 78
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# time is 79
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 80
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# time is 81
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  7
# time is 82
# decision: Req er age ei time a queue te ase 7
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 83
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 84
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  9
# time is 85
# decision: Req er age ei time a queue te ase 9
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  8
# time is 86
# decision: Req er age ei time a queue te ase 8
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# time is 87
# decision: Req er age ei time a queue te ase 7
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  5
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  8
# time is 88
# decision: Req er age ei time a queue te ase 8
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 89
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  8
# time is 90
# decision: Req er age ei time a queue te ase 8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  4
# Fog 1 akhon queue te ase  4
# Fog 1 akhon queue te ase  5
# time is 91
# decision: Req er age ei time a queue te ase 5
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  4
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  5
# Fog 2 akhon queue te ase  10
# time is 92
# decision: Req er age ei time a queue te ase 5
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  9
# time is 93
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# time is 94
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  8
# time is 95
# decision: Req er age ei time a queue te ase 8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# time is 96
# decision: Req er age ei time a queue te ase 8
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# time is 97
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  9
# time is 98
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  5
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# time is 99
# decision: Req er age ei time a queue te ase 8
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# time is 100
# decision: Req er age ei time a queue te ase 9
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# time is 101
# decision: Req er age ei time a queue te ase 8
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 102
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# time is 103
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  5
# Fog 2 akhon queue te ase  6
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# time is 104
# decision: Req er age ei time a queue te ase 9
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  8
# time is 105
# decision: Req er age ei time a queue te ase 9
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  8
# time is 106
# decision: Req er age ei time a queue te ase 8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  10
# time is 107
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# time is 108
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  6
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  5
# Fog 2 akhon queue te ase  5
# Fog 2 akhon queue te ase  6
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  10
# time is 109
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 110
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  9
# time is 111
# decision: Req er age ei time a queue te ase 9
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 112
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# time is 113
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# time is 114
# decision: Req er age ei time a queue te ase 9
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  7
# time is 115
# decision: Req er age ei time a queue te ase 8
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# time is 116
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# time is 117
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 118
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  6
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 119
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# time is 120
# decision: Req er age ei time a queue te ase 8
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  5
# time is 121
# decision: Req er age ei time a queue te ase 9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  5
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 122
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  1
# Fog 2 akhon queue te ase  2
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  1
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  1
# time is 123
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  1
# Fog 2 akhon queue te ase  1
# Fog 2 akhon queue te ase  1
# Fog 2 akhon queue te ase  1
# Fog 1 akhon queue te ase  4
# Fog 1 akhon queue te ase  5
# Fog 2 akhon queue te ase  1
# Fog 1 akhon queue te ase  6
# time is 124
# decision: Req er age ei time a queue te ase 6
# Fog 2 akhon queue te ase  2
# Fog 1 akhon queue te ase  5
# Fog 2 akhon queue te ase  3
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  3
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# time is 125
# decision: Req er age ei time a queue te ase 7
# Fog 1 akhon queue te ase  5
# Fog 2 akhon queue te ase  5
# Fog 2 akhon queue te ase  6
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  7
# time is 126
# decision: Req er age ei time a queue te ase 7
# Fog 2 akhon queue te ase  5
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# time is 127
# decision: Req er age ei time a queue te ase 7
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  3
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  4
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  8
# time is 128
# decision: Req er age ei time a queue te ase 6
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  4
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  3
# Fog 2 akhon queue te ase  10
# time is 129
# decision: Req er age ei time a queue te ase 3
# Fog 1 akhon queue te ase  4
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  6
# time is 130
# decision: Req er age ei time a queue te ase 6
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  6
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  7
# time is 131
# decision: Req er age ei time a queue te ase 7
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# time is 132
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  7
# time is 133
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  6
# time is 134
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# time is 135
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  6
# Fog 1 akhon queue te ase  4
# Fog 1 akhon queue te ase  5
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# time is 136
# decision: Req er age ei time a queue te ase 7
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  6
# time is 137
# decision: Req er age ei time a queue te ase 6
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  7
# time is 138
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  6
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# time is 139
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# time is 140
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  10
# time is 141
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# time is 142
# decision: Req er age ei time a queue te ase 9
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  4
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  7
# time is 143
# decision: Req er age ei time a queue te ase 8
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# time is 144
# decision: Req er age ei time a queue te ase 9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 145
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# time is 146
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  8
# time is 147
# decision: Req er age ei time a queue te ase 8
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  10
# time is 148
# decision: Req er age ei time a queue te ase 8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# time is 149
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# time is 150
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# time is 151
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# time is 152
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 153
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  8
# time is 154
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# time is 155
# decision: Req er age ei time a queue te ase 8
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# time is 156
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# time is 157
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# time is 158
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  7
# time is 159
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# time is 160
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# time is 161
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 162
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  5
# time is 163
# decision: Req er age ei time a queue te ase 5
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  2
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  2
# time is 164
# decision: Req er age ei time a queue te ase 2
# Fog 2 akhon queue te ase  4
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  2
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  1
# time is 165
# decision: Req er age ei time a queue te ase 1
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  3
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  2
# Fog 2 akhon queue te ase  5
# time is 166
# decision: Req er age ei time a queue te ase 2
# Fog 2 akhon queue te ase  3
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  2
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# Fog 1 akhon queue te ase  2
# time is 167
# decision: Req er age ei time a queue te ase 2
# Fog 1 akhon queue te ase  2
# Fog 2 akhon queue te ase  4
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  1
# Fog 1 akhon queue te ase  1
# Fog 1 akhon queue te ase  1
# Fog 2 akhon queue te ase  4
# Fog 1 akhon queue te ase  1
# Fog 1 akhon queue te ase  1
# Fog 2 akhon queue te ase  4
# Fog 1 akhon queue te ase  2
# Fog 2 akhon queue te ase  3
# Fog 2 akhon queue te ase  4
# Fog 2 akhon queue te ase  5
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  2
# time is 168
# decision: Req er age ei time a queue te ase 2
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  2
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  4
# Fog 1 akhon queue te ase  5
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  7
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# time is 169
# decision: Req er age ei time a queue te ase 9
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  6
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  10
# time is 170
# decision: Req er age ei time a queue te ase 10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 171
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  10
# time is 172
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# time is 173
# decision: Req er age ei time a queue te ase 10
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  4
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  8
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  3
# Fog 1 akhon queue te ase  4
# Fog 2 akhon queue te ase  6
# time is 174
# decision: Req er age ei time a queue te ase 4
# Fog 1 akhon queue te ase  5
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  6
# Fog 2 akhon queue te ase  7
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  7
# Fog 2 akhon queue te ase  8
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# time is 175
# decision: Req er age ei time a queue te ase 8
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  8
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  5
# time is 176
# decision: Req er age ei time a queue te ase 5
# Fog 1 akhon queue te ase  6
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  7
# Fog 1 akhon queue te ase  8
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 1 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# time is 177
# decision: Req er age ei time a queue te ase 9
# Fog 1 akhon queue te ase  10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 2 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  9
# Fog 2 akhon queue te ase  10
# Fog 1 akhon queue te ase  10
# time is 178
# ...
# time is 1737
# decision: Req er age ei time a queue te ase 1
# time is 1738
# decision: Req er age ei time a queue te ase 1
# time is 1739
# decision: Req er age ei time a queue te ase 1
# time is 1740
# decision: Req er age ei time a queue te ase 1
# time is 1741
# decision: Req er age ei time a queue te ase 1
# time is 1742
# decision: Req er age ei time a queue te ase 1
# time is 1743
# decision: Req er age ei time a queue te ase 1
# time is 1744
# decision: Req er age ei time a queue te ase 1
# time is 1745
# decision: Req er age ei time a queue te ase 1
# time is 1746
# decision: Req er age ei time a queue te ase 1
# time is 1747
# decision: Req er age ei time a queue te ase 1
# time is 1748
# decision: Req er age ei time a queue te ase 1
# time is 1749
# decision: Req er age ei time a queue te ase 1
# time is 1750
# decision: Req er age ei time a queue te ase 1
# time is 1751
# decision: Req er age ei time a queue te ase 1
# time is 1752
# decision: Req er age ei time a queue te ase 1
# time is 1753
# decision: Req er age ei time a queue te ase 1
# time is 1754
# decision: Req er age ei time a queue te ase 1
# time is 1755
# decision: Req er age ei time a queue te ase 1
# time is 1756
# decision: Req er age ei time a queue te ase 1
# time is 1757
# decision: Req er age ei time a queue te ase 1
# time is 1758
# decision: Req er age ei time a queue te ase 1
# time is 1759
# decision: Req er age ei time a queue te ase 1
# time is 1760
# decision: Req er age ei time a queue te ase 1
# time is 1761
# decision: Req er age ei time a queue te ase 1
# time is 1762
# decision: Req er age ei time a queue te ase 1
# time is 1763
# decision: Req er age ei time a queue te ase 1
# time is 1764
# decision: Req er age ei time a queue te ase 1
# time is 1765
# decision: Req er age ei time a queue te ase 1
# time is 1766
# decision: Req er age ei time a queue te ase 1
# time is 1767
# decision: Req er age ei time a queue te ase 1
# time is 1768
# decision: Req er age ei time a queue te ase 1
# time is 1769
# decision: Req er age ei time a queue te ase 1
# time is 1770
# decision: Req er age ei time a queue te ase 1
# time is 1771
# decision: Req er age ei time a queue te ase 1
# time is 1772
# decision: Req er age ei time a queue te ase 1
# time is 1773
# decision: Req er age ei time a queue te ase 1
# time is 1774
# decision: Req er age ei time a queue te ase 1
# time is 1775
# decision: Req er age ei time a queue te ase 1
# time is 1776
# decision: Req er age ei time a queue te ase 1
# time is 1777
# decision: Req er age ei time a queue te ase 1
# time is 1778
# decision: Req er age ei time a queue te ase 1
# time is 1779
# decision: Req er age ei time a queue te ase 1
# time is 1780
# decision: Req er age ei time a queue te ase 1
# time is 1781
# decision: Req er age ei time a queue te ase 1
# time is 1782
# decision: Req er age ei time a queue te ase 1
# time is 1783
# decision: Req er age ei time a queue te ase 1
# time is 1784
# decision: Req er age ei time a queue te ase 1
# time is 1785
# decision: Req er age ei time a queue te ase 1
# time is 1786
# decision: Req er age ei time a queue te ase 1
# time is 1787
# decision: Req er age ei time a queue te ase 1
# time is 1788
# decision: Req er age ei time a queue te ase 1
# time is 1789
# decision: Req er age ei time a queue te ase 1
# time is 1790
# decision: Req er age ei time a queue te ase 1
# time is 1791
# decision: Req er age ei time a queue te ase 1
# time is 1792
# decision: Req er age ei time a queue te ase 1
# time is 1793
# decision: Req er age ei time a queue te ase 1
# time is 1794
# decision: Req er age ei time a queue te ase 1
# time is 1795
# decision: Req er age ei time a queue te ase 1
# time is 1796
# decision: Req er age ei time a queue te ase 1
# time is 1797
# decision: Req er age ei time a queue te ase 1
# time is 1798
# decision: Req er age ei time a queue te ase 1
# time is 1799
# decision: Req er age ei time a queue te ase 1
# time is 1800
# decision: Req er age ei time a queue te ase 1
# time is 1801
# decision: Req er age ei time a queue te ase 1
# time is 1802
# decision: Req er age ei time a queue te ase 1
# time is 1803
# decision: Req er age ei time a queue te ase 1
# time is 1804
# decision: Req er age ei time a queue te ase 1
# time is 1805
# decision: Req er age ei time a queue te ase 1
# time is 1806
# decision: Req er age ei time a queue te ase 1
# time is 1807
# decision: Req er age ei time a queue te ase 1
# time is 1808
# decision: Req er age ei time a queue te ase 1
# time is 1809
# decision: Req er age ei time a queue te ase 1
# time is 1810
# decision: Req er age ei time a queue te ase 1
# time is 1811
# decision: Req er age ei time a queue te ase 1
# time is 1812
# decision: Req er age ei time a queue te ase 1
# time is 1813
# decision: Req er age ei time a queue te ase 1
# time is 1814
# decision: Req er age ei time a queue te ase 1
# time is 1815
# decision: Req er age ei time a queue te ase 1
# time is 1816
# decision: Req er age ei time a queue te ase 1
# time is 1817
# decision: Req er age ei time a queue te ase 1
# time is 1818
# decision: Req er age ei time a queue te ase 1
# time is 1819
# decision: Req er age ei time a queue te ase 1
# time is 1820
# decision: Req er age ei time a queue te ase 1
# time is 1821
# decision: Req er age ei time a queue te ase 1
# time is 1822
# decision: Req er age ei time a queue te ase 1
# time is 1823
# decision: Req er age ei time a queue te ase 1
# time is 1824
# decision: Req er age ei time a queue te ase 1
# time is 1825
# decision: Req er age ei time a queue te ase 1
# time is 1826
# decision: Req er age ei time a queue te ase 1
# time is 1827
# decision: Req er age ei time a queue te ase 1
# time is 1828
# decision: Req er age ei time a queue te ase 1
# time is 1829
# decision: Req er age ei time a queue te ase 1
# time is 1830
# decision: Req er age ei time a queue te ase 1
# time is 1831
# decision: Req er age ei time a queue te ase 1
# time is 1832
# decision: Req er age ei time a queue te ase 1
# time is 1833
# decision: Req er age ei time a queue te ase 1
# time is 1834
# decision: Req er age ei time a queue te ase 1
# time is 1835
# decision: Req er age ei time a queue te ase 1
# time is 1836
# decision: Req er age ei time a queue te ase 1
# time is 1837
# decision: Req er age ei time a queue te ase 1
# time is 1838
# decision: Req er age ei time a queue te ase 1
# time is 1839
# decision: Req er age ei time a queue te ase 1
# time is 1840
# decision: Req er age ei time a queue te ase 1
# time is 1841
# decision: Req er age ei time a queue te ase 1
# time is 1842
# decision: Req er age ei time a queue te ase 1
# time is 1843
# decision: Req er age ei time a queue te ase 1
# time is 1844
# decision: Req er age ei time a queue te ase 1
# time is 1845
# decision: Req er age ei time a queue te ase 1
# time is 1846
# decision: Req er age ei time a queue te ase 1
# time is 1847
# decision: Req er age ei time a queue te ase 1
# time is 1848
# decision: Req er age ei time a queue te ase 1
# time is 1849
# decision: Req er age ei time a queue te ase 1
# time is 1850
# decision: Req er age ei time a queue te ase 1
# time is 1851
# decision: Req er age ei time a queue te ase 1
# time is 1852
# decision: Req er age ei time a queue te ase 1
# time is 1853
# decision: Req er age ei time a queue te ase 1
# time is 1854
# decision: Req er age ei time a queue te ase 1
# time is 1855
# decision: Req er age ei time a queue te ase 1
# time is 1856
# decision: Req er age ei time a queue te ase 1
# time is 1857
# decision: Req er age ei time a queue te ase 1
# time is 1858
# decision: Req er age ei time a queue te ase 1
# time is 1859
# decision: Req er age ei time a queue te ase 1
# time is 1860
# decision: Req er age ei time a queue te ase 1
# time is 1861
# decision: Req er age ei time a queue te ase 1
# time is 1862
# decision: Req er age ei time a queue te ase 1
# time is 1863
# decision: Req er age ei time a queue te ase 1
# time is 1864
# decision: Req er age ei time a queue te ase 1
# time is 1865
# decision: Req er age ei time a queue te ase 1
# time is 1866
# decision: Req er age ei time a queue te ase 1
# time is 1867
# decision: Req er age ei time a queue te ase 1
# time is 1868
# decision: Req er age ei time a queue te ase 1
# time is 1869
# decision: Req er age ei time a queue te ase 1
# time is 1870
# decision: Req er age ei time a queue te ase 1
# time is 1871
# decision: Req er age ei time a queue te ase 1
# time is 1872
# decision: Req er age ei time a queue te ase 1
# time is 1873
# decision: Req er age ei time a queue te ase 1
# time is 1874
# decision: Req er age ei time a queue te ase 1
# time is 1875
# decision: Req er age ei time a queue te ase 1
# time is 1876
# decision: Req er age ei time a queue te ase 1
# time is 1877
# decision: Req er age ei time a queue te ase 1
# time is 1878
# decision: Req er age ei time a queue te ase 1
# time is 1879
# decision: Req er age ei time a queue te ase 1
# time is 1880
# decision: Req er age ei time a queue te ase 1
# time is 1881
# decision: Req er age ei time a queue te ase 1
# time is 1882
# decision: Req er age ei time a queue te ase 1
# time is 1883
# decision: Req er age ei time a queue te ase 1
# time is 1884
# decision: Req er age ei time a queue te ase 1
# time is 1885
# decision: Req er age ei time a queue te ase 1
# time is 1886
# decision: Req er age ei time a queue te ase 1
# time is 1887
# decision: Req er age ei time a queue te ase 1
# time is 1888
# decision: Req er age ei time a queue te ase 1
# time is 1889
# decision: Req er age ei time a queue te ase 1
# time is 1890
# decision: Req er age ei time a queue te ase 1
# time is 1891
# decision: Req er age ei time a queue te ase 1
# time is 1892
# decision: Req er age ei time a queue te ase 1
# time is 1893
# decision: Req er age ei time a queue te ase 1
# time is 1894
# decision: Req er age ei time a queue te ase 1
# time is 1895
# decision: Req er age ei time a queue te ase 1
# time is 1896
# decision: Req er age ei time a queue te ase 1
# time is 1897
# decision: Req er age ei time a queue te ase 1
# time is 1898
# decision: Req er age ei time a queue te ase 1
# time is 1899
# decision: Req er age ei time a queue te ase 1
# time is 1900
# decision: Req er age ei time a queue te ase 1
# time is 1901
# decision: Req er age ei time a queue te ase 1
# time is 1902
# decision: Req er age ei time a queue te ase 1
# time is 1903
# decision: Req er age ei time a queue te ase 1
# time is 1904
# decision: Req er age ei time a queue te ase 1
# time is 1905
# decision: Req er age ei time a queue te ase 1
# time is 1906
# decision: Req er age ei time a queue te ase 1
# time is 1907
# decision: Req er age ei time a queue te ase 1
# time is 1908
# decision: Req er age ei time a queue te ase 1
# time is 1909
# decision: Req er age ei time a queue te ase 1
# time is 1910
# decision: Req er age ei time a queue te ase 1
# time is 1911
# decision: Req er age ei time a queue te ase 1
# time is 1912
# decision: Req er age ei time a queue te ase 1
# time is 1913
# decision: Req er age ei time a queue te ase 1
# time is 1914
# decision: Req er age ei time a queue te ase 1
# time is 1915
# decision: Req er age ei time a queue te ase 1
# time is 1916
# decision: Req er age ei time a queue te ase 1
# time is 1917
# decision: Req er age ei time a queue te ase 1
# time is 1918
# decision: Req er age ei time a queue te ase 1
# time is 1919
# decision: Req er age ei time a queue te ase 1
# time is 1920
# decision: Req er age ei time a queue te ase 1
# time is 1921
# decision: Req er age ei time a queue te ase 1
# time is 1922
# decision: Req er age ei time a queue te ase 1
# time is 1923
# decision: Req er age ei time a queue te ase 1
# time is 1924
# decision: Req er age ei time a queue te ase 1
# time is 1925
# decision: Req er age ei time a queue te ase 1
# time is 1926
# decision: Req er age ei time a queue te ase 1
# time is 1927
# decision: Req er age ei time a queue te ase 1
# time is 1928
# decision: Req er age ei time a queue te ase 1
# time is 1929
# decision: Req er age ei time a queue te ase 1
# time is 1930
# decision: Req er age ei time a queue te ase 1
# time is 1931
# decision: Req er age ei time a queue te ase 1
# time is 1932
# decision: Req er age ei time a queue te ase 1
# time is 1933
# decision: Req er age ei time a queue te ase 1
# time is 1934
# decision: Req er age ei time a queue te ase 1
# time is 1935
# decision: Req er age ei time a queue te ase 1
# time is 1936
# decision: Req er age ei time a queue te ase 1
# time is 1937
# decision: Req er age ei time a queue te ase 1
# time is 1938
# decision: Req er age ei time a queue te ase 1
# time is 1939
# decision: Req er age ei time a queue te ase 1
# time is 1940
# decision: Req er age ei time a queue te ase 1
# time is 1941
# decision: Req er age ei time a queue te ase 1
# time is 1942
# decision: Req er age ei time a queue te ase 1
# time is 1943
# decision: Req er age ei time a queue te ase 1
# time is 1944
# decision: Req er age ei time a queue te ase 1
# time is 1945
# decision: Req er age ei time a queue te ase 1
# time is 1946
# decision: Req er age ei time a queue te ase 1
# time is 1947
# decision: Req er age ei time a queue te ase 1
# time is 1948
# decision: Req er age ei time a queue te ase 1
# time is 1949
# decision: Req er age ei time a queue te ase 1
# time is 1950
# decision: Req er age ei time a queue te ase 1
# time is 1951
# decision: Req er age ei time a queue te ase 1
# time is 1952
# decision: Req er age ei time a queue te ase 1
# time is 1953
# decision: Req er age ei time a queue te ase 1
# time is 1954
# decision: Req er age ei time a queue te ase 1
# time is 1955
# decision: Req er age ei time a queue te ase 1
# time is 1956
# decision: Req er age ei time a queue te ase 1
# time is 1957
# decision: Req er age ei time a queue te ase 1
# time is 1958
# decision: Req er age ei time a queue te ase 1
# time is 1959
# decision: Req er age ei time a queue te ase 1
# time is 1960
# decision: Req er age ei time a queue te ase 1
# time is 1961
# decision: Req er age ei time a queue te ase 1
# time is 1962
# decision: Req er age ei time a queue te ase 1
# time is 1963
# decision: Req er age ei time a queue te ase 1
# time is 1964
# decision: Req er age ei time a queue te ase 1
# time is 1965
# decision: Req er age ei time a queue te ase 1
# time is 1966
# decision: Req er age ei time a queue te ase 1
# time is 1967
# decision: Req er age ei time a queue te ase 1
# time is 1968
# decision: Req er age ei time a queue te ase 1
# time is 1969
# decision: Req er age ei time a queue te ase 1
# time is 1970
# decision: Req er age ei time a queue te ase 1
# time is 1971
# decision: Req er age ei time a queue te ase 1
# time is 1972
# decision: Req er age ei time a queue te ase 1
# time is 1973
# decision: Req er age ei time a queue te ase 1
# time is 1974
# decision: Req er age ei time a queue te ase 1
# time is 1975
# decision: Req er age ei time a queue te ase 1
# time is 1976
# decision: Req er age ei time a queue te ase 1
# time is 1977
# decision: Req er age ei time a queue te ase 1
# time is 1978
# decision: Req er age ei time a queue te ase 1
# time is 1979
# decision: Req er age ei time a queue te ase 1
# time is 1980
# decision: Req er age ei time a queue te ase 1
# time is 1981
# decision: Req er age ei time a queue te ase 1
# time is 1982
# decision: Req er age ei time a queue te ase 1
# time is 1983
# decision: Req er age ei time a queue te ase 1
# time is 1984
# decision: Req er age ei time a queue te ase 1
# time is 1985
# decision: Req er age ei time a queue te ase 1
# time is 1986
# decision: Req er age ei time a queue te ase 1
# time is 1987
# decision: Req er age ei time a queue te ase 1
# time is 1988
# decision: Req er age ei time a queue te ase 1
# time is 1989
# decision: Req er age ei time a queue te ase 1
# time is 1990
# decision: Req er age ei time a queue te ase 1
# time is 1991
# decision: Req er age ei time a queue te ase 1
# time is 1992
# decision: Req er age ei time a queue te ase 1
# time is 1993
# decision: Req er age ei time a queue te ase 1
# time is 1994
# decision: Req er age ei time a queue te ase 1
# time is 1995
# decision: Req er age ei time a queue te ase 1
# time is 1996
# decision: Req er age ei time a queue te ase 1
# time is 1997
# decision: Req er age ei time a queue te ase 1
# time is 1998
# decision: Req er age ei time a queue te ase 1
# time is 1999
# decision: Req er age ei time a queue te ase 1
# time is 2000
# decision: Req er age ei time a queue te ase 1
# 259 235
# 1002 998
# FOG-1 Average queueing time: 1.4645629863345815
# FOG-1 Average service time: 0.6097904923482016
# FOG-1 Average response time: 2.0743534786827844
# FOG-1 Average Energy consumption: 171.7734604124649
# FOG-2 Average queueing time: 1.4347714125048459
# FOG-2 Average service time: 0.6047382565199558
# FOG-2 Average response time: 2.039509669024804
# FOG-2 Average Energy consumption: 176.22382565199575
